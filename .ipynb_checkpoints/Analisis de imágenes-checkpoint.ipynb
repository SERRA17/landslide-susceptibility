# %%
import numpy as np  
from matplotlib import pyplot as plt, cm
import h5py
import pandas as pd
import glob
import os

# %%
from IPython.core.display import display, HTML
display(HTML("<style>div.output_scroll { height: 44em; }</style>"))
# Out:
# <style>div.output_scroll { height: 44em; }</style>

# %%
train_folder = r"C:\temp\UOC\TrainData\img"
#train_folder = r"C:\temp\UOC\TestData\img"
mask_folder =  r"C:\temp\UOC\TrainData\mask"
edt_folder = r"C:\temp\UOC\TrainData\edt"
da_landslide = pd.DataFrame(columns= {"imagen", "min_m", "max_m", "min_i", "max_i" ,"mean_m", "mean_i","std_m", "std_i","min","max","mean","std","banda"})
bandas= ("B1","B2","B3","B4","B5","B6","B7","B8","B9","B10","B11","B12","B13","B14")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-3-8beb8449060b> in <module>
#       3 mask_folder =  r"C:\temp\UOC\TrainData\mask"
#       4 edt_folder = r"C:\temp\UOC\TrainData\edt"
# ----> 5 da_landslide = pd.DataFrame(columns= {"imagen", "min_m", "max_m", "min_i", "max_i" ,"mean_m", "mean_i","std_m", "std_i","min","max","mean","std","banda"})
#       6 bandas= ("B1","B2","B3","B4","B5","B6","B7","B8","B9","B10","B11","B12","B13","B14")
#
# ~\Anaconda3\envs\capstone\lib\site-packages\pandas\core\frame.py in __init__(self, data, index, columns, dtype, copy)
#     433             )
#     434         elif isinstance(data, dict):
# --> 435             mgr = init_dict(data, index, columns, dtype=dtype)
#     436         elif isinstance(data, ma.MaskedArray):
#     437             import numpy.ma.mrecords as mrecords
#
# ~\Anaconda3\envs\capstone\lib\site-packages\pandas\core\internals\construction.py in init_dict(data, index, columns, dtype)
#     237             else:
#     238                 nan_dtype = dtype
# --> 239             val = construct_1d_arraylike_from_scalar(np.nan, len(index), nan_dtype)
#     240             arrays.loc[missing] = [val] * missing.sum()
#     241
#
# ~\Anaconda3\envs\capstone\lib\site-packages\pandas\core\dtypes\cast.py in construct_1d_arraylike_from_scalar(value, length, dtype)
#    1438     else:
#    1439         if not isinstance(dtype, (np.dtype, type(np.dtype))):
# -> 1440             dtype = dtype.dtype
#    1441
#    1442         if length and is_integer_dtype(dtype) and isna(value):
#
# AttributeError: type object 'object' has no attribute 'dtype'

# %%
cmap = cm.viridis
fichero_ejemplo = os.path.join (train_folder, 'image_1.h5')
example_dt = h5py.File(fichero_ejemplo,'r')

print(example_dt.keys())

images = example_dt['img']
print(images.shape)

fig, ax = plt.subplots(7,2,figsize = (20,80))

for i in range(14):
    img_np = images[:,:,i]
    plt.subplot(7,2,1+i)
    #plt.figsize=(10,10)
    d= plt.imshow(img_np, cmap=cmap)
    plt.title("Banda " + str(i) ,fontdict={'fontsize': 20})
    plt.colorbar(shrink=0.5)
plt.show()
# Out:
# <KeysViewHDF5 ['img']>
# (128, 128, 14)

# %%
#load masks
fichero_mask = os.path.join (mask_folder, 'mask_1.h5')
example_mask = h5py.File(fichero_mask,'r')

# see what is inside that h5 file
print(example_mask.keys())

masks = example_mask['mask']
print(masks.shape)
plt.figure(figsize = (8,8))
plt.imshow(masks) 
plt.title("Landslide" ,fontdict={'fontsize': 20})
# Out:
# <KeysViewHDF5 ['mask']>
# (128, 128)
# Text(0.5, 1.0, 'Landslide')

# %%
for fichero_t in glob.glob(train_folder + "\\*.h5"):
    f_name = os.path.basename(fichero_t)
    f_name = f_name.replace("image", "mask")
    fichero_m = os.path.join(mask_folder, f_name)
    if (os.path.exists(fichero_m)):
        mask_imagen = h5py.File(fichero_m, 'r')
        masks = mask_imagen['mask']
        l = np.count_nonzero(masks)
        if l == 0: continue
        masks_array = np.ma.array(masks)
        train_imagen = h5py.File(fichero_t, 'r')
        imagen = train_imagen['img']
        num_bandas = imagen.shape[2]
        for i in range(num_bandas):
            banda = imagen[:, :, i]
            banda_tot = np.ma.array(banda)
            if (np.isnan(banda_tot).any()):
                print(fichero_t)
            banda_img = np.ma.masked_where(masks_array >= True, banda)
            banda_masks = np.ma.masked_where(masks_array < True, banda)
            indice = len(da_landslide)
            da_landslide.loc[indice, ["imagen"]] = f_name
            da_landslide.loc[indice, ["banda"]] = bandas[i]
            da_landslide.loc[indice, ["min_m"]] = banda_masks.min()
            da_landslide.loc[indice, ["max_m"]] = banda_masks.max()
            da_landslide.loc[indice, ["min_i"]] = banda_img.min()
            da_landslide.loc[indice, ["max_i"]] = banda_img.max()
            da_landslide.loc[indice, ["mean_m"]] = banda_masks.mean()
            da_landslide.loc[indice, ["mean_i"]] = banda_img.mean()
            da_landslide.loc[indice, ["std_m"]] = banda_masks.std()
            da_landslide.loc[indice, ["std_i"]] = banda_img.std()
            da_landslide.loc[indice, ["min"]] = banda_tot.min()
            da_landslide.loc[indice, ["max"]] = banda_tot.max()
            da_landslide.loc[indice, ["std"]] = banda_tot.std()
            da_landslide.loc[indice, ["mean"]] = banda_tot.mean()

# %%
for i in range(14):
    da_landslide_banda = da_landslide[da_landslide['banda']==bandas[i]]
    fig = plt.figure(figsize=(16,8))
    #da_landslide_banda.plot.hist(subplots=True, layout=(4,1))
    ax = fig.add_subplot(111)
    df = pd.DataFrame(da_landslide_banda[["min_m","max_m","mean_m","min_i","max_i","mean_i"]])
    df.plot.hist(ax=ax, subplots=True,  bins=50 , layout=(2,3), title = bandas[i]) 
    #plt.suptitle(bandas[i])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-38-f774d788e398> in <module>
#       5     ax = fig.add_subplot(111)
#       6     df = pd.DataFrame(da_landslide_banda[["min_m","max_m","mean_m","min_i","max_i","mean_i"]])
# ----> 7     df.plot.hist(ax=ax, subplots=True,  bins=50 , layout=(2,3), title = bandas[i])
#       8     #plt.suptitle(bandas[i])
#
# ~\Anaconda3\envs\capstone\lib\site-packages\pandas\plotting\_core.py in hist(self, by, bins, **kwargs)
#    1178             >>> ax = df.plot.hist(bins=12, alpha=0.5)
#    1179         """
# -> 1180         return self(kind="hist", by=by, bins=bins, **kwargs)
#    1181
#    1182     def kde(self, bw_method=None, ind=None, **kwargs):
#
# ~\Anaconda3\envs\capstone\lib\site-packages\pandas\plotting\_core.py in __call__(self, *args, **kwargs)
#     845                     data.columns = label_name
#     846
# --> 847         return plot_backend.plot(data, kind=kind, **kwargs)
#     848
#     849     __call__.__doc__ = __doc__
#
# ~\Anaconda3\envs\capstone\lib\site-packages\pandas\plotting\_matplotlib\__init__.py in plot(data, kind, **kwargs)
#      59             kwargs["ax"] = getattr(ax, "left_ax", ax)
#      60     plot_obj = PLOT_CLASSES[kind](data, **kwargs)
# ---> 61     plot_obj.generate()
#      62     plot_obj.draw()
#      63     return plot_obj.result
#
# ~\Anaconda3\envs\capstone\lib\site-packages\pandas\plotting\_matplotlib\core.py in generate(self)
#     259     def generate(self):
#     260         self._args_adjust()
# --> 261         self._compute_plot_data()
#     262         self._setup_subplots()
#     263         self._make_plot()
#
# ~\Anaconda3\envs\capstone\lib\site-packages\pandas\plotting\_matplotlib\core.py in _compute_plot_data(self)
#     408         # no non-numeric frames or series allowed
#     409         if is_empty:
# --> 410             raise TypeError("no numeric data to plot")
#     411
#     412         # GH25587: cast ExtensionArray of pandas (IntegerArray, etc.) to
#
# TypeError: no numeric data to plot

# %%
aggr_landslide = da_landslide.groupby('banda').agg(MIN_V=('min','min'), MAX_V=('max','max')).reset_index()

# %%
aggr_landslide.head(10)
# Out:
#   banda  MIN_V      MAX_V
# 0    B1    0.0   2.092979
# 1   B10    0.0  21.441501
# 2   B11    0.0   4.998279
# 3   B12    0.0  12.586940
# 4   B13    0.0   4.040945
# 5   B14    0.0   5.121427
# 6    B2    0.0  10.713874
# 7    B3    0.0  16.856684
# 8    B4    0.0  26.320111
# 9    B5    0.0   9.972776

# %%
for fichero_t in glob.glob(train_folder + "\\*.h5"):
    f_name = os.path.basename(fichero_t)
    nueva_imagen =  np.zeros((128, 128, 14))
    l = np.count_nonzero(masks)
    if l == 0: continue
    train_imagen = h5py.File(fichero_t, 'r')
    imagen = train_imagen['img']
    num_bandas = imagen.shape[2]
    for i in range(num_bandas):
        banda = imagen[:, :, i]
        indice = len(da_landslide)
        banda_tot = np.ma.array(banda)
        banda_reclass = (banda_tot - aggr_landslide.loc[i,'MIN_V'])/(aggr_landslide.loc[i,'MAX_V'] - aggr_landslide.loc[i,'MIN_V'])
        nueva_imagen[:,:,i]= banda_reclass
    nuevo_fichero = os.path.join(edt_folder, f_name) 
    if (os.path.exists(nuevo_fichero)):
        os.remove(nuevo_fichero)
    hf = h5py.File(nuevo_fichero , 'w')
    hf.create_dataset('img', data= nueva_imagen)
    hf.close
# Out:
# C:\temp\UOC\TrainData\edt\image_1.h5
# C:\temp\UOC\TrainData\edt\image_10.h5
# C:\temp\UOC\TrainData\edt\image_100.h5
# C:\temp\UOC\TrainData\edt\image_1000.h5
# C:\temp\UOC\TrainData\edt\image_1001.h5
# C:\temp\UOC\TrainData\edt\image_1002.h5
# C:\temp\UOC\TrainData\edt\image_1003.h5
# C:\temp\UOC\TrainData\edt\image_1004.h5
# C:\temp\UOC\TrainData\edt\image_1005.h5
# C:\temp\UOC\TrainData\edt\image_1006.h5
# C:\temp\UOC\TrainData\edt\image_1007.h5
# C:\temp\UOC\TrainData\edt\image_1008.h5
# C:\temp\UOC\TrainData\edt\image_1009.h5
# C:\temp\UOC\TrainData\edt\image_101.h5
# C:\temp\UOC\TrainData\edt\image_1010.h5
# C:\temp\UOC\TrainData\edt\image_1011.h5
# C:\temp\UOC\TrainData\edt\image_1012.h5
# C:\temp\UOC\TrainData\edt\image_1013.h5
# C:\temp\UOC\TrainData\edt\image_1014.h5
# C:\temp\UOC\TrainData\edt\image_1015.h5
# C:\temp\UOC\TrainData\edt\image_1016.h5
# C:\temp\UOC\TrainData\edt\image_1017.h5
# C:\temp\UOC\TrainData\edt\image_1018.h5
# C:\temp\UOC\TrainData\edt\image_1019.h5
# C:\temp\UOC\TrainData\edt\image_102.h5
# C:\temp\UOC\TrainData\edt\image_1020.h5
# C:\temp\UOC\TrainData\edt\image_1021.h5
# C:\temp\UOC\TrainData\edt\image_1022.h5
# C:\temp\UOC\TrainData\edt\image_1023.h5
# C:\temp\UOC\TrainData\edt\image_1024.h5
# C:\temp\UOC\TrainData\edt\image_1025.h5
# C:\temp\UOC\TrainData\edt\image_1026.h5
# C:\temp\UOC\TrainData\edt\image_1027.h5
# C:\temp\UOC\TrainData\edt\image_1028.h5
# C:\temp\UOC\TrainData\edt\image_1029.h5
# C:\temp\UOC\TrainData\edt\image_103.h5
# C:\temp\UOC\TrainData\edt\image_1030.h5
# C:\temp\UOC\TrainData\edt\image_1031.h5
# C:\temp\UOC\TrainData\edt\image_1032.h5
# C:\temp\UOC\TrainData\edt\image_1033.h5
# C:\temp\UOC\TrainData\edt\image_1034.h5
# C:\temp\UOC\TrainData\edt\image_1035.h5
# C:\temp\UOC\TrainData\edt\image_1036.h5
# C:\temp\UOC\TrainData\edt\image_1037.h5
# C:\temp\UOC\TrainData\edt\image_1038.h5
# C:\temp\UOC\TrainData\edt\image_1039.h5
# C:\temp\UOC\TrainData\edt\image_104.h5
# C:\temp\UOC\TrainData\edt\image_1040.h5
# C:\temp\UOC\TrainData\edt\image_1041.h5
# C:\temp\UOC\TrainData\edt\image_1042.h5
# C:\temp\UOC\TrainData\edt\image_1043.h5
# C:\temp\UOC\TrainData\edt\image_1044.h5
# C:\temp\UOC\TrainData\edt\image_1045.h5
# C:\temp\UOC\TrainData\edt\image_1046.h5
# C:\temp\UOC\TrainData\edt\image_1047.h5
# C:\temp\UOC\TrainData\edt\image_1048.h5
# C:\temp\UOC\TrainData\edt\image_1049.h5
# C:\temp\UOC\TrainData\edt\image_105.h5
# C:\temp\UOC\TrainData\edt\image_1050.h5
# C:\temp\UOC\TrainData\edt\image_1051.h5
# C:\temp\UOC\TrainData\edt\image_1052.h5
# C:\temp\UOC\TrainData\edt\image_1053.h5
# C:\temp\UOC\TrainData\edt\image_1054.h5
# C:\temp\UOC\TrainData\edt\image_1055.h5
# C:\temp\UOC\TrainData\edt\image_1056.h5
# C:\temp\UOC\TrainData\edt\image_1057.h5
# C:\temp\UOC\TrainData\edt\image_1058.h5
# C:\temp\UOC\TrainData\edt\image_1059.h5
# C:\temp\UOC\TrainData\edt\image_106.h5
# C:\temp\UOC\TrainData\edt\image_1060.h5
# C:\temp\UOC\TrainData\edt\image_1061.h5
# C:\temp\UOC\TrainData\edt\image_1062.h5
# C:\temp\UOC\TrainData\edt\image_1063.h5
# C:\temp\UOC\TrainData\edt\image_1064.h5
# C:\temp\UOC\TrainData\edt\image_1065.h5
# C:\temp\UOC\TrainData\edt\image_1066.h5
# C:\temp\UOC\TrainData\edt\image_1067.h5
# C:\temp\UOC\TrainData\edt\image_1068.h5
# C:\temp\UOC\TrainData\edt\image_1069.h5
# C:\temp\UOC\TrainData\edt\image_107.h5
# C:\temp\UOC\TrainData\edt\image_1070.h5
# C:\temp\UOC\TrainData\edt\image_1071.h5
# C:\temp\UOC\TrainData\edt\image_1072.h5
# C:\temp\UOC\TrainData\edt\image_1073.h5
# C:\temp\UOC\TrainData\edt\image_1074.h5
# C:\temp\UOC\TrainData\edt\image_1075.h5
# C:\temp\UOC\TrainData\edt\image_1076.h5
# C:\temp\UOC\TrainData\edt\image_1077.h5
# C:\temp\UOC\TrainData\edt\image_1078.h5
# C:\temp\UOC\TrainData\edt\image_1079.h5
# C:\temp\UOC\TrainData\edt\image_108.h5
# C:\temp\UOC\TrainData\edt\image_1080.h5
# C:\temp\UOC\TrainData\edt\image_1081.h5
# C:\temp\UOC\TrainData\edt\image_1082.h5
# C:\temp\UOC\TrainData\edt\image_1083.h5
# C:\temp\UOC\TrainData\edt\image_1084.h5
# C:\temp\UOC\TrainData\edt\image_1085.h5
# C:\temp\UOC\TrainData\edt\image_1086.h5
# C:\temp\UOC\TrainData\edt\image_1087.h5
# C:\temp\UOC\TrainData\edt\image_1088.h5
# C:\temp\UOC\TrainData\edt\image_1089.h5
# C:\temp\UOC\TrainData\edt\image_109.h5
# C:\temp\UOC\TrainData\edt\image_1090.h5
# C:\temp\UOC\TrainData\edt\image_1091.h5
# C:\temp\UOC\TrainData\edt\image_1092.h5
# C:\temp\UOC\TrainData\edt\image_1093.h5
# C:\temp\UOC\TrainData\edt\image_1094.h5
# C:\temp\UOC\TrainData\edt\image_1095.h5
# C:\temp\UOC\TrainData\edt\image_1096.h5
# C:\temp\UOC\TrainData\edt\image_1097.h5
# C:\temp\UOC\TrainData\edt\image_1098.h5
# C:\temp\UOC\TrainData\edt\image_1099.h5
# C:\temp\UOC\TrainData\edt\image_11.h5
# C:\temp\UOC\TrainData\edt\image_110.h5
# C:\temp\UOC\TrainData\edt\image_1100.h5
# C:\temp\UOC\TrainData\edt\image_1101.h5
# C:\temp\UOC\TrainData\edt\image_1102.h5
# C:\temp\UOC\TrainData\edt\image_1103.h5
# C:\temp\UOC\TrainData\edt\image_1104.h5
# C:\temp\UOC\TrainData\edt\image_1105.h5
# C:\temp\UOC\TrainData\edt\image_1106.h5
# C:\temp\UOC\TrainData\edt\image_1107.h5
# C:\temp\UOC\TrainData\edt\image_1108.h5
# C:\temp\UOC\TrainData\edt\image_1109.h5
# C:\temp\UOC\TrainData\edt\image_111.h5
# C:\temp\UOC\TrainData\edt\image_1110.h5
# C:\temp\UOC\TrainData\edt\image_1111.h5
# C:\temp\UOC\TrainData\edt\image_1112.h5
# C:\temp\UOC\TrainData\edt\image_1113.h5
# C:\temp\UOC\TrainData\edt\image_1114.h5
# C:\temp\UOC\TrainData\edt\image_1115.h5
# C:\temp\UOC\TrainData\edt\image_1116.h5
# C:\temp\UOC\TrainData\edt\image_1117.h5
# C:\temp\UOC\TrainData\edt\image_1118.h5
# C:\temp\UOC\TrainData\edt\image_1119.h5
# C:\temp\UOC\TrainData\edt\image_112.h5
# C:\temp\UOC\TrainData\edt\image_1120.h5
# C:\temp\UOC\TrainData\edt\image_1121.h5
# C:\temp\UOC\TrainData\edt\image_1122.h5
# C:\temp\UOC\TrainData\edt\image_1123.h5
# C:\temp\UOC\TrainData\edt\image_1124.h5
# C:\temp\UOC\TrainData\edt\image_1125.h5
# C:\temp\UOC\TrainData\edt\image_1126.h5
# C:\temp\UOC\TrainData\edt\image_1127.h5
# C:\temp\UOC\TrainData\edt\image_1128.h5
# C:\temp\UOC\TrainData\edt\image_1129.h5
# C:\temp\UOC\TrainData\edt\image_113.h5
# C:\temp\UOC\TrainData\edt\image_1130.h5
# C:\temp\UOC\TrainData\edt\image_1131.h5
# C:\temp\UOC\TrainData\edt\image_1132.h5
# C:\temp\UOC\TrainData\edt\image_1133.h5
# C:\temp\UOC\TrainData\edt\image_1134.h5
# C:\temp\UOC\TrainData\edt\image_1135.h5
# C:\temp\UOC\TrainData\edt\image_1136.h5
# C:\temp\UOC\TrainData\edt\image_1137.h5
# C:\temp\UOC\TrainData\edt\image_1138.h5
# C:\temp\UOC\TrainData\edt\image_1139.h5
# C:\temp\UOC\TrainData\edt\image_114.h5
# C:\temp\UOC\TrainData\edt\image_1140.h5
# C:\temp\UOC\TrainData\edt\image_1141.h5
# C:\temp\UOC\TrainData\edt\image_1142.h5
# C:\temp\UOC\TrainData\edt\image_1143.h5
# C:\temp\UOC\TrainData\edt\image_1144.h5
# C:\temp\UOC\TrainData\edt\image_1145.h5
# C:\temp\UOC\TrainData\edt\image_1146.h5
# C:\temp\UOC\TrainData\edt\image_1147.h5
# C:\temp\UOC\TrainData\edt\image_1148.h5
# C:\temp\UOC\TrainData\edt\image_1149.h5
# C:\temp\UOC\TrainData\edt\image_115.h5
# C:\temp\UOC\TrainData\edt\image_1150.h5
# C:\temp\UOC\TrainData\edt\image_1151.h5
# C:\temp\UOC\TrainData\edt\image_1152.h5
# C:\temp\UOC\TrainData\edt\image_1153.h5
# C:\temp\UOC\TrainData\edt\image_1154.h5
# C:\temp\UOC\TrainData\edt\image_1155.h5
# C:\temp\UOC\TrainData\edt\image_1156.h5
# C:\temp\UOC\TrainData\edt\image_1157.h5
# C:\temp\UOC\TrainData\edt\image_1158.h5
# C:\temp\UOC\TrainData\edt\image_1159.h5
# C:\temp\UOC\TrainData\edt\image_116.h5
# C:\temp\UOC\TrainData\edt\image_1160.h5
# C:\temp\UOC\TrainData\edt\image_1161.h5
# C:\temp\UOC\TrainData\edt\image_1162.h5
# C:\temp\UOC\TrainData\edt\image_1163.h5
# C:\temp\UOC\TrainData\edt\image_1164.h5
# C:\temp\UOC\TrainData\edt\image_1165.h5
# C:\temp\UOC\TrainData\edt\image_1166.h5
# C:\temp\UOC\TrainData\edt\image_1167.h5
# C:\temp\UOC\TrainData\edt\image_1168.h5
# C:\temp\UOC\TrainData\edt\image_1169.h5
# C:\temp\UOC\TrainData\edt\image_117.h5
# C:\temp\UOC\TrainData\edt\image_1170.h5
# C:\temp\UOC\TrainData\edt\image_1171.h5
# C:\temp\UOC\TrainData\edt\image_1172.h5
# C:\temp\UOC\TrainData\edt\image_1173.h5
# C:\temp\UOC\TrainData\edt\image_1174.h5
# C:\temp\UOC\TrainData\edt\image_1175.h5
# C:\temp\UOC\TrainData\edt\image_1176.h5
# C:\temp\UOC\TrainData\edt\image_1177.h5
# C:\temp\UOC\TrainData\edt\image_1178.h5
# C:\temp\UOC\TrainData\edt\image_1179.h5
# C:\temp\UOC\TrainData\edt\image_118.h5
# C:\temp\UOC\TrainData\edt\image_1180.h5
# C:\temp\UOC\TrainData\edt\image_1181.h5
# C:\temp\UOC\TrainData\edt\image_1182.h5
# C:\temp\UOC\TrainData\edt\image_1183.h5
# C:\temp\UOC\TrainData\edt\image_1184.h5
# C:\temp\UOC\TrainData\edt\image_1185.h5
# C:\temp\UOC\TrainData\edt\image_1186.h5
# C:\temp\UOC\TrainData\edt\image_1187.h5
# C:\temp\UOC\TrainData\edt\image_1188.h5
# C:\temp\UOC\TrainData\edt\image_1189.h5
# C:\temp\UOC\TrainData\edt\image_119.h5
# C:\temp\UOC\TrainData\edt\image_1190.h5
# C:\temp\UOC\TrainData\edt\image_1191.h5
# C:\temp\UOC\TrainData\edt\image_1192.h5
# C:\temp\UOC\TrainData\edt\image_1193.h5
# C:\temp\UOC\TrainData\edt\image_1194.h5
# C:\temp\UOC\TrainData\edt\image_1195.h5
# C:\temp\UOC\TrainData\edt\image_1196.h5
# C:\temp\UOC\TrainData\edt\image_1197.h5
# C:\temp\UOC\TrainData\edt\image_1198.h5
# C:\temp\UOC\TrainData\edt\image_1199.h5
# C:\temp\UOC\TrainData\edt\image_12.h5
# C:\temp\UOC\TrainData\edt\image_120.h5
# C:\temp\UOC\TrainData\edt\image_1200.h5
# C:\temp\UOC\TrainData\edt\image_1201.h5
# C:\temp\UOC\TrainData\edt\image_1202.h5
# C:\temp\UOC\TrainData\edt\image_1203.h5
# C:\temp\UOC\TrainData\edt\image_1204.h5
# C:\temp\UOC\TrainData\edt\image_1205.h5
# C:\temp\UOC\TrainData\edt\image_1206.h5
# C:\temp\UOC\TrainData\edt\image_1207.h5
# C:\temp\UOC\TrainData\edt\image_1208.h5
# C:\temp\UOC\TrainData\edt\image_1209.h5
# C:\temp\UOC\TrainData\edt\image_121.h5
# C:\temp\UOC\TrainData\edt\image_1210.h5
# C:\temp\UOC\TrainData\edt\image_1211.h5
# C:\temp\UOC\TrainData\edt\image_1212.h5
# C:\temp\UOC\TrainData\edt\image_1213.h5
# C:\temp\UOC\TrainData\edt\image_1214.h5
# C:\temp\UOC\TrainData\edt\image_1215.h5
# C:\temp\UOC\TrainData\edt\image_1216.h5
# C:\temp\UOC\TrainData\edt\image_1217.h5
# C:\temp\UOC\TrainData\edt\image_1218.h5
# C:\temp\UOC\TrainData\edt\image_1219.h5
# C:\temp\UOC\TrainData\edt\image_122.h5
# C:\temp\UOC\TrainData\edt\image_1220.h5
# C:\temp\UOC\TrainData\edt\image_1221.h5
# C:\temp\UOC\TrainData\edt\image_1222.h5
# C:\temp\UOC\TrainData\edt\image_1223.h5
# C:\temp\UOC\TrainData\edt\image_1224.h5
# C:\temp\UOC\TrainData\edt\image_1225.h5
# C:\temp\UOC\TrainData\edt\image_1226.h5
# C:\temp\UOC\TrainData\edt\image_1227.h5
# C:\temp\UOC\TrainData\edt\image_1228.h5
# C:\temp\UOC\TrainData\edt\image_1229.h5
# C:\temp\UOC\TrainData\edt\image_123.h5
# C:\temp\UOC\TrainData\edt\image_1230.h5
# C:\temp\UOC\TrainData\edt\image_1231.h5
# C:\temp\UOC\TrainData\edt\image_1232.h5
# C:\temp\UOC\TrainData\edt\image_1233.h5
# C:\temp\UOC\TrainData\edt\image_1234.h5
# C:\temp\UOC\TrainData\edt\image_1235.h5
# C:\temp\UOC\TrainData\edt\image_1236.h5
# C:\temp\UOC\TrainData\edt\image_1237.h5
# C:\temp\UOC\TrainData\edt\image_1238.h5
# C:\temp\UOC\TrainData\edt\image_1239.h5
# C:\temp\UOC\TrainData\edt\image_124.h5
# C:\temp\UOC\TrainData\edt\image_1240.h5
# C:\temp\UOC\TrainData\edt\image_1241.h5
# C:\temp\UOC\TrainData\edt\image_1242.h5
# C:\temp\UOC\TrainData\edt\image_1243.h5
# C:\temp\UOC\TrainData\edt\image_1244.h5
# C:\temp\UOC\TrainData\edt\image_1245.h5
# C:\temp\UOC\TrainData\edt\image_1246.h5
# C:\temp\UOC\TrainData\edt\image_1247.h5
# C:\temp\UOC\TrainData\edt\image_1248.h5
# C:\temp\UOC\TrainData\edt\image_1249.h5
# C:\temp\UOC\TrainData\edt\image_125.h5
# C:\temp\UOC\TrainData\edt\image_1250.h5
# C:\temp\UOC\TrainData\edt\image_1251.h5
# C:\temp\UOC\TrainData\edt\image_1252.h5
# C:\temp\UOC\TrainData\edt\image_1253.h5
# C:\temp\UOC\TrainData\edt\image_1254.h5
# C:\temp\UOC\TrainData\edt\image_1255.h5
# C:\temp\UOC\TrainData\edt\image_1256.h5
# C:\temp\UOC\TrainData\edt\image_1257.h5
# C:\temp\UOC\TrainData\edt\image_1258.h5
# C:\temp\UOC\TrainData\edt\image_1259.h5
# C:\temp\UOC\TrainData\edt\image_126.h5
# C:\temp\UOC\TrainData\edt\image_1260.h5
# C:\temp\UOC\TrainData\edt\image_1261.h5
# C:\temp\UOC\TrainData\edt\image_1262.h5
# C:\temp\UOC\TrainData\edt\image_1263.h5
# C:\temp\UOC\TrainData\edt\image_1264.h5
# C:\temp\UOC\TrainData\edt\image_1265.h5
# C:\temp\UOC\TrainData\edt\image_1266.h5
# C:\temp\UOC\TrainData\edt\image_1267.h5
# C:\temp\UOC\TrainData\edt\image_1268.h5
# C:\temp\UOC\TrainData\edt\image_1269.h5
# C:\temp\UOC\TrainData\edt\image_127.h5
# C:\temp\UOC\TrainData\edt\image_1270.h5
# C:\temp\UOC\TrainData\edt\image_1271.h5
# C:\temp\UOC\TrainData\edt\image_1272.h5
# C:\temp\UOC\TrainData\edt\image_1273.h5
# C:\temp\UOC\TrainData\edt\image_1274.h5
# C:\temp\UOC\TrainData\edt\image_1275.h5
# C:\temp\UOC\TrainData\edt\image_1276.h5
# C:\temp\UOC\TrainData\edt\image_1277.h5
# C:\temp\UOC\TrainData\edt\image_1278.h5
# C:\temp\UOC\TrainData\edt\image_1279.h5
# C:\temp\UOC\TrainData\edt\image_128.h5
# C:\temp\UOC\TrainData\edt\image_1280.h5
# C:\temp\UOC\TrainData\edt\image_1281.h5
# C:\temp\UOC\TrainData\edt\image_1282.h5
# C:\temp\UOC\TrainData\edt\image_1283.h5
# C:\temp\UOC\TrainData\edt\image_1284.h5
# C:\temp\UOC\TrainData\edt\image_1285.h5
# C:\temp\UOC\TrainData\edt\image_1286.h5
# C:\temp\UOC\TrainData\edt\image_1287.h5
# C:\temp\UOC\TrainData\edt\image_1288.h5
# C:\temp\UOC\TrainData\edt\image_1289.h5
# C:\temp\UOC\TrainData\edt\image_129.h5
# C:\temp\UOC\TrainData\edt\image_1290.h5
# C:\temp\UOC\TrainData\edt\image_1291.h5
# C:\temp\UOC\TrainData\edt\image_1292.h5
# C:\temp\UOC\TrainData\edt\image_1293.h5
# C:\temp\UOC\TrainData\edt\image_1294.h5
# C:\temp\UOC\TrainData\edt\image_1295.h5
# C:\temp\UOC\TrainData\edt\image_1296.h5
# C:\temp\UOC\TrainData\edt\image_1297.h5
# C:\temp\UOC\TrainData\edt\image_1298.h5
# C:\temp\UOC\TrainData\edt\image_1299.h5
# C:\temp\UOC\TrainData\edt\image_13.h5
# C:\temp\UOC\TrainData\edt\image_130.h5
# C:\temp\UOC\TrainData\edt\image_1300.h5
# C:\temp\UOC\TrainData\edt\image_1301.h5
# C:\temp\UOC\TrainData\edt\image_1302.h5
# C:\temp\UOC\TrainData\edt\image_1303.h5
# C:\temp\UOC\TrainData\edt\image_1304.h5
# C:\temp\UOC\TrainData\edt\image_1305.h5
# C:\temp\UOC\TrainData\edt\image_1306.h5
# C:\temp\UOC\TrainData\edt\image_1307.h5
# C:\temp\UOC\TrainData\edt\image_1308.h5
# C:\temp\UOC\TrainData\edt\image_1309.h5
# C:\temp\UOC\TrainData\edt\image_131.h5
# C:\temp\UOC\TrainData\edt\image_1310.h5
# C:\temp\UOC\TrainData\edt\image_1311.h5
# C:\temp\UOC\TrainData\edt\image_1312.h5
# C:\temp\UOC\TrainData\edt\image_1313.h5
# C:\temp\UOC\TrainData\edt\image_1314.h5
# C:\temp\UOC\TrainData\edt\image_1315.h5
# C:\temp\UOC\TrainData\edt\image_1316.h5
# C:\temp\UOC\TrainData\edt\image_1317.h5
# C:\temp\UOC\TrainData\edt\image_1318.h5
# C:\temp\UOC\TrainData\edt\image_1319.h5
# C:\temp\UOC\TrainData\edt\image_132.h5
# C:\temp\UOC\TrainData\edt\image_1320.h5
# C:\temp\UOC\TrainData\edt\image_1321.h5
# C:\temp\UOC\TrainData\edt\image_1322.h5
# C:\temp\UOC\TrainData\edt\image_1323.h5
# C:\temp\UOC\TrainData\edt\image_1324.h5
# C:\temp\UOC\TrainData\edt\image_1325.h5
# C:\temp\UOC\TrainData\edt\image_1326.h5
# C:\temp\UOC\TrainData\edt\image_1327.h5
# C:\temp\UOC\TrainData\edt\image_1328.h5
# C:\temp\UOC\TrainData\edt\image_1329.h5
# C:\temp\UOC\TrainData\edt\image_133.h5
# C:\temp\UOC\TrainData\edt\image_1330.h5
# C:\temp\UOC\TrainData\edt\image_1331.h5
# C:\temp\UOC\TrainData\edt\image_1332.h5
# C:\temp\UOC\TrainData\edt\image_1333.h5
# C:\temp\UOC\TrainData\edt\image_1334.h5
# C:\temp\UOC\TrainData\edt\image_1335.h5
# C:\temp\UOC\TrainData\edt\image_1336.h5
# C:\temp\UOC\TrainData\edt\image_1337.h5
# C:\temp\UOC\TrainData\edt\image_1338.h5
# C:\temp\UOC\TrainData\edt\image_1339.h5
# C:\temp\UOC\TrainData\edt\image_134.h5
# C:\temp\UOC\TrainData\edt\image_1340.h5
# C:\temp\UOC\TrainData\edt\image_1341.h5
# C:\temp\UOC\TrainData\edt\image_1342.h5
# C:\temp\UOC\TrainData\edt\image_1343.h5
# C:\temp\UOC\TrainData\edt\image_1344.h5
# C:\temp\UOC\TrainData\edt\image_1345.h5
# C:\temp\UOC\TrainData\edt\image_1346.h5
# C:\temp\UOC\TrainData\edt\image_1347.h5
# C:\temp\UOC\TrainData\edt\image_1348.h5
# C:\temp\UOC\TrainData\edt\image_1349.h5
# C:\temp\UOC\TrainData\edt\image_135.h5
# C:\temp\UOC\TrainData\edt\image_1350.h5
# C:\temp\UOC\TrainData\edt\image_1351.h5
# C:\temp\UOC\TrainData\edt\image_1352.h5
# C:\temp\UOC\TrainData\edt\image_1353.h5
# C:\temp\UOC\TrainData\edt\image_1354.h5
# C:\temp\UOC\TrainData\edt\image_1355.h5
# C:\temp\UOC\TrainData\edt\image_1356.h5
# C:\temp\UOC\TrainData\edt\image_1357.h5
# C:\temp\UOC\TrainData\edt\image_1358.h5
# C:\temp\UOC\TrainData\edt\image_1359.h5
# C:\temp\UOC\TrainData\edt\image_136.h5
# C:\temp\UOC\TrainData\edt\image_1360.h5
# C:\temp\UOC\TrainData\edt\image_1361.h5
# C:\temp\UOC\TrainData\edt\image_1362.h5
# C:\temp\UOC\TrainData\edt\image_1363.h5
# C:\temp\UOC\TrainData\edt\image_1364.h5
# C:\temp\UOC\TrainData\edt\image_1365.h5
# C:\temp\UOC\TrainData\edt\image_1366.h5
# C:\temp\UOC\TrainData\edt\image_1367.h5
# C:\temp\UOC\TrainData\edt\image_1368.h5
# C:\temp\UOC\TrainData\edt\image_1369.h5
# C:\temp\UOC\TrainData\edt\image_137.h5
# C:\temp\UOC\TrainData\edt\image_1370.h5
# C:\temp\UOC\TrainData\edt\image_1371.h5
# C:\temp\UOC\TrainData\edt\image_1372.h5
# C:\temp\UOC\TrainData\edt\image_1373.h5
# C:\temp\UOC\TrainData\edt\image_1374.h5
# C:\temp\UOC\TrainData\edt\image_1375.h5
# C:\temp\UOC\TrainData\edt\image_1376.h5
# C:\temp\UOC\TrainData\edt\image_1377.h5
# C:\temp\UOC\TrainData\edt\image_1378.h5
# C:\temp\UOC\TrainData\edt\image_1379.h5
# C:\temp\UOC\TrainData\edt\image_138.h5
# C:\temp\UOC\TrainData\edt\image_1380.h5
# C:\temp\UOC\TrainData\edt\image_1381.h5
# C:\temp\UOC\TrainData\edt\image_1382.h5
# C:\temp\UOC\TrainData\edt\image_1383.h5
# C:\temp\UOC\TrainData\edt\image_1384.h5
# C:\temp\UOC\TrainData\edt\image_1385.h5
# C:\temp\UOC\TrainData\edt\image_1386.h5
# C:\temp\UOC\TrainData\edt\image_1387.h5
# C:\temp\UOC\TrainData\edt\image_1388.h5
# C:\temp\UOC\TrainData\edt\image_1389.h5
# C:\temp\UOC\TrainData\edt\image_139.h5
# C:\temp\UOC\TrainData\edt\image_1390.h5
# C:\temp\UOC\TrainData\edt\image_1391.h5
# C:\temp\UOC\TrainData\edt\image_1392.h5
# C:\temp\UOC\TrainData\edt\image_1393.h5
# C:\temp\UOC\TrainData\edt\image_1394.h5
# C:\temp\UOC\TrainData\edt\image_1395.h5
# C:\temp\UOC\TrainData\edt\image_1396.h5
# C:\temp\UOC\TrainData\edt\image_1397.h5
# C:\temp\UOC\TrainData\edt\image_1398.h5
# C:\temp\UOC\TrainData\edt\image_1399.h5
# C:\temp\UOC\TrainData\edt\image_14.h5
# C:\temp\UOC\TrainData\edt\image_140.h5
# C:\temp\UOC\TrainData\edt\image_1400.h5
# C:\temp\UOC\TrainData\edt\image_1401.h5
# C:\temp\UOC\TrainData\edt\image_1402.h5
# C:\temp\UOC\TrainData\edt\image_1403.h5
# C:\temp\UOC\TrainData\edt\image_1404.h5
# C:\temp\UOC\TrainData\edt\image_1405.h5
# C:\temp\UOC\TrainData\edt\image_1406.h5
# C:\temp\UOC\TrainData\edt\image_1407.h5
# C:\temp\UOC\TrainData\edt\image_1408.h5
# C:\temp\UOC\TrainData\edt\image_1409.h5
# C:\temp\UOC\TrainData\edt\image_141.h5
# C:\temp\UOC\TrainData\edt\image_1410.h5
# C:\temp\UOC\TrainData\edt\image_1411.h5
# C:\temp\UOC\TrainData\edt\image_1412.h5
# C:\temp\UOC\TrainData\edt\image_1413.h5
# C:\temp\UOC\TrainData\edt\image_1414.h5
# C:\temp\UOC\TrainData\edt\image_1415.h5
# C:\temp\UOC\TrainData\edt\image_1416.h5
# C:\temp\UOC\TrainData\edt\image_1417.h5
# C:\temp\UOC\TrainData\edt\image_1418.h5
# C:\temp\UOC\TrainData\edt\image_1419.h5
# C:\temp\UOC\TrainData\edt\image_142.h5
# C:\temp\UOC\TrainData\edt\image_1420.h5
# C:\temp\UOC\TrainData\edt\image_1421.h5
# C:\temp\UOC\TrainData\edt\image_1422.h5
# C:\temp\UOC\TrainData\edt\image_1423.h5
# C:\temp\UOC\TrainData\edt\image_1424.h5
# C:\temp\UOC\TrainData\edt\image_1425.h5
# C:\temp\UOC\TrainData\edt\image_1426.h5
# C:\temp\UOC\TrainData\edt\image_1427.h5
# C:\temp\UOC\TrainData\edt\image_1428.h5
# C:\temp\UOC\TrainData\edt\image_1429.h5
# C:\temp\UOC\TrainData\edt\image_143.h5
# C:\temp\UOC\TrainData\edt\image_1430.h5
# C:\temp\UOC\TrainData\edt\image_1431.h5
# C:\temp\UOC\TrainData\edt\image_1432.h5
# C:\temp\UOC\TrainData\edt\image_1433.h5
# C:\temp\UOC\TrainData\edt\image_1434.h5
# C:\temp\UOC\TrainData\edt\image_1435.h5
# C:\temp\UOC\TrainData\edt\image_1436.h5
# C:\temp\UOC\TrainData\edt\image_1437.h5
# C:\temp\UOC\TrainData\edt\image_1438.h5
# C:\temp\UOC\TrainData\edt\image_1439.h5
# C:\temp\UOC\TrainData\edt\image_144.h5
# C:\temp\UOC\TrainData\edt\image_1440.h5
# C:\temp\UOC\TrainData\edt\image_1441.h5
# C:\temp\UOC\TrainData\edt\image_1442.h5
# C:\temp\UOC\TrainData\edt\image_1443.h5
# C:\temp\UOC\TrainData\edt\image_1444.h5
# C:\temp\UOC\TrainData\edt\image_1445.h5
# C:\temp\UOC\TrainData\edt\image_1446.h5
# C:\temp\UOC\TrainData\edt\image_1447.h5
# C:\temp\UOC\TrainData\edt\image_1448.h5
# C:\temp\UOC\TrainData\edt\image_1449.h5
# C:\temp\UOC\TrainData\edt\image_145.h5
# C:\temp\UOC\TrainData\edt\image_1450.h5
# C:\temp\UOC\TrainData\edt\image_1451.h5
# C:\temp\UOC\TrainData\edt\image_1452.h5
# C:\temp\UOC\TrainData\edt\image_1453.h5
# C:\temp\UOC\TrainData\edt\image_1454.h5
# C:\temp\UOC\TrainData\edt\image_1455.h5
# C:\temp\UOC\TrainData\edt\image_1456.h5
# C:\temp\UOC\TrainData\edt\image_1457.h5
# C:\temp\UOC\TrainData\edt\image_1458.h5
# C:\temp\UOC\TrainData\edt\image_1459.h5
# C:\temp\UOC\TrainData\edt\image_146.h5
# C:\temp\UOC\TrainData\edt\image_1460.h5
# C:\temp\UOC\TrainData\edt\image_1461.h5
# C:\temp\UOC\TrainData\edt\image_1462.h5
# C:\temp\UOC\TrainData\edt\image_1463.h5
# C:\temp\UOC\TrainData\edt\image_1464.h5
# C:\temp\UOC\TrainData\edt\image_1465.h5
# C:\temp\UOC\TrainData\edt\image_1466.h5
# C:\temp\UOC\TrainData\edt\image_1467.h5
# C:\temp\UOC\TrainData\edt\image_1468.h5
# C:\temp\UOC\TrainData\edt\image_1469.h5
# C:\temp\UOC\TrainData\edt\image_147.h5
# C:\temp\UOC\TrainData\edt\image_1470.h5
# C:\temp\UOC\TrainData\edt\image_1471.h5
# C:\temp\UOC\TrainData\edt\image_1472.h5
# C:\temp\UOC\TrainData\edt\image_1473.h5
# C:\temp\UOC\TrainData\edt\image_1474.h5
# C:\temp\UOC\TrainData\edt\image_1475.h5
# C:\temp\UOC\TrainData\edt\image_1476.h5
# C:\temp\UOC\TrainData\edt\image_1477.h5
# C:\temp\UOC\TrainData\edt\image_1478.h5
# C:\temp\UOC\TrainData\edt\image_1479.h5
# C:\temp\UOC\TrainData\edt\image_148.h5
# C:\temp\UOC\TrainData\edt\image_1480.h5
# C:\temp\UOC\TrainData\edt\image_1481.h5
# C:\temp\UOC\TrainData\edt\image_1482.h5
# C:\temp\UOC\TrainData\edt\image_1483.h5
# C:\temp\UOC\TrainData\edt\image_1484.h5
# C:\temp\UOC\TrainData\edt\image_1485.h5
# C:\temp\UOC\TrainData\edt\image_1486.h5
# C:\temp\UOC\TrainData\edt\image_1487.h5
# C:\temp\UOC\TrainData\edt\image_1488.h5
# C:\temp\UOC\TrainData\edt\image_1489.h5
# C:\temp\UOC\TrainData\edt\image_149.h5
# C:\temp\UOC\TrainData\edt\image_1490.h5
# C:\temp\UOC\TrainData\edt\image_1491.h5
# C:\temp\UOC\TrainData\edt\image_1492.h5
# C:\temp\UOC\TrainData\edt\image_1493.h5
# C:\temp\UOC\TrainData\edt\image_1494.h5
# C:\temp\UOC\TrainData\edt\image_1495.h5
# C:\temp\UOC\TrainData\edt\image_1496.h5
# C:\temp\UOC\TrainData\edt\image_1497.h5
# C:\temp\UOC\TrainData\edt\image_1498.h5
# C:\temp\UOC\TrainData\edt\image_1499.h5
# C:\temp\UOC\TrainData\edt\image_15.h5
# C:\temp\UOC\TrainData\edt\image_150.h5
# C:\temp\UOC\TrainData\edt\image_1500.h5
# C:\temp\UOC\TrainData\edt\image_1501.h5
# C:\temp\UOC\TrainData\edt\image_1502.h5
# C:\temp\UOC\TrainData\edt\image_1503.h5
# C:\temp\UOC\TrainData\edt\image_1504.h5
# C:\temp\UOC\TrainData\edt\image_1505.h5
# C:\temp\UOC\TrainData\edt\image_1506.h5
# C:\temp\UOC\TrainData\edt\image_1507.h5
# C:\temp\UOC\TrainData\edt\image_1508.h5
# C:\temp\UOC\TrainData\edt\image_1509.h5
# C:\temp\UOC\TrainData\edt\image_151.h5
# C:\temp\UOC\TrainData\edt\image_1510.h5
# C:\temp\UOC\TrainData\edt\image_1511.h5
# C:\temp\UOC\TrainData\edt\image_1512.h5
# C:\temp\UOC\TrainData\edt\image_1513.h5
# C:\temp\UOC\TrainData\edt\image_1514.h5
# C:\temp\UOC\TrainData\edt\image_1515.h5
# C:\temp\UOC\TrainData\edt\image_1516.h5
# C:\temp\UOC\TrainData\edt\image_1517.h5
# C:\temp\UOC\TrainData\edt\image_1518.h5
# C:\temp\UOC\TrainData\edt\image_1519.h5
# C:\temp\UOC\TrainData\edt\image_152.h5
# C:\temp\UOC\TrainData\edt\image_1520.h5
# C:\temp\UOC\TrainData\edt\image_1521.h5
# C:\temp\UOC\TrainData\edt\image_1522.h5
# C:\temp\UOC\TrainData\edt\image_1523.h5
# C:\temp\UOC\TrainData\edt\image_1524.h5
# C:\temp\UOC\TrainData\edt\image_1525.h5
# C:\temp\UOC\TrainData\edt\image_1526.h5
# C:\temp\UOC\TrainData\edt\image_1527.h5
# C:\temp\UOC\TrainData\edt\image_1528.h5
# C:\temp\UOC\TrainData\edt\image_1529.h5
# C:\temp\UOC\TrainData\edt\image_153.h5
# C:\temp\UOC\TrainData\edt\image_1530.h5
# C:\temp\UOC\TrainData\edt\image_1531.h5
# C:\temp\UOC\TrainData\edt\image_1532.h5
# C:\temp\UOC\TrainData\edt\image_1533.h5
# C:\temp\UOC\TrainData\edt\image_1534.h5
# C:\temp\UOC\TrainData\edt\image_1535.h5
# C:\temp\UOC\TrainData\edt\image_1536.h5
# C:\temp\UOC\TrainData\edt\image_1537.h5
# C:\temp\UOC\TrainData\edt\image_1538.h5
# C:\temp\UOC\TrainData\edt\image_1539.h5
# C:\temp\UOC\TrainData\edt\image_154.h5
# C:\temp\UOC\TrainData\edt\image_1540.h5
# C:\temp\UOC\TrainData\edt\image_1541.h5
# C:\temp\UOC\TrainData\edt\image_1542.h5
# C:\temp\UOC\TrainData\edt\image_1543.h5
# C:\temp\UOC\TrainData\edt\image_1544.h5
# C:\temp\UOC\TrainData\edt\image_1545.h5
# C:\temp\UOC\TrainData\edt\image_1546.h5
# C:\temp\UOC\TrainData\edt\image_1547.h5
# C:\temp\UOC\TrainData\edt\image_1548.h5
# C:\temp\UOC\TrainData\edt\image_1549.h5
# C:\temp\UOC\TrainData\edt\image_155.h5
# C:\temp\UOC\TrainData\edt\image_1550.h5
# C:\temp\UOC\TrainData\edt\image_1551.h5
# C:\temp\UOC\TrainData\edt\image_1552.h5
# C:\temp\UOC\TrainData\edt\image_1553.h5
# C:\temp\UOC\TrainData\edt\image_1554.h5
# C:\temp\UOC\TrainData\edt\image_1555.h5
# C:\temp\UOC\TrainData\edt\image_1556.h5
# C:\temp\UOC\TrainData\edt\image_1557.h5
# C:\temp\UOC\TrainData\edt\image_1558.h5
# C:\temp\UOC\TrainData\edt\image_1559.h5
# C:\temp\UOC\TrainData\edt\image_156.h5
# C:\temp\UOC\TrainData\edt\image_1560.h5
# C:\temp\UOC\TrainData\edt\image_1561.h5
# C:\temp\UOC\TrainData\edt\image_1562.h5
# C:\temp\UOC\TrainData\edt\image_1563.h5
# C:\temp\UOC\TrainData\edt\image_1564.h5
# C:\temp\UOC\TrainData\edt\image_1565.h5
# C:\temp\UOC\TrainData\edt\image_1566.h5
# C:\temp\UOC\TrainData\edt\image_1567.h5
# C:\temp\UOC\TrainData\edt\image_1568.h5
# C:\temp\UOC\TrainData\edt\image_1569.h5
# C:\temp\UOC\TrainData\edt\image_157.h5
# C:\temp\UOC\TrainData\edt\image_1570.h5
# C:\temp\UOC\TrainData\edt\image_1571.h5
# C:\temp\UOC\TrainData\edt\image_1572.h5
# C:\temp\UOC\TrainData\edt\image_1573.h5
# C:\temp\UOC\TrainData\edt\image_1574.h5
# C:\temp\UOC\TrainData\edt\image_1575.h5
# C:\temp\UOC\TrainData\edt\image_1576.h5
# C:\temp\UOC\TrainData\edt\image_1577.h5
# C:\temp\UOC\TrainData\edt\image_1578.h5
# C:\temp\UOC\TrainData\edt\image_1579.h5
# C:\temp\UOC\TrainData\edt\image_158.h5
# C:\temp\UOC\TrainData\edt\image_1580.h5
# C:\temp\UOC\TrainData\edt\image_1581.h5
# C:\temp\UOC\TrainData\edt\image_1582.h5
# C:\temp\UOC\TrainData\edt\image_1583.h5
# C:\temp\UOC\TrainData\edt\image_1584.h5
# C:\temp\UOC\TrainData\edt\image_1585.h5
# C:\temp\UOC\TrainData\edt\image_1586.h5
# C:\temp\UOC\TrainData\edt\image_1587.h5
# C:\temp\UOC\TrainData\edt\image_1588.h5
# C:\temp\UOC\TrainData\edt\image_1589.h5
# C:\temp\UOC\TrainData\edt\image_159.h5
# C:\temp\UOC\TrainData\edt\image_1590.h5
# C:\temp\UOC\TrainData\edt\image_1591.h5
# C:\temp\UOC\TrainData\edt\image_1592.h5
# C:\temp\UOC\TrainData\edt\image_1593.h5
# C:\temp\UOC\TrainData\edt\image_1594.h5
# C:\temp\UOC\TrainData\edt\image_1595.h5
# C:\temp\UOC\TrainData\edt\image_1596.h5
# C:\temp\UOC\TrainData\edt\image_1597.h5
# C:\temp\UOC\TrainData\edt\image_1598.h5
# C:\temp\UOC\TrainData\edt\image_1599.h5
# C:\temp\UOC\TrainData\edt\image_16.h5
# C:\temp\UOC\TrainData\edt\image_160.h5
# C:\temp\UOC\TrainData\edt\image_1600.h5
# C:\temp\UOC\TrainData\edt\image_1601.h5
# C:\temp\UOC\TrainData\edt\image_1602.h5
# C:\temp\UOC\TrainData\edt\image_1603.h5
# C:\temp\UOC\TrainData\edt\image_1604.h5
# C:\temp\UOC\TrainData\edt\image_1605.h5
# C:\temp\UOC\TrainData\edt\image_1606.h5
# C:\temp\UOC\TrainData\edt\image_1607.h5
# C:\temp\UOC\TrainData\edt\image_1608.h5
# C:\temp\UOC\TrainData\edt\image_1609.h5
# C:\temp\UOC\TrainData\edt\image_161.h5
# C:\temp\UOC\TrainData\edt\image_1610.h5
# C:\temp\UOC\TrainData\edt\image_1611.h5
# C:\temp\UOC\TrainData\edt\image_1612.h5
# C:\temp\UOC\TrainData\edt\image_1613.h5
# C:\temp\UOC\TrainData\edt\image_1614.h5
# C:\temp\UOC\TrainData\edt\image_1615.h5
# C:\temp\UOC\TrainData\edt\image_1616.h5
# C:\temp\UOC\TrainData\edt\image_1617.h5
# C:\temp\UOC\TrainData\edt\image_1618.h5
# C:\temp\UOC\TrainData\edt\image_1619.h5
# C:\temp\UOC\TrainData\edt\image_162.h5
# C:\temp\UOC\TrainData\edt\image_1620.h5
# C:\temp\UOC\TrainData\edt\image_1621.h5
# C:\temp\UOC\TrainData\edt\image_1622.h5
# C:\temp\UOC\TrainData\edt\image_1623.h5
# C:\temp\UOC\TrainData\edt\image_1624.h5
# C:\temp\UOC\TrainData\edt\image_1625.h5
# C:\temp\UOC\TrainData\edt\image_1626.h5
# C:\temp\UOC\TrainData\edt\image_1627.h5
# C:\temp\UOC\TrainData\edt\image_1628.h5
# C:\temp\UOC\TrainData\edt\image_1629.h5
# C:\temp\UOC\TrainData\edt\image_163.h5
# C:\temp\UOC\TrainData\edt\image_1630.h5
# C:\temp\UOC\TrainData\edt\image_1631.h5
# C:\temp\UOC\TrainData\edt\image_1632.h5
# C:\temp\UOC\TrainData\edt\image_1633.h5
# C:\temp\UOC\TrainData\edt\image_1634.h5
# C:\temp\UOC\TrainData\edt\image_1635.h5
# C:\temp\UOC\TrainData\edt\image_1636.h5
# C:\temp\UOC\TrainData\edt\image_1637.h5
# C:\temp\UOC\TrainData\edt\image_1638.h5
# C:\temp\UOC\TrainData\edt\image_1639.h5
# C:\temp\UOC\TrainData\edt\image_164.h5
# C:\temp\UOC\TrainData\edt\image_1640.h5
# C:\temp\UOC\TrainData\edt\image_1641.h5
# C:\temp\UOC\TrainData\edt\image_1642.h5
# C:\temp\UOC\TrainData\edt\image_1643.h5
# C:\temp\UOC\TrainData\edt\image_1644.h5
# C:\temp\UOC\TrainData\edt\image_1645.h5
# C:\temp\UOC\TrainData\edt\image_1646.h5
# C:\temp\UOC\TrainData\edt\image_1647.h5
# C:\temp\UOC\TrainData\edt\image_1648.h5
# C:\temp\UOC\TrainData\edt\image_1649.h5
# C:\temp\UOC\TrainData\edt\image_165.h5
# C:\temp\UOC\TrainData\edt\image_1650.h5
# C:\temp\UOC\TrainData\edt\image_1651.h5
# C:\temp\UOC\TrainData\edt\image_1652.h5
# C:\temp\UOC\TrainData\edt\image_1653.h5
# C:\temp\UOC\TrainData\edt\image_1654.h5
# C:\temp\UOC\TrainData\edt\image_1655.h5
# C:\temp\UOC\TrainData\edt\image_1656.h5
# C:\temp\UOC\TrainData\edt\image_1657.h5
# C:\temp\UOC\TrainData\edt\image_1658.h5
# C:\temp\UOC\TrainData\edt\image_1659.h5
# C:\temp\UOC\TrainData\edt\image_166.h5
# C:\temp\UOC\TrainData\edt\image_1660.h5
# C:\temp\UOC\TrainData\edt\image_1661.h5
# C:\temp\UOC\TrainData\edt\image_1662.h5
# C:\temp\UOC\TrainData\edt\image_1663.h5
# C:\temp\UOC\TrainData\edt\image_1664.h5
# C:\temp\UOC\TrainData\edt\image_1665.h5
# C:\temp\UOC\TrainData\edt\image_1666.h5
# C:\temp\UOC\TrainData\edt\image_1667.h5
# C:\temp\UOC\TrainData\edt\image_1668.h5
# C:\temp\UOC\TrainData\edt\image_1669.h5
# C:\temp\UOC\TrainData\edt\image_167.h5
# C:\temp\UOC\TrainData\edt\image_1670.h5
# C:\temp\UOC\TrainData\edt\image_1671.h5
# C:\temp\UOC\TrainData\edt\image_1672.h5
# C:\temp\UOC\TrainData\edt\image_1673.h5
# C:\temp\UOC\TrainData\edt\image_1674.h5
# C:\temp\UOC\TrainData\edt\image_1675.h5
# C:\temp\UOC\TrainData\edt\image_1676.h5
# C:\temp\UOC\TrainData\edt\image_1677.h5
# C:\temp\UOC\TrainData\edt\image_1678.h5
# C:\temp\UOC\TrainData\edt\image_1679.h5
# C:\temp\UOC\TrainData\edt\image_168.h5
# C:\temp\UOC\TrainData\edt\image_1680.h5
# C:\temp\UOC\TrainData\edt\image_1681.h5
# C:\temp\UOC\TrainData\edt\image_1682.h5
# C:\temp\UOC\TrainData\edt\image_1683.h5
# C:\temp\UOC\TrainData\edt\image_1684.h5
# C:\temp\UOC\TrainData\edt\image_1685.h5
# C:\temp\UOC\TrainData\edt\image_1686.h5
# C:\temp\UOC\TrainData\edt\image_1687.h5
# C:\temp\UOC\TrainData\edt\image_1688.h5
# C:\temp\UOC\TrainData\edt\image_1689.h5
# C:\temp\UOC\TrainData\edt\image_169.h5
# C:\temp\UOC\TrainData\edt\image_1690.h5
# C:\temp\UOC\TrainData\edt\image_1691.h5
# C:\temp\UOC\TrainData\edt\image_1692.h5
# C:\temp\UOC\TrainData\edt\image_1693.h5
# C:\temp\UOC\TrainData\edt\image_1694.h5
# C:\temp\UOC\TrainData\edt\image_1695.h5
# C:\temp\UOC\TrainData\edt\image_1696.h5
# C:\temp\UOC\TrainData\edt\image_1697.h5
# C:\temp\UOC\TrainData\edt\image_1698.h5
# C:\temp\UOC\TrainData\edt\image_1699.h5
# C:\temp\UOC\TrainData\edt\image_17.h5
# C:\temp\UOC\TrainData\edt\image_170.h5
# C:\temp\UOC\TrainData\edt\image_1700.h5
# C:\temp\UOC\TrainData\edt\image_1701.h5
# C:\temp\UOC\TrainData\edt\image_1702.h5
# C:\temp\UOC\TrainData\edt\image_1703.h5
# C:\temp\UOC\TrainData\edt\image_1704.h5
# C:\temp\UOC\TrainData\edt\image_1705.h5
# C:\temp\UOC\TrainData\edt\image_1706.h5
# C:\temp\UOC\TrainData\edt\image_1707.h5
# C:\temp\UOC\TrainData\edt\image_1708.h5
# C:\temp\UOC\TrainData\edt\image_1709.h5
# C:\temp\UOC\TrainData\edt\image_171.h5
# C:\temp\UOC\TrainData\edt\image_1710.h5
# C:\temp\UOC\TrainData\edt\image_1711.h5
# C:\temp\UOC\TrainData\edt\image_1712.h5
# C:\temp\UOC\TrainData\edt\image_1713.h5
# C:\temp\UOC\TrainData\edt\image_1714.h5
# C:\temp\UOC\TrainData\edt\image_1715.h5
# C:\temp\UOC\TrainData\edt\image_1716.h5
# C:\temp\UOC\TrainData\edt\image_1717.h5
# C:\temp\UOC\TrainData\edt\image_1718.h5
# C:\temp\UOC\TrainData\edt\image_1719.h5
# C:\temp\UOC\TrainData\edt\image_172.h5
# C:\temp\UOC\TrainData\edt\image_1720.h5
# C:\temp\UOC\TrainData\edt\image_1721.h5
# C:\temp\UOC\TrainData\edt\image_1722.h5
# C:\temp\UOC\TrainData\edt\image_1723.h5
# C:\temp\UOC\TrainData\edt\image_1724.h5
# C:\temp\UOC\TrainData\edt\image_1725.h5
# C:\temp\UOC\TrainData\edt\image_1726.h5
# C:\temp\UOC\TrainData\edt\image_1727.h5
# C:\temp\UOC\TrainData\edt\image_1728.h5
# C:\temp\UOC\TrainData\edt\image_1729.h5
# C:\temp\UOC\TrainData\edt\image_173.h5
# C:\temp\UOC\TrainData\edt\image_1730.h5
# C:\temp\UOC\TrainData\edt\image_1731.h5
# C:\temp\UOC\TrainData\edt\image_1732.h5
# C:\temp\UOC\TrainData\edt\image_1733.h5
# C:\temp\UOC\TrainData\edt\image_1734.h5
# C:\temp\UOC\TrainData\edt\image_1735.h5
# C:\temp\UOC\TrainData\edt\image_1736.h5
# C:\temp\UOC\TrainData\edt\image_1737.h5
# C:\temp\UOC\TrainData\edt\image_1738.h5
# C:\temp\UOC\TrainData\edt\image_1739.h5
# C:\temp\UOC\TrainData\edt\image_174.h5
# C:\temp\UOC\TrainData\edt\image_1740.h5
# C:\temp\UOC\TrainData\edt\image_1741.h5
# C:\temp\UOC\TrainData\edt\image_1742.h5
# C:\temp\UOC\TrainData\edt\image_1743.h5
# C:\temp\UOC\TrainData\edt\image_1744.h5
# C:\temp\UOC\TrainData\edt\image_1745.h5
# C:\temp\UOC\TrainData\edt\image_1746.h5
# C:\temp\UOC\TrainData\edt\image_1747.h5
# C:\temp\UOC\TrainData\edt\image_1748.h5
# C:\temp\UOC\TrainData\edt\image_1749.h5
# C:\temp\UOC\TrainData\edt\image_175.h5
# C:\temp\UOC\TrainData\edt\image_1750.h5
# C:\temp\UOC\TrainData\edt\image_1751.h5
# C:\temp\UOC\TrainData\edt\image_1752.h5
# C:\temp\UOC\TrainData\edt\image_1753.h5
# C:\temp\UOC\TrainData\edt\image_1754.h5
# C:\temp\UOC\TrainData\edt\image_1755.h5
# C:\temp\UOC\TrainData\edt\image_1756.h5
# C:\temp\UOC\TrainData\edt\image_1757.h5
# C:\temp\UOC\TrainData\edt\image_1758.h5
# C:\temp\UOC\TrainData\edt\image_1759.h5
# C:\temp\UOC\TrainData\edt\image_176.h5
# C:\temp\UOC\TrainData\edt\image_1760.h5
# C:\temp\UOC\TrainData\edt\image_1761.h5
# C:\temp\UOC\TrainData\edt\image_1762.h5
# C:\temp\UOC\TrainData\edt\image_1763.h5
# C:\temp\UOC\TrainData\edt\image_1764.h5
# C:\temp\UOC\TrainData\edt\image_1765.h5
# C:\temp\UOC\TrainData\edt\image_1766.h5
# C:\temp\UOC\TrainData\edt\image_1767.h5
# C:\temp\UOC\TrainData\edt\image_1768.h5
# C:\temp\UOC\TrainData\edt\image_1769.h5
# C:\temp\UOC\TrainData\edt\image_177.h5
# C:\temp\UOC\TrainData\edt\image_1770.h5
# C:\temp\UOC\TrainData\edt\image_1771.h5
# C:\temp\UOC\TrainData\edt\image_1772.h5
# C:\temp\UOC\TrainData\edt\image_1773.h5
# C:\temp\UOC\TrainData\edt\image_1774.h5
# C:\temp\UOC\TrainData\edt\image_1775.h5
# C:\temp\UOC\TrainData\edt\image_1776.h5
# C:\temp\UOC\TrainData\edt\image_1777.h5
# C:\temp\UOC\TrainData\edt\image_1778.h5
# C:\temp\UOC\TrainData\edt\image_1779.h5
# C:\temp\UOC\TrainData\edt\image_178.h5
# C:\temp\UOC\TrainData\edt\image_1780.h5
# C:\temp\UOC\TrainData\edt\image_1781.h5
# C:\temp\UOC\TrainData\edt\image_1782.h5
# C:\temp\UOC\TrainData\edt\image_1783.h5
# C:\temp\UOC\TrainData\edt\image_1784.h5
# C:\temp\UOC\TrainData\edt\image_1785.h5
# C:\temp\UOC\TrainData\edt\image_1786.h5
# C:\temp\UOC\TrainData\edt\image_1787.h5
# C:\temp\UOC\TrainData\edt\image_1788.h5
# C:\temp\UOC\TrainData\edt\image_1789.h5
# C:\temp\UOC\TrainData\edt\image_179.h5
# C:\temp\UOC\TrainData\edt\image_1790.h5
# C:\temp\UOC\TrainData\edt\image_1791.h5
# C:\temp\UOC\TrainData\edt\image_1792.h5
# C:\temp\UOC\TrainData\edt\image_1793.h5
# C:\temp\UOC\TrainData\edt\image_1794.h5
# C:\temp\UOC\TrainData\edt\image_1795.h5
# C:\temp\UOC\TrainData\edt\image_1796.h5
# C:\temp\UOC\TrainData\edt\image_1797.h5
# C:\temp\UOC\TrainData\edt\image_1798.h5
# C:\temp\UOC\TrainData\edt\image_1799.h5
# C:\temp\UOC\TrainData\edt\image_18.h5
# C:\temp\UOC\TrainData\edt\image_180.h5
# C:\temp\UOC\TrainData\edt\image_1800.h5
# C:\temp\UOC\TrainData\edt\image_1801.h5
# C:\temp\UOC\TrainData\edt\image_1802.h5
# C:\temp\UOC\TrainData\edt\image_1803.h5
# C:\temp\UOC\TrainData\edt\image_1804.h5
# C:\temp\UOC\TrainData\edt\image_1805.h5
# C:\temp\UOC\TrainData\edt\image_1806.h5
# C:\temp\UOC\TrainData\edt\image_1807.h5
# C:\temp\UOC\TrainData\edt\image_1808.h5
# C:\temp\UOC\TrainData\edt\image_1809.h5
# C:\temp\UOC\TrainData\edt\image_181.h5
# C:\temp\UOC\TrainData\edt\image_1810.h5
# C:\temp\UOC\TrainData\edt\image_1811.h5
# C:\temp\UOC\TrainData\edt\image_1812.h5
# C:\temp\UOC\TrainData\edt\image_1813.h5
# C:\temp\UOC\TrainData\edt\image_1814.h5
# C:\temp\UOC\TrainData\edt\image_1815.h5
# C:\temp\UOC\TrainData\edt\image_1816.h5
# C:\temp\UOC\TrainData\edt\image_1817.h5
# C:\temp\UOC\TrainData\edt\image_1818.h5
# C:\temp\UOC\TrainData\edt\image_1819.h5
# C:\temp\UOC\TrainData\edt\image_182.h5
# C:\temp\UOC\TrainData\edt\image_1820.h5
# C:\temp\UOC\TrainData\edt\image_1821.h5
# C:\temp\UOC\TrainData\edt\image_1822.h5
# C:\temp\UOC\TrainData\edt\image_1823.h5
# C:\temp\UOC\TrainData\edt\image_1824.h5
# C:\temp\UOC\TrainData\edt\image_1825.h5
# C:\temp\UOC\TrainData\edt\image_1826.h5
# C:\temp\UOC\TrainData\edt\image_1827.h5
# C:\temp\UOC\TrainData\edt\image_1828.h5
# C:\temp\UOC\TrainData\edt\image_1829.h5
# C:\temp\UOC\TrainData\edt\image_183.h5
# C:\temp\UOC\TrainData\edt\image_1830.h5
# C:\temp\UOC\TrainData\edt\image_1831.h5
# C:\temp\UOC\TrainData\edt\image_1832.h5
# C:\temp\UOC\TrainData\edt\image_1833.h5
# C:\temp\UOC\TrainData\edt\image_1834.h5
# C:\temp\UOC\TrainData\edt\image_1835.h5
# C:\temp\UOC\TrainData\edt\image_1836.h5
# C:\temp\UOC\TrainData\edt\image_1837.h5
# C:\temp\UOC\TrainData\edt\image_1838.h5
# C:\temp\UOC\TrainData\edt\image_1839.h5
# C:\temp\UOC\TrainData\edt\image_184.h5
# C:\temp\UOC\TrainData\edt\image_1840.h5
# C:\temp\UOC\TrainData\edt\image_1841.h5
# C:\temp\UOC\TrainData\edt\image_1842.h5
# C:\temp\UOC\TrainData\edt\image_1843.h5
# C:\temp\UOC\TrainData\edt\image_1844.h5
# C:\temp\UOC\TrainData\edt\image_1845.h5
# C:\temp\UOC\TrainData\edt\image_1846.h5
# C:\temp\UOC\TrainData\edt\image_1847.h5
# C:\temp\UOC\TrainData\edt\image_1848.h5
# C:\temp\UOC\TrainData\edt\image_1849.h5
# C:\temp\UOC\TrainData\edt\image_185.h5
# C:\temp\UOC\TrainData\edt\image_1850.h5
# C:\temp\UOC\TrainData\edt\image_1851.h5
# C:\temp\UOC\TrainData\edt\image_1852.h5
# C:\temp\UOC\TrainData\edt\image_1853.h5
# C:\temp\UOC\TrainData\edt\image_1854.h5
# C:\temp\UOC\TrainData\edt\image_1855.h5
# C:\temp\UOC\TrainData\edt\image_1856.h5
# C:\temp\UOC\TrainData\edt\image_1857.h5
# C:\temp\UOC\TrainData\edt\image_1858.h5
# C:\temp\UOC\TrainData\edt\image_1859.h5
# C:\temp\UOC\TrainData\edt\image_186.h5
# C:\temp\UOC\TrainData\edt\image_1860.h5
# C:\temp\UOC\TrainData\edt\image_1861.h5
# C:\temp\UOC\TrainData\edt\image_1862.h5
# C:\temp\UOC\TrainData\edt\image_1863.h5
# C:\temp\UOC\TrainData\edt\image_1864.h5
# C:\temp\UOC\TrainData\edt\image_1865.h5
# C:\temp\UOC\TrainData\edt\image_1866.h5
# C:\temp\UOC\TrainData\edt\image_1867.h5
# C:\temp\UOC\TrainData\edt\image_1868.h5
# C:\temp\UOC\TrainData\edt\image_1869.h5
# C:\temp\UOC\TrainData\edt\image_187.h5
# C:\temp\UOC\TrainData\edt\image_1870.h5
# C:\temp\UOC\TrainData\edt\image_1871.h5
# C:\temp\UOC\TrainData\edt\image_1872.h5
# C:\temp\UOC\TrainData\edt\image_1873.h5
# C:\temp\UOC\TrainData\edt\image_1874.h5
# C:\temp\UOC\TrainData\edt\image_1875.h5
# C:\temp\UOC\TrainData\edt\image_1876.h5
# C:\temp\UOC\TrainData\edt\image_1877.h5
# C:\temp\UOC\TrainData\edt\image_1878.h5
# C:\temp\UOC\TrainData\edt\image_1879.h5
# C:\temp\UOC\TrainData\edt\image_188.h5
# C:\temp\UOC\TrainData\edt\image_1880.h5
# C:\temp\UOC\TrainData\edt\image_1881.h5
# C:\temp\UOC\TrainData\edt\image_1882.h5
# C:\temp\UOC\TrainData\edt\image_1883.h5
# C:\temp\UOC\TrainData\edt\image_1884.h5
# C:\temp\UOC\TrainData\edt\image_1885.h5
# C:\temp\UOC\TrainData\edt\image_1886.h5
# C:\temp\UOC\TrainData\edt\image_1887.h5
# C:\temp\UOC\TrainData\edt\image_1888.h5
# C:\temp\UOC\TrainData\edt\image_1889.h5
# C:\temp\UOC\TrainData\edt\image_189.h5
# C:\temp\UOC\TrainData\edt\image_1890.h5
# C:\temp\UOC\TrainData\edt\image_1891.h5
# C:\temp\UOC\TrainData\edt\image_1892.h5
# C:\temp\UOC\TrainData\edt\image_1893.h5
# C:\temp\UOC\TrainData\edt\image_1894.h5
# C:\temp\UOC\TrainData\edt\image_1895.h5
# C:\temp\UOC\TrainData\edt\image_1896.h5
# C:\temp\UOC\TrainData\edt\image_1897.h5
# C:\temp\UOC\TrainData\edt\image_1898.h5
# C:\temp\UOC\TrainData\edt\image_1899.h5
# C:\temp\UOC\TrainData\edt\image_19.h5
# C:\temp\UOC\TrainData\edt\image_190.h5
# C:\temp\UOC\TrainData\edt\image_1900.h5
# C:\temp\UOC\TrainData\edt\image_1901.h5
# C:\temp\UOC\TrainData\edt\image_1902.h5
# C:\temp\UOC\TrainData\edt\image_1903.h5
# C:\temp\UOC\TrainData\edt\image_1904.h5
# C:\temp\UOC\TrainData\edt\image_1905.h5
# C:\temp\UOC\TrainData\edt\image_1906.h5
# C:\temp\UOC\TrainData\edt\image_1907.h5
# C:\temp\UOC\TrainData\edt\image_1908.h5
# C:\temp\UOC\TrainData\edt\image_1909.h5
# C:\temp\UOC\TrainData\edt\image_191.h5
# C:\temp\UOC\TrainData\edt\image_1910.h5
# C:\temp\UOC\TrainData\edt\image_1911.h5
# C:\temp\UOC\TrainData\edt\image_1912.h5
# C:\temp\UOC\TrainData\edt\image_1913.h5
# C:\temp\UOC\TrainData\edt\image_1914.h5
# C:\temp\UOC\TrainData\edt\image_1915.h5
# C:\temp\UOC\TrainData\edt\image_1916.h5
# C:\temp\UOC\TrainData\edt\image_1917.h5
# C:\temp\UOC\TrainData\edt\image_1918.h5
# C:\temp\UOC\TrainData\edt\image_1919.h5
# C:\temp\UOC\TrainData\edt\image_192.h5
# C:\temp\UOC\TrainData\edt\image_1920.h5
# C:\temp\UOC\TrainData\edt\image_1921.h5
# C:\temp\UOC\TrainData\edt\image_1922.h5
# C:\temp\UOC\TrainData\edt\image_1923.h5
# C:\temp\UOC\TrainData\edt\image_1924.h5
# C:\temp\UOC\TrainData\edt\image_1925.h5
# C:\temp\UOC\TrainData\edt\image_1926.h5
# C:\temp\UOC\TrainData\edt\image_1927.h5
# C:\temp\UOC\TrainData\edt\image_1928.h5
# C:\temp\UOC\TrainData\edt\image_1929.h5
# C:\temp\UOC\TrainData\edt\image_193.h5
# C:\temp\UOC\TrainData\edt\image_1930.h5
# C:\temp\UOC\TrainData\edt\image_1931.h5
# C:\temp\UOC\TrainData\edt\image_1932.h5
# C:\temp\UOC\TrainData\edt\image_1933.h5
# C:\temp\UOC\TrainData\edt\image_1934.h5
# C:\temp\UOC\TrainData\edt\image_1935.h5
# C:\temp\UOC\TrainData\edt\image_1936.h5
# C:\temp\UOC\TrainData\edt\image_1937.h5
# C:\temp\UOC\TrainData\edt\image_1938.h5
# C:\temp\UOC\TrainData\edt\image_1939.h5
# C:\temp\UOC\TrainData\edt\image_194.h5
# C:\temp\UOC\TrainData\edt\image_1940.h5
# C:\temp\UOC\TrainData\edt\image_1941.h5
# C:\temp\UOC\TrainData\edt\image_1942.h5
# C:\temp\UOC\TrainData\edt\image_1943.h5
# C:\temp\UOC\TrainData\edt\image_1944.h5
# C:\temp\UOC\TrainData\edt\image_1945.h5
# C:\temp\UOC\TrainData\edt\image_1946.h5
# C:\temp\UOC\TrainData\edt\image_1947.h5
# C:\temp\UOC\TrainData\edt\image_1948.h5
# C:\temp\UOC\TrainData\edt\image_1949.h5
# C:\temp\UOC\TrainData\edt\image_195.h5
# C:\temp\UOC\TrainData\edt\image_1950.h5
# C:\temp\UOC\TrainData\edt\image_1951.h5
# C:\temp\UOC\TrainData\edt\image_1952.h5
# C:\temp\UOC\TrainData\edt\image_1953.h5
# C:\temp\UOC\TrainData\edt\image_1954.h5
# C:\temp\UOC\TrainData\edt\image_1955.h5
# C:\temp\UOC\TrainData\edt\image_1956.h5
# C:\temp\UOC\TrainData\edt\image_1957.h5
# C:\temp\UOC\TrainData\edt\image_1958.h5
# C:\temp\UOC\TrainData\edt\image_1959.h5
# C:\temp\UOC\TrainData\edt\image_196.h5
# C:\temp\UOC\TrainData\edt\image_1960.h5
# C:\temp\UOC\TrainData\edt\image_1961.h5
# C:\temp\UOC\TrainData\edt\image_1962.h5
# C:\temp\UOC\TrainData\edt\image_1963.h5
# C:\temp\UOC\TrainData\edt\image_1964.h5
# C:\temp\UOC\TrainData\edt\image_1965.h5
# C:\temp\UOC\TrainData\edt\image_1966.h5
# C:\temp\UOC\TrainData\edt\image_1967.h5
# C:\temp\UOC\TrainData\edt\image_1968.h5
# C:\temp\UOC\TrainData\edt\image_1969.h5
# C:\temp\UOC\TrainData\edt\image_197.h5
# C:\temp\UOC\TrainData\edt\image_1970.h5
# C:\temp\UOC\TrainData\edt\image_1971.h5
# C:\temp\UOC\TrainData\edt\image_1972.h5
# C:\temp\UOC\TrainData\edt\image_1973.h5
# C:\temp\UOC\TrainData\edt\image_1974.h5
# C:\temp\UOC\TrainData\edt\image_1975.h5
# C:\temp\UOC\TrainData\edt\image_1976.h5
# C:\temp\UOC\TrainData\edt\image_1977.h5
# C:\temp\UOC\TrainData\edt\image_1978.h5
# C:\temp\UOC\TrainData\edt\image_1979.h5
# C:\temp\UOC\TrainData\edt\image_198.h5
# C:\temp\UOC\TrainData\edt\image_1980.h5
# C:\temp\UOC\TrainData\edt\image_1981.h5
# C:\temp\UOC\TrainData\edt\image_1982.h5
# C:\temp\UOC\TrainData\edt\image_1983.h5
# C:\temp\UOC\TrainData\edt\image_1984.h5
# C:\temp\UOC\TrainData\edt\image_1985.h5
# C:\temp\UOC\TrainData\edt\image_1986.h5
# C:\temp\UOC\TrainData\edt\image_1987.h5
# C:\temp\UOC\TrainData\edt\image_1988.h5
# C:\temp\UOC\TrainData\edt\image_1989.h5
# C:\temp\UOC\TrainData\edt\image_199.h5
# C:\temp\UOC\TrainData\edt\image_1990.h5
# C:\temp\UOC\TrainData\edt\image_1991.h5
# C:\temp\UOC\TrainData\edt\image_1992.h5
# C:\temp\UOC\TrainData\edt\image_1993.h5
# C:\temp\UOC\TrainData\edt\image_1994.h5
# C:\temp\UOC\TrainData\edt\image_1995.h5
# C:\temp\UOC\TrainData\edt\image_1996.h5
# C:\temp\UOC\TrainData\edt\image_1997.h5
# C:\temp\UOC\TrainData\edt\image_1998.h5
# C:\temp\UOC\TrainData\edt\image_1999.h5
# C:\temp\UOC\TrainData\edt\image_2.h5
# C:\temp\UOC\TrainData\edt\image_20.h5
# C:\temp\UOC\TrainData\edt\image_200.h5
# C:\temp\UOC\TrainData\edt\image_2000.h5
# C:\temp\UOC\TrainData\edt\image_2001.h5
# C:\temp\UOC\TrainData\edt\image_2002.h5
# C:\temp\UOC\TrainData\edt\image_2003.h5
# C:\temp\UOC\TrainData\edt\image_2004.h5
# C:\temp\UOC\TrainData\edt\image_2005.h5
# C:\temp\UOC\TrainData\edt\image_2006.h5
# C:\temp\UOC\TrainData\edt\image_2007.h5
# C:\temp\UOC\TrainData\edt\image_2008.h5
# C:\temp\UOC\TrainData\edt\image_2009.h5
# C:\temp\UOC\TrainData\edt\image_201.h5
# C:\temp\UOC\TrainData\edt\image_2010.h5
# C:\temp\UOC\TrainData\edt\image_2011.h5
# C:\temp\UOC\TrainData\edt\image_2012.h5
# C:\temp\UOC\TrainData\edt\image_2013.h5
# C:\temp\UOC\TrainData\edt\image_2014.h5
# C:\temp\UOC\TrainData\edt\image_2015.h5
# C:\temp\UOC\TrainData\edt\image_2016.h5
# C:\temp\UOC\TrainData\edt\image_2017.h5
# C:\temp\UOC\TrainData\edt\image_2018.h5
# C:\temp\UOC\TrainData\edt\image_2019.h5
# C:\temp\UOC\TrainData\edt\image_202.h5
# C:\temp\UOC\TrainData\edt\image_2020.h5
# C:\temp\UOC\TrainData\edt\image_2021.h5
# C:\temp\UOC\TrainData\edt\image_2022.h5
# C:\temp\UOC\TrainData\edt\image_2023.h5
# C:\temp\UOC\TrainData\edt\image_2024.h5
# C:\temp\UOC\TrainData\edt\image_2025.h5
# C:\temp\UOC\TrainData\edt\image_2026.h5
# C:\temp\UOC\TrainData\edt\image_2027.h5
# C:\temp\UOC\TrainData\edt\image_2028.h5
# C:\temp\UOC\TrainData\edt\image_2029.h5
# C:\temp\UOC\TrainData\edt\image_203.h5
# C:\temp\UOC\TrainData\edt\image_2030.h5
# C:\temp\UOC\TrainData\edt\image_2031.h5
# C:\temp\UOC\TrainData\edt\image_2032.h5
# C:\temp\UOC\TrainData\edt\image_2033.h5
# C:\temp\UOC\TrainData\edt\image_2034.h5
# C:\temp\UOC\TrainData\edt\image_2035.h5
# C:\temp\UOC\TrainData\edt\image_2036.h5
# C:\temp\UOC\TrainData\edt\image_2037.h5
# C:\temp\UOC\TrainData\edt\image_2038.h5
# C:\temp\UOC\TrainData\edt\image_2039.h5
# C:\temp\UOC\TrainData\edt\image_204.h5
# C:\temp\UOC\TrainData\edt\image_2040.h5
# C:\temp\UOC\TrainData\edt\image_2041.h5
# C:\temp\UOC\TrainData\edt\image_2042.h5
# C:\temp\UOC\TrainData\edt\image_2043.h5
# C:\temp\UOC\TrainData\edt\image_2044.h5
# C:\temp\UOC\TrainData\edt\image_2045.h5
# C:\temp\UOC\TrainData\edt\image_2046.h5
# C:\temp\UOC\TrainData\edt\image_2047.h5
# C:\temp\UOC\TrainData\edt\image_2048.h5
# C:\temp\UOC\TrainData\edt\image_2049.h5
# C:\temp\UOC\TrainData\edt\image_205.h5
# C:\temp\UOC\TrainData\edt\image_2050.h5
# C:\temp\UOC\TrainData\edt\image_2051.h5
# C:\temp\UOC\TrainData\edt\image_2052.h5
# C:\temp\UOC\TrainData\edt\image_2053.h5
# C:\temp\UOC\TrainData\edt\image_2054.h5
# C:\temp\UOC\TrainData\edt\image_2055.h5
# C:\temp\UOC\TrainData\edt\image_2056.h5
# C:\temp\UOC\TrainData\edt\image_2057.h5
# C:\temp\UOC\TrainData\edt\image_2058.h5
# C:\temp\UOC\TrainData\edt\image_2059.h5
# C:\temp\UOC\TrainData\edt\image_206.h5
# C:\temp\UOC\TrainData\edt\image_2060.h5
# C:\temp\UOC\TrainData\edt\image_2061.h5
# C:\temp\UOC\TrainData\edt\image_2062.h5
# C:\temp\UOC\TrainData\edt\image_2063.h5
# C:\temp\UOC\TrainData\edt\image_2064.h5
# C:\temp\UOC\TrainData\edt\image_2065.h5
# C:\temp\UOC\TrainData\edt\image_2066.h5
# C:\temp\UOC\TrainData\edt\image_2067.h5
# C:\temp\UOC\TrainData\edt\image_2068.h5
# C:\temp\UOC\TrainData\edt\image_2069.h5
# C:\temp\UOC\TrainData\edt\image_207.h5
# C:\temp\UOC\TrainData\edt\image_2070.h5
# C:\temp\UOC\TrainData\edt\image_2071.h5
# C:\temp\UOC\TrainData\edt\image_2072.h5
# C:\temp\UOC\TrainData\edt\image_2073.h5
# C:\temp\UOC\TrainData\edt\image_2074.h5
# C:\temp\UOC\TrainData\edt\image_2075.h5
# C:\temp\UOC\TrainData\edt\image_2076.h5
# C:\temp\UOC\TrainData\edt\image_2077.h5
# C:\temp\UOC\TrainData\edt\image_2078.h5
# C:\temp\UOC\TrainData\edt\image_2079.h5
# C:\temp\UOC\TrainData\edt\image_208.h5
# C:\temp\UOC\TrainData\edt\image_2080.h5
# ...
# C:\temp\UOC\TrainData\edt\image_629.h5
# C:\temp\UOC\TrainData\edt\image_63.h5
# C:\temp\UOC\TrainData\edt\image_630.h5
# C:\temp\UOC\TrainData\edt\image_631.h5
# C:\temp\UOC\TrainData\edt\image_632.h5
# C:\temp\UOC\TrainData\edt\image_633.h5
# C:\temp\UOC\TrainData\edt\image_634.h5
# C:\temp\UOC\TrainData\edt\image_635.h5
# C:\temp\UOC\TrainData\edt\image_636.h5
# C:\temp\UOC\TrainData\edt\image_637.h5
# C:\temp\UOC\TrainData\edt\image_638.h5
# C:\temp\UOC\TrainData\edt\image_639.h5
# C:\temp\UOC\TrainData\edt\image_64.h5
# C:\temp\UOC\TrainData\edt\image_640.h5
# C:\temp\UOC\TrainData\edt\image_641.h5
# C:\temp\UOC\TrainData\edt\image_642.h5
# C:\temp\UOC\TrainData\edt\image_643.h5
# C:\temp\UOC\TrainData\edt\image_644.h5
# C:\temp\UOC\TrainData\edt\image_645.h5
# C:\temp\UOC\TrainData\edt\image_646.h5
# C:\temp\UOC\TrainData\edt\image_647.h5
# C:\temp\UOC\TrainData\edt\image_648.h5
# C:\temp\UOC\TrainData\edt\image_649.h5
# C:\temp\UOC\TrainData\edt\image_65.h5
# C:\temp\UOC\TrainData\edt\image_650.h5
# C:\temp\UOC\TrainData\edt\image_651.h5
# C:\temp\UOC\TrainData\edt\image_652.h5
# C:\temp\UOC\TrainData\edt\image_653.h5
# C:\temp\UOC\TrainData\edt\image_654.h5
# C:\temp\UOC\TrainData\edt\image_655.h5
# C:\temp\UOC\TrainData\edt\image_656.h5
# C:\temp\UOC\TrainData\edt\image_657.h5
# C:\temp\UOC\TrainData\edt\image_658.h5
# C:\temp\UOC\TrainData\edt\image_659.h5
# C:\temp\UOC\TrainData\edt\image_66.h5
# C:\temp\UOC\TrainData\edt\image_660.h5
# C:\temp\UOC\TrainData\edt\image_661.h5
# C:\temp\UOC\TrainData\edt\image_662.h5
# C:\temp\UOC\TrainData\edt\image_663.h5
# C:\temp\UOC\TrainData\edt\image_664.h5
# C:\temp\UOC\TrainData\edt\image_665.h5
# C:\temp\UOC\TrainData\edt\image_666.h5
# C:\temp\UOC\TrainData\edt\image_667.h5
# C:\temp\UOC\TrainData\edt\image_668.h5
# C:\temp\UOC\TrainData\edt\image_669.h5
# C:\temp\UOC\TrainData\edt\image_67.h5
# C:\temp\UOC\TrainData\edt\image_670.h5
# C:\temp\UOC\TrainData\edt\image_671.h5
# C:\temp\UOC\TrainData\edt\image_672.h5
# C:\temp\UOC\TrainData\edt\image_673.h5
# C:\temp\UOC\TrainData\edt\image_674.h5
# C:\temp\UOC\TrainData\edt\image_675.h5
# C:\temp\UOC\TrainData\edt\image_676.h5
# C:\temp\UOC\TrainData\edt\image_677.h5
# C:\temp\UOC\TrainData\edt\image_678.h5
# C:\temp\UOC\TrainData\edt\image_679.h5
# C:\temp\UOC\TrainData\edt\image_68.h5
# C:\temp\UOC\TrainData\edt\image_680.h5
# C:\temp\UOC\TrainData\edt\image_681.h5
# C:\temp\UOC\TrainData\edt\image_682.h5
# C:\temp\UOC\TrainData\edt\image_683.h5
# C:\temp\UOC\TrainData\edt\image_684.h5
# C:\temp\UOC\TrainData\edt\image_685.h5
# C:\temp\UOC\TrainData\edt\image_686.h5
# C:\temp\UOC\TrainData\edt\image_687.h5
# C:\temp\UOC\TrainData\edt\image_688.h5
# C:\temp\UOC\TrainData\edt\image_689.h5
# C:\temp\UOC\TrainData\edt\image_69.h5
# C:\temp\UOC\TrainData\edt\image_690.h5
# C:\temp\UOC\TrainData\edt\image_691.h5
# C:\temp\UOC\TrainData\edt\image_692.h5
# C:\temp\UOC\TrainData\edt\image_693.h5
# C:\temp\UOC\TrainData\edt\image_694.h5
# C:\temp\UOC\TrainData\edt\image_695.h5
# C:\temp\UOC\TrainData\edt\image_696.h5
# C:\temp\UOC\TrainData\edt\image_697.h5
# C:\temp\UOC\TrainData\edt\image_698.h5
# C:\temp\UOC\TrainData\edt\image_699.h5
# C:\temp\UOC\TrainData\edt\image_7.h5
# C:\temp\UOC\TrainData\edt\image_70.h5
# C:\temp\UOC\TrainData\edt\image_700.h5
# C:\temp\UOC\TrainData\edt\image_701.h5
# C:\temp\UOC\TrainData\edt\image_702.h5
# C:\temp\UOC\TrainData\edt\image_703.h5
# C:\temp\UOC\TrainData\edt\image_704.h5
# C:\temp\UOC\TrainData\edt\image_705.h5
# C:\temp\UOC\TrainData\edt\image_706.h5
# C:\temp\UOC\TrainData\edt\image_707.h5
# C:\temp\UOC\TrainData\edt\image_708.h5
# C:\temp\UOC\TrainData\edt\image_709.h5
# C:\temp\UOC\TrainData\edt\image_71.h5
# C:\temp\UOC\TrainData\edt\image_710.h5
# C:\temp\UOC\TrainData\edt\image_711.h5
# C:\temp\UOC\TrainData\edt\image_712.h5
# C:\temp\UOC\TrainData\edt\image_713.h5
# C:\temp\UOC\TrainData\edt\image_714.h5
# C:\temp\UOC\TrainData\edt\image_715.h5
# C:\temp\UOC\TrainData\edt\image_716.h5
# C:\temp\UOC\TrainData\edt\image_717.h5
# C:\temp\UOC\TrainData\edt\image_718.h5
# C:\temp\UOC\TrainData\edt\image_719.h5
# C:\temp\UOC\TrainData\edt\image_72.h5
# C:\temp\UOC\TrainData\edt\image_720.h5
# C:\temp\UOC\TrainData\edt\image_721.h5
# C:\temp\UOC\TrainData\edt\image_722.h5
# C:\temp\UOC\TrainData\edt\image_723.h5
# C:\temp\UOC\TrainData\edt\image_724.h5
# C:\temp\UOC\TrainData\edt\image_725.h5
# C:\temp\UOC\TrainData\edt\image_726.h5
# C:\temp\UOC\TrainData\edt\image_727.h5
# C:\temp\UOC\TrainData\edt\image_728.h5
# C:\temp\UOC\TrainData\edt\image_729.h5
# C:\temp\UOC\TrainData\edt\image_73.h5
# C:\temp\UOC\TrainData\edt\image_730.h5
# C:\temp\UOC\TrainData\edt\image_731.h5
# C:\temp\UOC\TrainData\edt\image_732.h5
# C:\temp\UOC\TrainData\edt\image_733.h5
# C:\temp\UOC\TrainData\edt\image_734.h5
# C:\temp\UOC\TrainData\edt\image_735.h5
# C:\temp\UOC\TrainData\edt\image_736.h5
# C:\temp\UOC\TrainData\edt\image_737.h5
# C:\temp\UOC\TrainData\edt\image_738.h5
# C:\temp\UOC\TrainData\edt\image_739.h5
# C:\temp\UOC\TrainData\edt\image_74.h5
# C:\temp\UOC\TrainData\edt\image_740.h5
# C:\temp\UOC\TrainData\edt\image_741.h5
# C:\temp\UOC\TrainData\edt\image_742.h5
# C:\temp\UOC\TrainData\edt\image_743.h5
# C:\temp\UOC\TrainData\edt\image_744.h5
# C:\temp\UOC\TrainData\edt\image_745.h5
# C:\temp\UOC\TrainData\edt\image_746.h5
# C:\temp\UOC\TrainData\edt\image_747.h5
# C:\temp\UOC\TrainData\edt\image_748.h5
# C:\temp\UOC\TrainData\edt\image_749.h5
# C:\temp\UOC\TrainData\edt\image_75.h5
# C:\temp\UOC\TrainData\edt\image_750.h5
# C:\temp\UOC\TrainData\edt\image_751.h5
# C:\temp\UOC\TrainData\edt\image_752.h5
# C:\temp\UOC\TrainData\edt\image_753.h5
# C:\temp\UOC\TrainData\edt\image_754.h5
# C:\temp\UOC\TrainData\edt\image_755.h5
# C:\temp\UOC\TrainData\edt\image_756.h5
# C:\temp\UOC\TrainData\edt\image_757.h5
# C:\temp\UOC\TrainData\edt\image_758.h5
# C:\temp\UOC\TrainData\edt\image_759.h5
# C:\temp\UOC\TrainData\edt\image_76.h5
# C:\temp\UOC\TrainData\edt\image_760.h5
# C:\temp\UOC\TrainData\edt\image_761.h5
# C:\temp\UOC\TrainData\edt\image_762.h5
# C:\temp\UOC\TrainData\edt\image_763.h5
# C:\temp\UOC\TrainData\edt\image_764.h5
# C:\temp\UOC\TrainData\edt\image_765.h5
# C:\temp\UOC\TrainData\edt\image_766.h5
# C:\temp\UOC\TrainData\edt\image_767.h5
# C:\temp\UOC\TrainData\edt\image_768.h5
# C:\temp\UOC\TrainData\edt\image_769.h5
# C:\temp\UOC\TrainData\edt\image_77.h5
# C:\temp\UOC\TrainData\edt\image_770.h5
# C:\temp\UOC\TrainData\edt\image_771.h5
# C:\temp\UOC\TrainData\edt\image_772.h5
# C:\temp\UOC\TrainData\edt\image_773.h5
# C:\temp\UOC\TrainData\edt\image_774.h5
# C:\temp\UOC\TrainData\edt\image_775.h5
# C:\temp\UOC\TrainData\edt\image_776.h5
# C:\temp\UOC\TrainData\edt\image_777.h5
# C:\temp\UOC\TrainData\edt\image_778.h5
# C:\temp\UOC\TrainData\edt\image_779.h5
# C:\temp\UOC\TrainData\edt\image_78.h5
# C:\temp\UOC\TrainData\edt\image_780.h5
# C:\temp\UOC\TrainData\edt\image_781.h5
# C:\temp\UOC\TrainData\edt\image_782.h5
# C:\temp\UOC\TrainData\edt\image_783.h5
# C:\temp\UOC\TrainData\edt\image_784.h5
# C:\temp\UOC\TrainData\edt\image_785.h5
# C:\temp\UOC\TrainData\edt\image_786.h5
# C:\temp\UOC\TrainData\edt\image_787.h5
# C:\temp\UOC\TrainData\edt\image_788.h5
# C:\temp\UOC\TrainData\edt\image_789.h5
# C:\temp\UOC\TrainData\edt\image_79.h5
# C:\temp\UOC\TrainData\edt\image_790.h5
# C:\temp\UOC\TrainData\edt\image_791.h5
# C:\temp\UOC\TrainData\edt\image_792.h5
# C:\temp\UOC\TrainData\edt\image_793.h5
# C:\temp\UOC\TrainData\edt\image_794.h5
# C:\temp\UOC\TrainData\edt\image_795.h5
# C:\temp\UOC\TrainData\edt\image_796.h5
# C:\temp\UOC\TrainData\edt\image_797.h5
# C:\temp\UOC\TrainData\edt\image_798.h5
# C:\temp\UOC\TrainData\edt\image_799.h5
# C:\temp\UOC\TrainData\edt\image_8.h5
# C:\temp\UOC\TrainData\edt\image_80.h5
# C:\temp\UOC\TrainData\edt\image_800.h5
# C:\temp\UOC\TrainData\edt\image_801.h5
# C:\temp\UOC\TrainData\edt\image_802.h5
# C:\temp\UOC\TrainData\edt\image_803.h5
# C:\temp\UOC\TrainData\edt\image_804.h5
# C:\temp\UOC\TrainData\edt\image_805.h5
# C:\temp\UOC\TrainData\edt\image_806.h5
# C:\temp\UOC\TrainData\edt\image_807.h5
# C:\temp\UOC\TrainData\edt\image_808.h5
# C:\temp\UOC\TrainData\edt\image_809.h5
# C:\temp\UOC\TrainData\edt\image_81.h5
# C:\temp\UOC\TrainData\edt\image_810.h5
# C:\temp\UOC\TrainData\edt\image_811.h5
# C:\temp\UOC\TrainData\edt\image_812.h5
# C:\temp\UOC\TrainData\edt\image_813.h5
# C:\temp\UOC\TrainData\edt\image_814.h5
# C:\temp\UOC\TrainData\edt\image_815.h5
# C:\temp\UOC\TrainData\edt\image_816.h5
# C:\temp\UOC\TrainData\edt\image_817.h5
# C:\temp\UOC\TrainData\edt\image_818.h5
# C:\temp\UOC\TrainData\edt\image_819.h5
# C:\temp\UOC\TrainData\edt\image_82.h5
# C:\temp\UOC\TrainData\edt\image_820.h5
# C:\temp\UOC\TrainData\edt\image_821.h5
# C:\temp\UOC\TrainData\edt\image_822.h5
# C:\temp\UOC\TrainData\edt\image_823.h5
# C:\temp\UOC\TrainData\edt\image_824.h5
# C:\temp\UOC\TrainData\edt\image_825.h5
# C:\temp\UOC\TrainData\edt\image_826.h5
# C:\temp\UOC\TrainData\edt\image_827.h5
# C:\temp\UOC\TrainData\edt\image_828.h5
# C:\temp\UOC\TrainData\edt\image_829.h5
# C:\temp\UOC\TrainData\edt\image_83.h5
# C:\temp\UOC\TrainData\edt\image_830.h5
# C:\temp\UOC\TrainData\edt\image_831.h5
# C:\temp\UOC\TrainData\edt\image_832.h5
# C:\temp\UOC\TrainData\edt\image_833.h5
# C:\temp\UOC\TrainData\edt\image_834.h5
# C:\temp\UOC\TrainData\edt\image_835.h5
# C:\temp\UOC\TrainData\edt\image_836.h5
# C:\temp\UOC\TrainData\edt\image_837.h5
# C:\temp\UOC\TrainData\edt\image_838.h5
# C:\temp\UOC\TrainData\edt\image_839.h5
# C:\temp\UOC\TrainData\edt\image_84.h5
# C:\temp\UOC\TrainData\edt\image_840.h5
# C:\temp\UOC\TrainData\edt\image_841.h5
# C:\temp\UOC\TrainData\edt\image_842.h5
# C:\temp\UOC\TrainData\edt\image_843.h5
# C:\temp\UOC\TrainData\edt\image_844.h5
# C:\temp\UOC\TrainData\edt\image_845.h5
# C:\temp\UOC\TrainData\edt\image_846.h5
# C:\temp\UOC\TrainData\edt\image_847.h5
# C:\temp\UOC\TrainData\edt\image_848.h5
# C:\temp\UOC\TrainData\edt\image_849.h5
# C:\temp\UOC\TrainData\edt\image_85.h5
# C:\temp\UOC\TrainData\edt\image_850.h5
# C:\temp\UOC\TrainData\edt\image_851.h5
# C:\temp\UOC\TrainData\edt\image_852.h5
# C:\temp\UOC\TrainData\edt\image_853.h5
# C:\temp\UOC\TrainData\edt\image_854.h5
# C:\temp\UOC\TrainData\edt\image_855.h5
# C:\temp\UOC\TrainData\edt\image_856.h5
# C:\temp\UOC\TrainData\edt\image_857.h5
# C:\temp\UOC\TrainData\edt\image_858.h5
# C:\temp\UOC\TrainData\edt\image_859.h5
# C:\temp\UOC\TrainData\edt\image_86.h5
# C:\temp\UOC\TrainData\edt\image_860.h5
# C:\temp\UOC\TrainData\edt\image_861.h5
# C:\temp\UOC\TrainData\edt\image_862.h5
# C:\temp\UOC\TrainData\edt\image_863.h5
# C:\temp\UOC\TrainData\edt\image_864.h5
# C:\temp\UOC\TrainData\edt\image_865.h5
# C:\temp\UOC\TrainData\edt\image_866.h5
# C:\temp\UOC\TrainData\edt\image_867.h5
# C:\temp\UOC\TrainData\edt\image_868.h5
# C:\temp\UOC\TrainData\edt\image_869.h5
# C:\temp\UOC\TrainData\edt\image_87.h5
# C:\temp\UOC\TrainData\edt\image_870.h5
# C:\temp\UOC\TrainData\edt\image_871.h5
# C:\temp\UOC\TrainData\edt\image_872.h5
# C:\temp\UOC\TrainData\edt\image_873.h5
# C:\temp\UOC\TrainData\edt\image_874.h5
# C:\temp\UOC\TrainData\edt\image_875.h5
# C:\temp\UOC\TrainData\edt\image_876.h5
# C:\temp\UOC\TrainData\edt\image_877.h5
# C:\temp\UOC\TrainData\edt\image_878.h5
# C:\temp\UOC\TrainData\edt\image_879.h5
# C:\temp\UOC\TrainData\edt\image_88.h5
# C:\temp\UOC\TrainData\edt\image_880.h5
# C:\temp\UOC\TrainData\edt\image_881.h5
# C:\temp\UOC\TrainData\edt\image_882.h5
# C:\temp\UOC\TrainData\edt\image_883.h5
# C:\temp\UOC\TrainData\edt\image_884.h5
# C:\temp\UOC\TrainData\edt\image_885.h5
# C:\temp\UOC\TrainData\edt\image_886.h5
# C:\temp\UOC\TrainData\edt\image_887.h5
# C:\temp\UOC\TrainData\edt\image_888.h5
# C:\temp\UOC\TrainData\edt\image_889.h5
# C:\temp\UOC\TrainData\edt\image_89.h5
# C:\temp\UOC\TrainData\edt\image_890.h5
# C:\temp\UOC\TrainData\edt\image_891.h5
# C:\temp\UOC\TrainData\edt\image_892.h5
# C:\temp\UOC\TrainData\edt\image_893.h5
# C:\temp\UOC\TrainData\edt\image_894.h5
# C:\temp\UOC\TrainData\edt\image_895.h5
# C:\temp\UOC\TrainData\edt\image_896.h5
# C:\temp\UOC\TrainData\edt\image_897.h5
# C:\temp\UOC\TrainData\edt\image_898.h5
# C:\temp\UOC\TrainData\edt\image_899.h5
# C:\temp\UOC\TrainData\edt\image_9.h5
# C:\temp\UOC\TrainData\edt\image_90.h5
# C:\temp\UOC\TrainData\edt\image_900.h5
# C:\temp\UOC\TrainData\edt\image_901.h5
# C:\temp\UOC\TrainData\edt\image_902.h5
# C:\temp\UOC\TrainData\edt\image_903.h5
# C:\temp\UOC\TrainData\edt\image_904.h5
# C:\temp\UOC\TrainData\edt\image_905.h5
# C:\temp\UOC\TrainData\edt\image_906.h5
# C:\temp\UOC\TrainData\edt\image_907.h5
# C:\temp\UOC\TrainData\edt\image_908.h5
# C:\temp\UOC\TrainData\edt\image_909.h5
# C:\temp\UOC\TrainData\edt\image_91.h5
# C:\temp\UOC\TrainData\edt\image_910.h5
# C:\temp\UOC\TrainData\edt\image_911.h5
# C:\temp\UOC\TrainData\edt\image_912.h5
# C:\temp\UOC\TrainData\edt\image_913.h5
# C:\temp\UOC\TrainData\edt\image_914.h5
# C:\temp\UOC\TrainData\edt\image_915.h5
# C:\temp\UOC\TrainData\edt\image_916.h5
# C:\temp\UOC\TrainData\edt\image_917.h5
# C:\temp\UOC\TrainData\edt\image_918.h5
# C:\temp\UOC\TrainData\edt\image_919.h5
# C:\temp\UOC\TrainData\edt\image_92.h5
# C:\temp\UOC\TrainData\edt\image_920.h5
# C:\temp\UOC\TrainData\edt\image_921.h5
# C:\temp\UOC\TrainData\edt\image_922.h5
# C:\temp\UOC\TrainData\edt\image_923.h5
# C:\temp\UOC\TrainData\edt\image_924.h5
# C:\temp\UOC\TrainData\edt\image_925.h5
# C:\temp\UOC\TrainData\edt\image_926.h5
# C:\temp\UOC\TrainData\edt\image_927.h5
# C:\temp\UOC\TrainData\edt\image_928.h5
# C:\temp\UOC\TrainData\edt\image_929.h5
# C:\temp\UOC\TrainData\edt\image_93.h5
# C:\temp\UOC\TrainData\edt\image_930.h5
# C:\temp\UOC\TrainData\edt\image_931.h5
# C:\temp\UOC\TrainData\edt\image_932.h5
# C:\temp\UOC\TrainData\edt\image_933.h5
# C:\temp\UOC\TrainData\edt\image_934.h5
# C:\temp\UOC\TrainData\edt\image_935.h5
# C:\temp\UOC\TrainData\edt\image_936.h5
# C:\temp\UOC\TrainData\edt\image_937.h5
# C:\temp\UOC\TrainData\edt\image_938.h5
# C:\temp\UOC\TrainData\edt\image_939.h5
# C:\temp\UOC\TrainData\edt\image_94.h5
# C:\temp\UOC\TrainData\edt\image_940.h5
# C:\temp\UOC\TrainData\edt\image_941.h5
# C:\temp\UOC\TrainData\edt\image_942.h5
# C:\temp\UOC\TrainData\edt\image_943.h5
# C:\temp\UOC\TrainData\edt\image_944.h5
# C:\temp\UOC\TrainData\edt\image_945.h5
# C:\temp\UOC\TrainData\edt\image_946.h5
# C:\temp\UOC\TrainData\edt\image_947.h5
# C:\temp\UOC\TrainData\edt\image_948.h5
# C:\temp\UOC\TrainData\edt\image_949.h5
# C:\temp\UOC\TrainData\edt\image_95.h5
# C:\temp\UOC\TrainData\edt\image_950.h5
# C:\temp\UOC\TrainData\edt\image_951.h5
# C:\temp\UOC\TrainData\edt\image_952.h5
# C:\temp\UOC\TrainData\edt\image_953.h5
# C:\temp\UOC\TrainData\edt\image_954.h5
# C:\temp\UOC\TrainData\edt\image_955.h5
# C:\temp\UOC\TrainData\edt\image_956.h5
# C:\temp\UOC\TrainData\edt\image_957.h5
# C:\temp\UOC\TrainData\edt\image_958.h5
# C:\temp\UOC\TrainData\edt\image_959.h5
# C:\temp\UOC\TrainData\edt\image_96.h5
# C:\temp\UOC\TrainData\edt\image_960.h5
# C:\temp\UOC\TrainData\edt\image_961.h5
# C:\temp\UOC\TrainData\edt\image_962.h5
# C:\temp\UOC\TrainData\edt\image_963.h5
# C:\temp\UOC\TrainData\edt\image_964.h5
# C:\temp\UOC\TrainData\edt\image_965.h5
# C:\temp\UOC\TrainData\edt\image_966.h5
# C:\temp\UOC\TrainData\edt\image_967.h5
# C:\temp\UOC\TrainData\edt\image_968.h5
# C:\temp\UOC\TrainData\edt\image_969.h5
# C:\temp\UOC\TrainData\edt\image_97.h5
# C:\temp\UOC\TrainData\edt\image_970.h5
# C:\temp\UOC\TrainData\edt\image_971.h5
# C:\temp\UOC\TrainData\edt\image_972.h5
# C:\temp\UOC\TrainData\edt\image_973.h5
# C:\temp\UOC\TrainData\edt\image_974.h5
# C:\temp\UOC\TrainData\edt\image_975.h5
# C:\temp\UOC\TrainData\edt\image_976.h5
# C:\temp\UOC\TrainData\edt\image_977.h5
# C:\temp\UOC\TrainData\edt\image_978.h5
# C:\temp\UOC\TrainData\edt\image_979.h5
# C:\temp\UOC\TrainData\edt\image_98.h5
# C:\temp\UOC\TrainData\edt\image_980.h5
# C:\temp\UOC\TrainData\edt\image_981.h5
# C:\temp\UOC\TrainData\edt\image_982.h5
# C:\temp\UOC\TrainData\edt\image_983.h5
# C:\temp\UOC\TrainData\edt\image_984.h5
# C:\temp\UOC\TrainData\edt\image_985.h5
# C:\temp\UOC\TrainData\edt\image_986.h5
# C:\temp\UOC\TrainData\edt\image_987.h5
# C:\temp\UOC\TrainData\edt\image_988.h5
# C:\temp\UOC\TrainData\edt\image_989.h5
# C:\temp\UOC\TrainData\edt\image_99.h5
# C:\temp\UOC\TrainData\edt\image_990.h5
# C:\temp\UOC\TrainData\edt\image_991.h5
# C:\temp\UOC\TrainData\edt\image_992.h5
# C:\temp\UOC\TrainData\edt\image_993.h5
# C:\temp\UOC\TrainData\edt\image_994.h5
# C:\temp\UOC\TrainData\edt\image_995.h5
# C:\temp\UOC\TrainData\edt\image_996.h5
# C:\temp\UOC\TrainData\edt\image_997.h5
# C:\temp\UOC\TrainData\edt\image_998.h5
# C:\temp\UOC\TrainData\edt\image_999.h5

# %%
cmap = cm.viridis
fichero_ejemplo = os.path.join (edt_folder, 'image_1.h5')
example_dt = h5py.File(fichero_ejemplo,'r')

# see what is inside that h5 file
print(example_dt.keys())

images = example_dt['img']
print(images.shape)

plt.subplots(7,2,figsize = (20,80))

for i in range(14):
    img_np = images[:,:,i]
    plt.subplot(7,2,1+i)
    #plt.figsize=(10,10)
    plt.imshow(img_np)
    plt.title("Banda " + str(i) ,fontdict={'fontsize': 20})
    plt.colorbar(shrink=0.5)
plt.show()
# Out:
# <KeysViewHDF5 ['img']>
# (128, 128, 14)
