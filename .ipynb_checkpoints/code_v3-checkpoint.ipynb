# %%
import pandas as pd
import numpy as np
import h5py
import glob
import matplotlib.pyplot as plt
# %matplotlib inline
import tensorflow as tf
import os
import richdem as rd
import cv2 as cv
import pickle

# %% [markdown]
# # Functions we need

# %%
from tensorflow.keras import backend as K

#normalization function
def normalize(x):
    num= x- x.min()
    den= x.max()-x.min()
    return num/den

def recall_m(y_true, y_pred):
    true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
    possible_positives = K.sum(K.round(K.clip(y_true, 0, 1)))
    recall = true_positives / (possible_positives + K.epsilon())
    return recall

# precision
def precision_m(y_true, y_pred):
    true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
    predicted_positives = K.sum(K.round(K.clip(y_pred, 0, 1)))
    precision = true_positives / (predicted_positives + K.epsilon())
    return precision

#f1 score
def f1_m(y_true, y_pred):
    precision = precision_m(y_true, y_pred)
    recall = recall_m(y_true, y_pred)
    return 2*((precision*recall)/(precision+recall+K.epsilon()))

# %% [markdown]
# # Prepare and explore the data

# %%
base_folder= r'C:\temp\UOC\TrainData'
TRAIN_PATH = base_folder + "\\img\*.h5"
TRAIN_MASK = base_folder + "\\mask\*.h5"

TRAIN_XX = np.zeros((3799, 128, 128, 7))
TRAIN_YY = np.zeros((3799, 128, 128, 1))
all_train = sorted(glob.glob(TRAIN_PATH))
all_mask = sorted(glob.glob(TRAIN_MASK))

# %%
for i, (img, mask) in enumerate(zip(all_train, all_mask)):
    print(i, img, mask)
    with h5py.File(img) as hdf:
        ls = list(hdf.keys())
        data = np.array(hdf.get('img'))

        # assign 0 for the nan value
        data[np.isnan(data)] = 0.000001
        
        #clean slope and dem
        dem= data[:, :, 13]
        slope= data[:, :, 12]
        k = 5 #smoothing factor
        dem_suavizado = cv.blur(dem,(k,k)) #reducción de ruido dem
        dem_suavizado= normalize(dem_suavizado)
        slope_suavizado = cv.blur(slope,(k,k)) #reducción de ruido slope
        slope_suavizado= normalize(slope_suavizado)
        
        #curvature
        dem_richdem = rd.rdarray(dem_suavizado, no_data=-9999) #convert to rdarray
        dem_curvature = rd.TerrainAttribute(dem_richdem, attrib="curvature")
        dem_curvature= normalize(dem_curvature)
        dem_planform_curvature = rd.TerrainAttribute(dem_richdem, attrib="planform_curvature")
        dem_planform_curvature= normalize(dem_planform_curvature)
        dem_profile_curvature = rd.TerrainAttribute(dem_richdem, attrib="profile_curvature")
        dem_profile_curvature= normalize(dem_profile_curvature)
    
        #BSI calculation
        BSI= ((data[:,:,10] + data[:,:,3]) - (data[:,:,7] + data[:,:,1]) / (data[:,:,10] + data[:,:,3]) + (data[:,:,7] + data[:,:,1]))
        BSI= normalize(BSI)

        # ndvi calculation
        data_red = data[:, :, 3]
        data_nir = data[:, :, 7]
        NDVI = np.divide(data_nir - data_red,np.add(data_nir, data_red))
        NDVI= normalize(NDVI)
        
        # final array
        TRAIN_XX[i, :, :, 0] = dem_suavizado
        TRAIN_XX[i, :, :, 1] = slope_suavizado
        TRAIN_XX[i, :, :, 2] = dem_curvature
        TRAIN_XX[i, :, :, 3] = dem_planform_curvature
        TRAIN_XX[i, :, :, 4] = dem_profile_curvature
        TRAIN_XX[i, :, :, 5] = BSI
        TRAIN_XX[i, :, :, 6] = NDVI
    
    
    with h5py.File(mask) as hdf:
        ls = list(hdf.keys())
        data=np.array(hdf.get('mask'))
        TRAIN_YY[i, :, :, 0] = data
# Out:
# 0 C:\temp\UOC\TrainData\img\image_1.h5 C:\temp\UOC\TrainData\mask\mask_1.h5
# Warning! No geotransform defined. Choosing a standard one! (Top left cell's top let corner at <0,0>; cells are 1x1.)
# Warning! No geotransform defined. Choosing a standard one! (Top left cell's top let corner at <0,0>; cells are 1x1.)
# Warning! No geotransform defined. Choosing a standard one! (Top left cell's top let corner at <0,0>; cells are 1x1.)
# Warning! No geotransform defined. Choosing a standard one! (Top left cell's top let corner at <0,0>; cells are 1x1.)
# Warning! No geotransform defined. Choosing a standard one! (Top left cell's top let corner at <0,0>; cells are 1x1.)
# Warning! No geotransform defined. Choosing a standard one! (Top left cell's top let corner at <0,0>; cells are 1x1.)
# 1 C:\temp\UOC\TrainData\img\image_10.h5 C:\temp\UOC\TrainData\mask\mask_10.h5
# Warning! No geotransform defined. Choosing a standard one! (Top left cell's top let corner at <0,0>; cells are 1x1.)
# Warning! No geotransform defined. Choosing a standard one! (Top left cell's top let corner at <0,0>; cells are 1x1.)
# Warning! No geotransform defined. Choosing a standard one! (Top left cell's top let corner at <0,0>; cells are 1x1.)
# Warning! No geotransform defined. Choosing a standard one! (Top left cell's top let corner at <0,0>; cells are 1x1.)
# Warning! No geotransform defined. Choosing a standard one! (Top left cell's top let corner at <0,0>; cells are 1x1.)
# Warning! No geotransform defined. Choosing a standard one! (Top left cell's top let corner at <0,0>; cells are 1x1.)
# 2 C:\temp\UOC\TrainData\img\image_100.h5 C:\temp\UOC\TrainData\mask\mask_100.h5
# Warning! No geotransform defined. Choosing a standard one! (Top left cell's top let corner at <0,0>; cells are 1x1.)
# Warning! No geotransform defined. Choosing a standard one! (Top left cell's top let corner at <0,0>; cells are 1x1.)
# Warning! No geotransform defined. Choosing a standard one! (Top left cell's top let corner at <0,0>; cells are 1x1.)
# Warning! No geotransform defined. Choosing a standard one! (Top left cell's top let corner at <0,0>; cells are 1x1.)
# Warning! No geotransform defined. Choosing a standard one! (Top left cell's top let corner at <0,0>; cells are 1x1.)
# Warning! No geotransform defined. Choosing a standard one! (Top left cell's top let corner at <0,0>; cells are 1x1.)
# 3 C:\temp\UOC\TrainData\img\image_1000.h5 C:\temp\UOC\TrainData\mask\mask_1000.h5
# Warning! No geotransform defined. Choosing a standard one! (Top left cell's top let corner at <0,0>; cells are 1x1.)
# Warning! No geotransform defined. Choosing a standard one! (Top left cell's top let corner at <0,0>; cells are 1x1.)
# Warning! No geotransform defined. Choosing a standard one! (Top left cell's top let corner at <0,0>; cells are 1x1.)
# Warning! No geotransform defined. Choosing a standard one! (Top left cell's top let corner at <0,0>; cells are 1x1.)
# Warning! No geotransform defined. Choosing a standard one! (Top left cell's top let corner at <0,0>; cells are 1x1.)
# Warning! No geotransform defined. Choosing a standard one! (Top left cell's top let corner at <0,0>; cells are 1x1.)
# 4 C:\temp\UOC\TrainData\img\image_1001.h5 C:\temp\UOC\TrainData\mask\mask_1001.h5
# Warning! No geotransform defined. Choosing a standard one! (Top left cell's top let corner at <0,0>; cells are 1x1.)
# Warning! No geotransform defined. Choosing a standard one! (Top left cell's top let corner at <0,0>; cells are 1x1.)
# Warning! No geotransform defined. Choosing a standard one! (Top left cell's top let corner at <0,0>; cells are 1x1.)
# Warning! No geotransform defined. Choosing a standard one! (Top left cell's top let corner at <0,0>; cells are 1x1.)
# Warning! No geotransform defined. Choosing a standard one! (Top left cell's top let corner at <0,0>; cells are 1x1.)
# Warning! No geotransform defined. Choosing a standard one! (Top left cell's top let corner at <0,0>; cells are 1x1.)
# 5 C:\temp\UOC\TrainData\img\image_1002.h5 C:\temp\UOC\TrainData\mask\mask_1002.h5
# Warning! No geotransform defined. Choosing a standard one! (Top left cell's top let corner at <0,0>; cells are 1x1.)
# Warning! No geotransform defined. Choosing a standard one! (Top left cell's top let corner at <0,0>; cells are 1x1.)
# Warning! No geotransform defined. Choosing a standard one! (Top left cell's top let corner at <0,0>; cells are 1x1.)
# Warning! No geotransform defined. Choosing a standard one! (Top left cell's top let corner at <0,0>; cells are 1x1.)
# Warning! No geotransform defined. Choosing a standard one! (Top left cell's top let corner at <0,0>; cells are 1x1.)
# Warning! No geotransform defined. Choosing a standard one! (Top left cell's top let corner at <0,0>; cells are 1x1.)
# 6 C:\temp\UOC\TrainData\img\image_1003.h5 C:\temp\UOC\TrainData\mask\mask_1003.h5
# Warning! No geotransform defined. Choosing a standard one! (Top left cell's top let corner at <0,0>; cells are 1x1.)
# Warning! No geotransform defined. Choosing a standard one! (Top left cell's top let corner at <0,0>; cells are 1x1.)
# Warning! No geotransform defined. Choosing a standard one! (Top left cell's top let corner at <0,0>; cells are 1x1.)
# Warning! No geotransform defined. Choosing a standard one! (Top left cell's top let corner at <0,0>; cells are 1x1.)
# Warning! No geotransform defined. Choosing a standard one! (Top left cell's top let corner at <0,0>; cells are 1x1.)
# Warning! No geotransform defined. Choosing a standard one! (Top left cell's top let corner at <0,0>; cells are 1x1.)
# 7 C:\temp\UOC\TrainData\img\image_1004.h5 C:\temp\UOC\TrainData\mask\mask_1004.h5
# Warning! No geotransform defined. Choosing a standard one! (Top left cell's top let corner at <0,0>; cells are 1x1.)
# Warning! No geotransform defined. Choosing a standard one! (Top left cell's top let corner at <0,0>; cells are 1x1.)
# Warning! No geotransform defined. Choosing a standard one! (Top left cell's top let corner at <0,0>; cells are 1x1.)
# Warning! No geotransform defined. Choosing a standard one! (Top left cell's top let corner at <0,0>; cells are 1x1.)
# Warning! No geotransform defined. Choosing a standard one! (Top left cell's top let corner at <0,0>; cells are 1x1.)
# Warning! No geotransform defined. Choosing a standard one! (Top left cell's top let corner at <0,0>; cells are 1x1.)
# 8 C:\temp\UOC\TrainData\img\image_1005.h5 C:\temp\UOC\TrainData\mask\mask_1005.h5
# Warning! No geotransform defined. Choosing a standard one! (Top left cell's top let corner at <0,0>; cells are 1x1.)
# Warning! No geotransform defined. Choosing a standard one! (Top left cell's top let corner at <0,0>; cells are 1x1.)
# Warning! No geotransform defined. Choosing a standard one! (Top left cell's top let corner at <0,0>; cells are 1x1.)
# Warning! No geotransform defined. Choosing a standard one! (Top left cell's top let corner at <0,0>; cells are 1x1.)
# Warning! No geotransform defined. Choosing a standard one! (Top left cell's top let corner at <0,0>; cells are 1x1.)
# Warning! No geotransform defined. Choosing a standard one! (Top left cell's top let corner at <0,0>; cells are 1x1.)
# 9 C:\temp\UOC\TrainData\img\image_1006.h5 C:\temp\UOC\TrainData\mask\mask_1006.h5
# Warning! No geotransform defined. Choosing a standard one! (Top left cell's top let corner at <0,0>; cells are 1x1.)
# Warning! No geotransform defined. Choosing a standard one! (Top left cell's top let corner at <0,0>; cells are 1x1.)
# Warning! No geotransform defined. Choosing a standard one! (Top left cell's top let corner at <0,0>; cells are 1x1.)
# Warning! No geotransform defined. Choosing a standard one! (Top left cell's top let corner at <0,0>; cells are 1x1.)
# Warning! No geotransform defined. Choosing a standard one! (Top left cell's top let corner at <0,0>; cells are 1x1.)
# Warning! No geotransform defined. Choosing a standard one! (Top left cell's top let corner at <0,0>; cells are 1x1.)
# 10 C:\temp\UOC\TrainData\img\image_1007.h5 C:\temp\UOC\TrainData\mask\mask_1007.h5
# Warning! No geotransform defined. Choosing a standard one! (Top left cell's top let corner at <0,0>; cells are 1x1.)
# Warning! No geotransform defined. Choosing a standard one! (Top left cell's top let corner at <0,0>; cells are 1x1.)
# Warning! No geotransform defined. Choosing a standard one! (Top left cell's top let corner at <0,0>; cells are 1x1.)
# Warning! No geotransform defined. Choosing a standard one! (Top left cell's top let corner at <0,0>; cells are 1x1.)
# Warning! No geotransform defined. Choosing a standard one! (Top left cell's top let corner at <0,0>; cells are 1x1.)
# Warning! No geotransform defined. Choosing a standard one! (Top left cell's top let corner at <0,0>; cells are 1x1.)
# 11 C:\temp\UOC\TrainData\img\image_1008.h5 C:\temp\UOC\TrainData\mask\mask_1008.h5
# Warning! No geotransform defined. Choosing a standard one! (Top left cell's top let corner at <0,0>; cells are 1x1.)
# Warning! No geotransform defined. Choosing a standard one! (Top left cell's top let corner at <0,0>; cells are 1x1.)
# Warning! No geotransform defined. Choosing a standard one! (Top left cell's top let corner at <0,0>; cells are 1x1.)
# Warning! No geotransform defined. Choosing a standard one! (Top left cell's top let corner at <0,0>; cells are 1x1.)
# Warning! No geotransform defined. Choosing a standard one! (Top left cell's top let corner at <0,0>; cells are 1x1.)
# Warning! No geotransform defined. Choosing a standard one! (Top left cell's top let corner at <0,0>; cells are 1x1.)
# 12 C:\temp\UOC\TrainData\img\image_1009.h5 C:\temp\UOC\TrainData\mask\mask_1009.h5
# Warning! No geotransform defined. Choosing a standard one! (Top left cell's top let corner at <0,0>; cells are 1x1.)
# Warning! No geotransform defined. Choosing a standard one! (Top left cell's top let corner at <0,0>; cells are 1x1.)
# Warning! No geotransform defined. Choosing a standard one! (Top left cell's top let corner at <0,0>; cells are 1x1.)
# Warning! No geotransform defined. Choosing a standard one! (Top left cell's top let corner at <0,0>; cells are 1x1.)
# Warning! No geotransform defined. Choosing a standard one! (Top left cell's top let corner at <0,0>; cells are 1x1.)
# Warning! No geotransform defined. Choosing a standard one! (Top left cell's top let corner at <0,0>; cells are 1x1.)
# 13 C:\temp\UOC\TrainData\img\image_101.h5 C:\temp\UOC\TrainData\mask\mask_101.h5
# Warning! No geotransform defined. Choosing a standard one! (Top left cell's top let corner at <0,0>; cells are 1x1.)
# Warning! No geotransform defined. Choosing a standard one! (Top left cell's top let corner at <0,0>; cells are 1x1.)
# Warning! No geotransform defined. Choosing a standard one! (Top left cell's top let corner at <0,0>; cells are 1x1.)
# Warning! No geotransform defined. Choosing a standard one! (Top left cell's top let corner at <0,0>; cells are 1x1.)
# Warning! No geotransform defined. Choosing a standard one! (Top left cell's top let corner at <0,0>; cells are 1x1.)
# Warning! No geotransform defined. Choosing a standard one! (Top left cell's top let corner at <0,0>; cells are 1x1.)
# 14 C:\temp\UOC\TrainData\img\image_1010.h5 C:\temp\UOC\TrainData\mask\mask_1010.h5
# Warning! No geotransform defined. Choosing a standard one! (Top left cell's top let corner at <0,0>; cells are 1x1.)
# Warning! No geotransform defined. Choosing a standard one! (Top left cell's top let corner at <0,0>; cells are 1x1.)
# Warning! No geotransform defined. Choosing a standard one! (Top left cell's top let corner at <0,0>; cells are 1x1.)
# Warning! No geotransform defined. Choosing a standard one! (Top left cell's top let corner at <0,0>; cells are 1x1.)
# Warning! No geotransform defined. Choosing a standard one! (Top left cell's top let corner at <0,0>; cells are 1x1.)
# Warning! No geotransform defined. Choosing a standard one! (Top left cell's top let corner at <0,0>; cells are 1x1.)
# 15 C:\temp\UOC\TrainData\img\image_1011.h5 C:\temp\UOC\TrainData\mask\mask_1011.h5
# Warning! No geotransform defined. Choosing a standard one! (Top left cell's top let corner at <0,0>; cells are 1x1.)
# Warning! No geotransform defined. Choosing a standard one! (Top left cell's top let corner at <0,0>; cells are 1x1.)
# Warning! No geotransform defined. Choosing a standard one! (Top left cell's top let corner at <0,0>; cells are 1x1.)
# Warning! No geotransform defined. Choosing a standard one! (Top left cell's top let corner at <0,0>; cells are 1x1.)
# Warning! No geotransform defined. Choosing a standard one! (Top left cell's top let corner at <0,0>; cells are 1x1.)
# Warning! No geotransform defined. Choosing a standard one! (Top left cell's top let corner at <0,0>; cells are 1x1.)
# 16 C:\temp\UOC\TrainData\img\image_1012.h5 C:\temp\UOC\TrainData\mask\mask_1012.h5
# Warning! No geotransform defined. Choosing a standard one! (Top left cell's top let corner at <0,0>; cells are 1x1.)
# Warning! No geotransform defined. Choosing a standard one! (Top left cell's top let corner at <0,0>; cells are 1x1.)
# Warning! No geotransform defined. Choosing a standard one! (Top left cell's top let corner at <0,0>; cells are 1x1.)
# Warning! No geotransform defined. Choosing a standard one! (Top left cell's top let corner at <0,0>; cells are 1x1.)
# Warning! No geotransform defined. Choosing a standard one! (Top left cell's top let corner at <0,0>; cells are 1x1.)
# Warning! No geotransform defined. Choosing a standard one! (Top left cell's top let corner at <0,0>; cells are 1x1.)
# 17 C:\temp\UOC\TrainData\img\image_1013.h5 C:\temp\UOC\TrainData\mask\mask_1013.h5
# Warning! No geotransform defined. Choosing a standard one! (Top left cell's top let corner at <0,0>; cells are 1x1.)
# Warning! No geotransform defined. Choosing a standard one! (Top left cell's top let corner at <0,0>; cells are 1x1.)
# Warning! No geotransform defined. Choosing a standard one! (Top left cell's top let corner at <0,0>; cells are 1x1.)
# Warning! No geotransform defined. Choosing a standard one! (Top left cell's top let corner at <0,0>; cells are 1x1.)
# Warning! No geotransform defined. Choosing a standard one! (Top left cell's top let corner at <0,0>; cells are 1x1.)
# Warning! No geotransform defined. Choosing a standard one! (Top left cell's top let corner at <0,0>; cells are 1x1.)
# 18 C:\temp\UOC\TrainData\img\image_1014.h5 C:\temp\UOC\TrainData\mask\mask_1014.h5
# Warning! No geotransform defined. Choosing a standard one! (Top left cell's top let corner at <0,0>; cells are 1x1.)
# Warning! No geotransform defined. Choosing a standard one! (Top left cell's top let corner at <0,0>; cells are 1x1.)
# Warning! No geotransform defined. Choosing a standard one! (Top left cell's top let corner at <0,0>; cells are 1x1.)
# Warning! No geotransform defined. Choosing a standard one! (Top left cell's top let corner at <0,0>; cells are 1x1.)
# Warning! No geotransform defined. Choosing a standard one! (Top left cell's top let corner at <0,0>; cells are 1x1.)
# Warning! No geotransform defined. Choosing a standard one! (Top left cell's top let corner at <0,0>; cells are 1x1.)
# 19 C:\temp\UOC\TrainData\img\image_1015.h5 C:\temp\UOC\TrainData\mask\mask_1015.h5
# Warning! No geotransform defined. Choosing a standard one! (Top left cell's top let corner at <0,0>; cells are 1x1.)
# Warning! No geotransform defined. Choosing a standard one! (Top left cell's top let corner at <0,0>; cells are 1x1.)
# Warning! No geotransform defined. Choosing a standard one! (Top left cell's top let corner at <0,0>; cells are 1x1.)
# Warning! No geotransform defined. Choosing a standard one! (Top left cell's top let corner at <0,0>; cells are 1x1.)
# Warning! No geotransform defined. Choosing a standard one! (Top left cell's top let corner at <0,0>; cells are 1x1.)
# Warning! No geotransform defined. Choosing a standard one! (Top left cell's top let corner at <0,0>; cells are 1x1.)
# 20 C:\temp\UOC\TrainData\img\image_1016.h5 C:\temp\UOC\TrainData\mask\mask_1016.h5
# Warning! No geotransform defined. Choosing a standard one! (Top left cell's top let corner at <0,0>; cells are 1x1.)
# Warning! No geotransform defined. Choosing a standard one! (Top left cell's top let corner at <0,0>; cells are 1x1.)
# Warning! No geotransform defined. Choosing a standard one! (Top left cell's top let corner at <0,0>; cells are 1x1.)
# Warning! No geotransform defined. Choosing a standard one! (Top left cell's top let corner at <0,0>; cells are 1x1.)
# Warning! No geotransform defined. Choosing a standard one! (Top left cell's top let corner at <0,0>; cells are 1x1.)
# Warning! No geotransform defined. Choosing a standard one! (Top left cell's top let corner at <0,0>; cells are 1x1.)
# 21 C:\temp\UOC\TrainData\img\image_1017.h5 C:\temp\UOC\TrainData\mask\mask_1017.h5
# Warning! No geotransform defined. Choosing a standard one! (Top left cell's top let corner at <0,0>; cells are 1x1.)
# Warning! No geotransform defined. Choosing a standard one! (Top left cell's top let corner at <0,0>; cells are 1x1.)
# Warning! No geotransform defined. Choosing a standard one! (Top left cell's top let corner at <0,0>; cells are 1x1.)
# Warning! No geotransform defined. Choosing a standard one! (Top left cell's top let corner at <0,0>; cells are 1x1.)
# Warning! No geotransform defined. Choosing a standard one! (Top left cell's top let corner at <0,0>; cells are 1x1.)
# Warning! No geotransform defined. Choosing a standard one! (Top left cell's top let corner at <0,0>; cells are 1x1.)
# 22 C:\temp\UOC\TrainData\img\image_1018.h5 C:\temp\UOC\TrainData\mask\mask_1018.h5
# Warning! No geotransform defined. Choosing a standard one! (Top left cell's top let corner at <0,0>; cells are 1x1.)
# Warning! No geotransform defined. Choosing a standard one! (Top left cell's top let corner at <0,0>; cells are 1x1.)
# Warning! No geotransform defined. Choosing a standard one! (Top left cell's top let corner at <0,0>; cells are 1x1.)
# Warning! No geotransform defined. Choosing a standard one! (Top left cell's top let corner at <0,0>; cells are 1x1.)
# Warning! No geotransform defined. Choosing a standard one! (Top left cell's top let corner at <0,0>; cells are 1x1.)
# Warning! No geotransform defined. Choosing a standard one! (Top left cell's top let corner at <0,0>; cells are 1x1.)
# 23 C:\temp\UOC\TrainData\img\image_1019.h5 C:\temp\UOC\TrainData\mask\mask_1019.h5
# Warning! No geotransform defined. Choosing a standard one! (Top left cell's top let corner at <0,0>; cells are 1x1.)
# Warning! No geotransform defined. Choosing a standard one! (Top left cell's top let corner at <0,0>; cells are 1x1.)
# Warning! No geotransform defined. Choosing a standard one! (Top left cell's top let corner at <0,0>; cells are 1x1.)
# Warning! No geotransform defined. Choosing a standard one! (Top left cell's top let corner at <0,0>; cells are 1x1.)
# Warning! No geotransform defined. Choosing a standard one! (Top left cell's top let corner at <0,0>; cells are 1x1.)
# Warning! No geotransform defined. Choosing a standard one! (Top left cell's top let corner at <0,0>; cells are 1x1.)
# 24 C:\temp\UOC\TrainData\img\image_102.h5 C:\temp\UOC\TrainData\mask\mask_102.h5
# Warning! No geotransform defined. Choosing a standard one! (Top left cell's top let corner at <0,0>; cells are 1x1.)
# Warning! No geotransform defined. Choosing a standard one! (Top left cell's top let corner at <0,0>; cells are 1x1.)
# Warning! No geotransform defined. Choosing a standard one! (Top left cell's top let corner at <0,0>; cells are 1x1.)
# Warning! No geotransform defined. Choosing a standard one! (Top left cell's top let corner at <0,0>; cells are 1x1.)
# Warning! No geotransform defined. Choosing a standard one! (Top left cell's top let corner at <0,0>; cells are 1x1.)
# Warning! No geotransform defined. Choosing a standard one! (Top left cell's top let corner at <0,0>; cells are 1x1.)
# 25 C:\temp\UOC\TrainData\img\image_1020.h5 C:\temp\UOC\TrainData\mask\mask_1020.h5
# Warning! No geotransform defined. Choosing a standard one! (Top left cell's top let corner at <0,0>; cells are 1x1.)
# Warning! No geotransform defined. Choosing a standard one! (Top left cell's top let corner at <0,0>; cells are 1x1.)
# Warning! No geotransform defined. Choosing a standard one! (Top left cell's top let corner at <0,0>; cells are 1x1.)
# Warning! No geotransform defined. Choosing a standard one! (Top left cell's top let corner at <0,0>; cells are 1x1.)
# Warning! No geotransform defined. Choosing a standard one! (Top left cell's top let corner at <0,0>; cells are 1x1.)
# Warning! No geotransform defined. Choosing a standard one! (Top left cell's top let corner at <0,0>; cells are 1x1.)
# 26 C:\temp\UOC\TrainData\img\image_1021.h5 C:\temp\UOC\TrainData\mask\mask_1021.h5
# Warning! No geotransform defined. Choosing a standard one! (Top left cell's top let corner at <0,0>; cells are 1x1.)
# Warning! No geotransform defined. Choosing a standard one! (Top left cell's top let corner at <0,0>; cells are 1x1.)
# Warning! No geotransform defined. Choosing a standard one! (Top left cell's top let corner at <0,0>; cells are 1x1.)
# Warning! No geotransform defined. Choosing a standard one! (Top left cell's top let corner at <0,0>; cells are 1x1.)
# Warning! No geotransform defined. Choosing a standard one! (Top left cell's top let corner at <0,0>; cells are 1x1.)
# Warning! No geotransform defined. Choosing a standard one! (Top left cell's top let corner at <0,0>; cells are 1x1.)
# 27 C:\temp\UOC\TrainData\img\image_1022.h5 C:\temp\UOC\TrainData\mask\mask_1022.h5
# Warning! No geotransform defined. Choosing a standard one! (Top left cell's top let corner at <0,0>; cells are 1x1.)
# Warning! No geotransform defined. Choosing a standard one! (Top left cell's top let corner at <0,0>; cells are 1x1.)
# Warning! No geotransform defined. Choosing a standard one! (Top left cell's top let corner at <0,0>; cells are 1x1.)
# Warning! No geotransform defined. Choosing a standard one! (Top left cell's top let corner at <0,0>; cells are 1x1.)
# Warning! No geotransform defined. Choosing a standard one! (Top left cell's top let corner at <0,0>; cells are 1x1.)
# Warning! No geotransform defined. Choosing a standard one! (Top left cell's top let corner at <0,0>; cells are 1x1.)
# 28 C:\temp\UOC\TrainData\img\image_1023.h5 C:\temp\UOC\TrainData\mask\mask_1023.h5
# Warning! No geotransform defined. Choosing a standard one! (Top left cell's top let corner at <0,0>; cells are 1x1.)
# Warning! No geotransform defined. Choosing a standard one! (Top left cell's top let corner at <0,0>; cells are 1x1.)
# Warning! No geotransform defined. Choosing a standard one! (Top left cell's top let corner at <0,0>; cells are 1x1.)
# Warning! No geotransform defined. Choosing a standard one! (Top left cell's top let corner at <0,0>; cells are 1x1.)
# Warning! No geotransform defined. Choosing a standard one! (Top left cell's top let corner at <0,0>; cells are 1x1.)
# Warning! No geotransform defined. Choosing a standard one! (Top left cell's top let corner at <0,0>; cells are 1x1.)
# 29 C:\temp\UOC\TrainData\img\image_1024.h5 C:\temp\UOC\TrainData\mask\mask_1024.h5
# Warning! No geotransform defined. Choosing a standard one! (Top left cell's top let corner at <0,0>; cells are 1x1.)
# Warning! No geotransform defined. Choosing a standard one! (Top left cell's top let corner at <0,0>; cells are 1x1.)
# Warning! No geotransform defined. Choosing a standard one! (Top left cell's top let corner at <0,0>; cells are 1x1.)
# Warning! No geotransform defined. Choosing a standard one! (Top left cell's top let corner at <0,0>; cells are 1x1.)
# Warning! No geotransform defined. Choosing a standard one! (Top left cell's top let corner at <0,0>; cells are 1x1.)
# Warning! No geotransform defined. Choosing a standard one! (Top left cell's top let corner at <0,0>; cells are 1x1.)
# 30 C:\temp\UOC\TrainData\img\image_1025.h5 C:\temp\UOC\TrainData\mask\mask_1025.h5
# Warning! No geotransform defined. Choosing a standard one! (Top left cell's top let corner at <0,0>; cells are 1x1.)
# Warning! No geotransform defined. Choosing a standard one! (Top left cell's top let corner at <0,0>; cells are 1x1.)
# Warning! No geotransform defined. Choosing a standard one! (Top left cell's top let corner at <0,0>; cells are 1x1.)
# Warning! No geotransform defined. Choosing a standard one! (Top left cell's top let corner at <0,0>; cells are 1x1.)
# Warning! No geotransform defined. Choosing a standard one! (Top left cell's top let corner at <0,0>; cells are 1x1.)
# Warning! No geotransform defined. Choosing a standard one! (Top left cell's top let corner at <0,0>; cells are 1x1.)
# 31 C:\temp\UOC\TrainData\img\image_1026.h5 C:\temp\UOC\TrainData\mask\mask_1026.h5
# Warning! No geotransform defined. Choosing a standard one! (Top left cell's top let corner at <0,0>; cells are 1x1.)
# Warning! No geotransform defined. Choosing a standard one! (Top left cell's top let corner at <0,0>; cells are 1x1.)
# Warning! No geotransform defined. Choosing a standard one! (Top left cell's top let corner at <0,0>; cells are 1x1.)
# Warning! No geotransform defined. Choosing a standard one! (Top left cell's top let corner at <0,0>; cells are 1x1.)
# Warning! No geotransform defined. Choosing a standard one! (Top left cell's top let corner at <0,0>; cells are 1x1.)
# Warning! No geotransform defined. Choosing a standard one! (Top left cell's top let corner at <0,0>; cells are 1x1.)
# 32 C:\temp\UOC\TrainData\img\image_1027.h5 C:\temp\UOC\TrainData\mask\mask_1027.h5
# Warning! No geotransform defined. Choosing a standard one! (Top left cell's top let corner at <0,0>; cells are 1x1.)
# Warning! No geotransform defined. Choosing a standard one! (Top left cell's top let corner at <0,0>; cells are 1x1.)
# Warning! No geotransform defined. Choosing a standard one! (Top left cell's top let corner at <0,0>; cells are 1x1.)
# Warning! No geotransform defined. Choosing a standard one! (Top left cell's top let corner at <0,0>; cells are 1x1.)
# Warning! No geotransform defined. Choosing a standard one! (Top left cell's top let corner at <0,0>; cells are 1x1.)
# Warning! No geotransform defined. Choosing a standard one! (Top left cell's top let corner at <0,0>; cells are 1x1.)
# 33 C:\temp\UOC\TrainData\img\image_1028.h5 C:\temp\UOC\TrainData\mask\mask_1028.h5
# Warning! No geotransform defined. Choosing a standard one! (Top left cell's top let corner at <0,0>; cells are 1x1.)
# Warning! No geotransform defined. Choosing a standard one! (Top left cell's top let corner at <0,0>; cells are 1x1.)
# Warning! No geotransform defined. Choosing a standard one! (Top left cell's top let corner at <0,0>; cells are 1x1.)
# Warning! No geotransform defined. Choosing a standard one! (Top left cell's top let corner at <0,0>; cells are 1x1.)
# Warning! No geotransform defined. Choosing a standard one! (Top left cell's top let corner at <0,0>; cells are 1x1.)
# Warning! No geotransform defined. Choosing a standard one! (Top left cell's top let corner at <0,0>; cells are 1x1.)
# 34 C:\temp\UOC\TrainData\img\image_1029.h5 C:\temp\UOC\TrainData\mask\mask_1029.h5
# Warning! No geotransform defined. Choosing a standard one! (Top left cell's top let corner at <0,0>; cells are 1x1.)
# Warning! No geotransform defined. Choosing a standard one! (Top left cell's top let corner at <0,0>; cells are 1x1.)
# Warning! No geotransform defined. Choosing a standard one! (Top left cell's top let corner at <0,0>; cells are 1x1.)
# Warning! No geotransform defined. Choosing a standard one! (Top left cell's top let corner at <0,0>; cells are 1x1.)
# Warning! No geotransform defined. Choosing a standard one! (Top left cell's top let corner at <0,0>; cells are 1x1.)
# Warning! No geotransform defined. Choosing a standard one! (Top left cell's top let corner at <0,0>; cells are 1x1.)
# 35 C:\temp\UOC\TrainData\img\image_103.h5 C:\temp\UOC\TrainData\mask\mask_103.h5
# Warning! No geotransform defined. Choosing a standard one! (Top left cell's top let corner at <0,0>; cells are 1x1.)
# Warning! No geotransform defined. Choosing a standard one! (Top left cell's top let corner at <0,0>; cells are 1x1.)
# Warning! No geotransform defined. Choosing a standard one! (Top left cell's top let corner at <0,0>; cells are 1x1.)
# Warning! No geotransform defined. Choosing a standard one! (Top left cell's top let corner at <0,0>; cells are 1x1.)
# Warning! No geotransform defined. Choosing a standard one! (Top left cell's top let corner at <0,0>; cells are 1x1.)
# Warning! No geotransform defined. Choosing a standard one! (Top left cell's top let corner at <0,0>; cells are 1x1.)
# 36 C:\temp\UOC\TrainData\img\image_1030.h5 C:\temp\UOC\TrainData\mask\mask_1030.h5
# Warning! No geotransform defined. Choosing a standard one! (Top left cell's top let corner at <0,0>; cells are 1x1.)
# Warning! No geotransform defined. Choosing a standard one! (Top left cell's top let corner at <0,0>; cells are 1x1.)
# Warning! No geotransform defined. Choosing a standard one! (Top left cell's top let corner at <0,0>; cells are 1x1.)
# Warning! No geotransform defined. Choosing a standard one! (Top left cell's top let corner at <0,0>; cells are 1x1.)
# Warning! No geotransform defined. Choosing a standard one! (Top left cell's top let corner at <0,0>; cells are 1x1.)
# Warning! No geotransform defined. Choosing a standard one! (Top left cell's top let corner at <0,0>; cells are 1x1.)
# 37 C:\temp\UOC\TrainData\img\image_1031.h5 C:\temp\UOC\TrainData\mask\mask_1031.h5
# Warning! No geotransform defined. Choosing a standard one! (Top left cell's top let corner at <0,0>; cells are 1x1.)
# Warning! No geotransform defined. Choosing a standard one! (Top left cell's top let corner at <0,0>; cells are 1x1.)
# Warning! No geotransform defined. Choosing a standard one! (Top left cell's top let corner at <0,0>; cells are 1x1.)
# Warning! No geotransform defined. Choosing a standard one! (Top left cell's top let corner at <0,0>; cells are 1x1.)
# Warning! No geotransform defined. Choosing a standard one! (Top left cell's top let corner at <0,0>; cells are 1x1.)
# Warning! No geotransform defined. Choosing a standard one! (Top left cell's top let corner at <0,0>; cells are 1x1.)
# 38 C:\temp\UOC\TrainData\img\image_1032.h5 C:\temp\UOC\TrainData\mask\mask_1032.h5
# Warning! No geotransform defined. Choosing a standard one! (Top left cell's top let corner at <0,0>; cells are 1x1.)
# Warning! No geotransform defined. Choosing a standard one! (Top left cell's top let corner at <0,0>; cells are 1x1.)
# Warning! No geotransform defined. Choosing a standard one! (Top left cell's top let corner at <0,0>; cells are 1x1.)
# Warning! No geotransform defined. Choosing a standard one! (Top left cell's top let corner at <0,0>; cells are 1x1.)
# Warning! No geotransform defined. Choosing a standard one! (Top left cell's top let corner at <0,0>; cells are 1x1.)
# Warning! No geotransform defined. Choosing a standard one! (Top left cell's top let corner at <0,0>; cells are 1x1.)
# 39 C:\temp\UOC\TrainData\img\image_1033.h5 C:\temp\UOC\TrainData\mask\mask_1033.h5
# Warning! No geotransform defined. Choosing a standard one! (Top left cell's top let corner at <0,0>; cells are 1x1.)
# Warning! No geotransform defined. Choosing a standard one! (Top left cell's top let corner at <0,0>; cells are 1x1.)
# Warning! No geotransform defined. Choosing a standard one! (Top left cell's top let corner at <0,0>; cells are 1x1.)
# Warning! No geotransform defined. Choosing a standard one! (Top left cell's top let corner at <0,0>; cells are 1x1.)
# Warning! No geotransform defined. Choosing a standard one! (Top left cell's top let corner at <0,0>; cells are 1x1.)
# Warning! No geotransform defined. Choosing a standard one! (Top left cell's top let corner at <0,0>; cells are 1x1.)
# 40 C:\temp\UOC\TrainData\img\image_1034.h5 C:\temp\UOC\TrainData\mask\mask_1034.h5
# Warning! No geotransform defined. Choosing a standard one! (Top left cell's top let corner at <0,0>; cells are 1x1.)
# Warning! No geotransform defined. Choosing a standard one! (Top left cell's top let corner at <0,0>; cells are 1x1.)
# Warning! No geotransform defined. Choosing a standard one! (Top left cell's top let corner at <0,0>; cells are 1x1.)
# Warning! No geotransform defined. Choosing a standard one! (Top left cell's top let corner at <0,0>; cells are 1x1.)
# Warning! No geotransform defined. Choosing a standard one! (Top left cell's top let corner at <0,0>; cells are 1x1.)
# Warning! No geotransform defined. Choosing a standard one! (Top left cell's top let corner at <0,0>; cells are 1x1.)
# 41 C:\temp\UOC\TrainData\img\image_1035.h5 C:\temp\UOC\TrainData\mask\mask_1035.h5
# Warning! No geotransform defined. Choosing a standard one! (Top left cell's top let corner at <0,0>; cells are 1x1.)
# Warning! No geotransform defined. Choosing a standard one! (Top left cell's top let corner at <0,0>; cells are 1x1.)
# Warning! No geotransform defined. Choosing a standard one! (Top left cell's top let corner at <0,0>; cells are 1x1.)
# Warning! No geotransform defined. Choosing a standard one! (Top left cell's top let corner at <0,0>; cells are 1x1.)
# Warning! No geotransform defined. Choosing a standard one! (Top left cell's top let corner at <0,0>; cells are 1x1.)
# Warning! No geotransform defined. Choosing a standard one! (Top left cell's top let corner at <0,0>; cells are 1x1.)
# 42 C:\temp\UOC\TrainData\img\image_1036.h5 C:\temp\UOC\TrainData\mask\mask_1036.h5
# Warning! No geotransform defined. Choosing a standard one! (Top left cell's top let corner at <0,0>; cells are 1x1.)
# Warning! No geotransform defined. Choosing a standard one! (Top left cell's top let corner at <0,0>; cells are 1x1.)
# Warning! No geotransform defined. Choosing a standard one! (Top left cell's top let corner at <0,0>; cells are 1x1.)
# Warning! No geotransform defined. Choosing a standard one! (Top left cell's top let corner at <0,0>; cells are 1x1.)
# Warning! No geotransform defined. Choosing a standard one! (Top left cell's top let corner at <0,0>; cells are 1x1.)
# Warning! No geotransform defined. Choosing a standard one! (Top left cell's top let corner at <0,0>; cells are 1x1.)
# 43 C:\temp\UOC\TrainData\img\image_1037.h5 C:\temp\UOC\TrainData\mask\mask_1037.h5
# Warning! No geotransform defined. Choosing a standard one! (Top left cell's top let corner at <0,0>; cells are 1x1.)
# Warning! No geotransform defined. Choosing a standard one! (Top left cell's top let corner at <0,0>; cells are 1x1.)
# Warning! No geotransform defined. Choosing a standard one! (Top left cell's top let corner at <0,0>; cells are 1x1.)
# Warning! No geotransform defined. Choosing a standard one! (Top left cell's top let corner at <0,0>; cells are 1x1.)
# Warning! No geotransform defined. Choosing a standard one! (Top left cell's top let corner at <0,0>; cells are 1x1.)
# Warning! No geotransform defined. Choosing a standard one! (Top left cell's top let corner at <0,0>; cells are 1x1.)
# 44 C:\temp\UOC\TrainData\img\image_1038.h5 C:\temp\UOC\TrainData\mask\mask_1038.h5
# Warning! No geotransform defined. Choosing a standard one! (Top left cell's top let corner at <0,0>; cells are 1x1.)
# Warning! No geotransform defined. Choosing a standard one! (Top left cell's top let corner at <0,0>; cells are 1x1.)
# Warning! No geotransform defined. Choosing a standard one! (Top left cell's top let corner at <0,0>; cells are 1x1.)
# Warning! No geotransform defined. Choosing a standard one! (Top left cell's top let corner at <0,0>; cells are 1x1.)
# Warning! No geotransform defined. Choosing a standard one! (Top left cell's top let corner at <0,0>; cells are 1x1.)
# Warning! No geotransform defined. Choosing a standard one! (Top left cell's top let corner at <0,0>; cells are 1x1.)
# 45 C:\temp\UOC\TrainData\img\image_1039.h5 C:\temp\UOC\TrainData\mask\mask_1039.h5
# Warning! No geotransform defined. Choosing a standard one! (Top left cell's top let corner at <0,0>; cells are 1x1.)
# Warning! No geotransform defined. Choosing a standard one! (Top left cell's top let corner at <0,0>; cells are 1x1.)
# Warning! No geotransform defined. Choosing a standard one! (Top left cell's top let corner at <0,0>; cells are 1x1.)
# Warning! No geotransform defined. Choosing a standard one! (Top left cell's top let corner at <0,0>; cells are 1x1.)
# Warning! No geotransform defined. Choosing a standard one! (Top left cell's top let corner at <0,0>; cells are 1x1.)
# Warning! No geotransform defined. Choosing a standard one! (Top left cell's top let corner at <0,0>; cells are 1x1.)
# 46 C:\temp\UOC\TrainData\img\image_104.h5 C:\temp\UOC\TrainData\mask\mask_104.h5
# Warning! No geotransform defined. Choosing a standard one! (Top left cell's top let corner at <0,0>; cells are 1x1.)
# Warning! No geotransform defined. Choosing a standard one! (Top left cell's top let corner at <0,0>; cells are 1x1.)
# Warning! No geotransform defined. Choosing a standard one! (Top left cell's top let corner at <0,0>; cells are 1x1.)
# Warning! No geotransform defined. Choosing a standard one! (Top left cell's top let corner at <0,0>; cells are 1x1.)
# Warning! No geotransform defined. Choosing a standard one! (Top left cell's top let corner at <0,0>; cells are 1x1.)
# Warning! No geotransform defined. Choosing a standard one! (Top left cell's top let corner at <0,0>; cells are 1x1.)
# 47 C:\temp\UOC\TrainData\img\image_1040.h5 C:\temp\UOC\TrainData\mask\mask_1040.h5
# Warning! No geotransform defined. Choosing a standard one! (Top left cell's top let corner at <0,0>; cells are 1x1.)
# Warning! No geotransform defined. Choosing a standard one! (Top left cell's top let corner at <0,0>; cells are 1x1.)
# Warning! No geotransform defined. Choosing a standard one! (Top left cell's top let corner at <0,0>; cells are 1x1.)
# Warning! No geotransform defined. Choosing a standard one! (Top left cell's top let corner at <0,0>; cells are 1x1.)
# Warning! No geotransform defined. Choosing a standard one! (Top left cell's top let corner at <0,0>; cells are 1x1.)
# Warning! No geotransform defined. Choosing a standard one! (Top left cell's top let corner at <0,0>; cells are 1x1.)
# 48 C:\temp\UOC\TrainData\img\image_1041.h5 C:\temp\UOC\TrainData\mask\mask_1041.h5
# Warning! No geotransform defined. Choosing a standard one! (Top left cell's top let corner at <0,0>; cells are 1x1.)
# Warning! No geotransform defined. Choosing a standard one! (Top left cell's top let corner at <0,0>; cells are 1x1.)
# Warning! No geotransform defined. Choosing a standard one! (Top left cell's top let corner at <0,0>; cells are 1x1.)
# Warning! No geotransform defined. Choosing a standard one! (Top left cell's top let corner at <0,0>; cells are 1x1.)
# Warning! No geotransform defined. Choosing a standard one! (Top left cell's top let corner at <0,0>; cells are 1x1.)
# Warning! No geotransform defined. Choosing a standard one! (Top left cell's top let corner at <0,0>; cells are 1x1.)
# 49 C:\temp\UOC\TrainData\img\image_1042.h5 C:\temp\UOC\TrainData\mask\mask_1042.h5
# Warning! No geotransform defined. Choosing a standard one! (Top left cell's top let corner at <0,0>; cells are 1x1.)
# Warning! No geotransform defined. Choosing a standard one! (Top left cell's top let corner at <0,0>; cells are 1x1.)
# Warning! No geotransform defined. Choosing a standard one! (Top left cell's top let corner at <0,0>; cells are 1x1.)
# Warning! No geotransform defined. Choosing a standard one! (Top left cell's top let corner at <0,0>; cells are 1x1.)
# Warning! No geotransform defined. Choosing a standard one! (Top left cell's top let corner at <0,0>; cells are 1x1.)
# Warning! No geotransform defined. Choosing a standard one! (Top left cell's top let corner at <0,0>; cells are 1x1.)
# 50 C:\temp\UOC\TrainData\img\image_1043.h5 C:\temp\UOC\TrainData\mask\mask_1043.h5
# Warning! No geotransform defined. Choosing a standard one! (Top left cell's top let corner at <0,0>; cells are 1x1.)
# Warning! No geotransform defined. Choosing a standard one! (Top left cell's top let corner at <0,0>; cells are 1x1.)
# Warning! No geotransform defined. Choosing a standard one! (Top left cell's top let corner at <0,0>; cells are 1x1.)
# Warning! No geotransform defined. Choosing a standard one! (Top left cell's top let corner at <0,0>; cells are 1x1.)
# Warning! No geotransform defined. Choosing a standard one! (Top left cell's top let corner at <0,0>; cells are 1x1.)
# Warning! No geotransform defined. Choosing a standard one! (Top left cell's top let corner at <0,0>; cells are 1x1.)
# 51 C:\temp\UOC\TrainData\img\image_1044.h5 C:\temp\UOC\TrainData\mask\mask_1044.h5
# Warning! No geotransform defined. Choosing a standard one! (Top left cell's top let corner at <0,0>; cells are 1x1.)
# Warning! No geotransform defined. Choosing a standard one! (Top left cell's top let corner at <0,0>; cells are 1x1.)
# Warning! No geotransform defined. Choosing a standard one! (Top left cell's top let corner at <0,0>; cells are 1x1.)
# Warning! No geotransform defined. Choosing a standard one! (Top left cell's top let corner at <0,0>; cells are 1x1.)
# Warning! No geotransform defined. Choosing a standard one! (Top left cell's top let corner at <0,0>; cells are 1x1.)
# Warning! No geotransform defined. Choosing a standard one! (Top left cell's top let corner at <0,0>; cells are 1x1.)
# 52 C:\temp\UOC\TrainData\img\image_1045.h5 C:\temp\UOC\TrainData\mask\mask_1045.h5
# Warning! No geotransform defined. Choosing a standard one! (Top left cell's top let corner at <0,0>; cells are 1x1.)
# Warning! No geotransform defined. Choosing a standard one! (Top left cell's top let corner at <0,0>; cells are 1x1.)
# Warning! No geotransform defined. Choosing a standard one! (Top left cell's top let corner at <0,0>; cells are 1x1.)
# Warning! No geotransform defined. Choosing a standard one! (Top left cell's top let corner at <0,0>; cells are 1x1.)
# Warning! No geotransform defined. Choosing a standard one! (Top left cell's top let corner at <0,0>; cells are 1x1.)
# Warning! No geotransform defined. Choosing a standard one! (Top left cell's top let corner at <0,0>; cells are 1x1.)
# 53 C:\temp\UOC\TrainData\img\image_1046.h5 C:\temp\UOC\TrainData\mask\mask_1046.h5
# Warning! No geotransform defined. Choosing a standard one! (Top left cell's top let corner at <0,0>; cells are 1x1.)
# Warning! No geotransform defined. Choosing a standard one! (Top left cell's top let corner at <0,0>; cells are 1x1.)
# Warning! No geotransform defined. Choosing a standard one! (Top left cell's top let corner at <0,0>; cells are 1x1.)
# Warning! No geotransform defined. Choosing a standard one! (Top left cell's top let corner at <0,0>; cells are 1x1.)
# Warning! No geotransform defined. Choosing a standard one! (Top left cell's top let corner at <0,0>; cells are 1x1.)
# Warning! No geotransform defined. Choosing a standard one! (Top left cell's top let corner at <0,0>; cells are 1x1.)
# 54 C:\temp\UOC\TrainData\img\image_1047.h5 C:\temp\UOC\TrainData\mask\mask_1047.h5
# Warning! No geotransform defined. Choosing a standard one! (Top left cell's top let corner at <0,0>; cells are 1x1.)
# Warning! No geotransform defined. Choosing a standard one! (Top left cell's top let corner at <0,0>; cells are 1x1.)
# Warning! No geotransform defined. Choosing a standard one! (Top left cell's top let corner at <0,0>; cells are 1x1.)
# Warning! No geotransform defined. Choosing a standard one! (Top left cell's top let corner at <0,0>; cells are 1x1.)
# Warning! No geotransform defined. Choosing a standard one! (Top left cell's top let corner at <0,0>; cells are 1x1.)
# Warning! No geotransform defined. Choosing a standard one! (Top left cell's top let corner at <0,0>; cells are 1x1.)
# 55 C:\temp\UOC\TrainData\img\image_1048.h5 C:\temp\UOC\TrainData\mask\mask_1048.h5
# Warning! No geotransform defined. Choosing a standard one! (Top left cell's top let corner at <0,0>; cells are 1x1.)
# Warning! No geotransform defined. Choosing a standard one! (Top left cell's top let corner at <0,0>; cells are 1x1.)
# Warning! No geotransform defined. Choosing a standard one! (Top left cell's top let corner at <0,0>; cells are 1x1.)
# Warning! No geotransform defined. Choosing a standard one! (Top left cell's top let corner at <0,0>; cells are 1x1.)
# Warning! No geotransform defined. Choosing a standard one! (Top left cell's top let corner at <0,0>; cells are 1x1.)
# Warning! No geotransform defined. Choosing a standard one! (Top left cell's top let corner at <0,0>; cells are 1x1.)
# 56 C:\temp\UOC\TrainData\img\image_1049.h5 C:\temp\UOC\TrainData\mask\mask_1049.h5
# Warning! No geotransform defined. Choosing a standard one! (Top left cell's top let corner at <0,0>; cells are 1x1.)
# Warning! No geotransform defined. Choosing a standard one! (Top left cell's top let corner at <0,0>; cells are 1x1.)
# Warning! No geotransform defined. Choosing a standard one! (Top left cell's top let corner at <0,0>; cells are 1x1.)
# Warning! No geotransform defined. Choosing a standard one! (Top left cell's top let corner at <0,0>; cells are 1x1.)
# Warning! No geotransform defined. Choosing a standard one! (Top left cell's top let corner at <0,0>; cells are 1x1.)
# Warning! No geotransform defined. Choosing a standard one! (Top left cell's top let corner at <0,0>; cells are 1x1.)
# 57 C:\temp\UOC\TrainData\img\image_105.h5 C:\temp\UOC\TrainData\mask\mask_105.h5
# Warning! No geotransform defined. Choosing a standard one! (Top left cell's top let corner at <0,0>; cells are 1x1.)
# Warning! No geotransform defined. Choosing a standard one! (Top left cell's top let corner at <0,0>; cells are 1x1.)
# Warning! No geotransform defined. Choosing a standard one! (Top left cell's top let corner at <0,0>; cells are 1x1.)
# Warning! No geotransform defined. Choosing a standard one! (Top left cell's top let corner at <0,0>; cells are 1x1.)
# Warning! No geotransform defined. Choosing a standard one! (Top left cell's top let corner at <0,0>; cells are 1x1.)
# Warning! No geotransform defined. Choosing a standard one! (Top left cell's top let corner at <0,0>; cells are 1x1.)
# 58 C:\temp\UOC\TrainData\img\image_1050.h5 C:\temp\UOC\TrainData\mask\mask_1050.h5
# Warning! No geotransform defined. Choosing a standard one! (Top left cell's top let corner at <0,0>; cells are 1x1.)
# Warning! No geotransform defined. Choosing a standard one! (Top left cell's top let corner at <0,0>; cells are 1x1.)
# Warning! No geotransform defined. Choosing a standard one! (Top left cell's top let corner at <0,0>; cells are 1x1.)
# Warning! No geotransform defined. Choosing a standard one! (Top left cell's top let corner at <0,0>; cells are 1x1.)
# Warning! No geotransform defined. Choosing a standard one! (Top left cell's top let corner at <0,0>; cells are 1x1.)
# Warning! No geotransform defined. Choosing a standard one! (Top left cell's top let corner at <0,0>; cells are 1x1.)
# 59 C:\temp\UOC\TrainData\img\image_1051.h5 C:\temp\UOC\TrainData\mask\mask_1051.h5
# Warning! No geotransform defined. Choosing a standard one! (Top left cell's top let corner at <0,0>; cells are 1x1.)
# Warning! No geotransform defined. Choosing a standard one! (Top left cell's top let corner at <0,0>; cells are 1x1.)
# Warning! No geotransform defined. Choosing a standard one! (Top left cell's top let corner at <0,0>; cells are 1x1.)
# Warning! No geotransform defined. Choosing a standard one! (Top left cell's top let corner at <0,0>; cells are 1x1.)
# Warning! No geotransform defined. Choosing a standard one! (Top left cell's top let corner at <0,0>; cells are 1x1.)
# Warning! No geotransform defined. Choosing a standard one! (Top left cell's top let corner at <0,0>; cells are 1x1.)
# 60 C:\temp\UOC\TrainData\img\image_1052.h5 C:\temp\UOC\TrainData\mask\mask_1052.h5
# Warning! No geotransform defined. Choosing a standard one! (Top left cell's top let corner at <0,0>; cells are 1x1.)
# Warning! No geotransform defined. Choosing a standard one! (Top left cell's top let corner at <0,0>; cells are 1x1.)
# Warning! No geotransform defined. Choosing a standard one! (Top left cell's top let corner at <0,0>; cells are 1x1.)
# Warning! No geotransform defined. Choosing a standard one! (Top left cell's top let corner at <0,0>; cells are 1x1.)
# Warning! No geotransform defined. Choosing a standard one! (Top left cell's top let corner at <0,0>; cells are 1x1.)
# Warning! No geotransform defined. Choosing a standard one! (Top left cell's top let corner at <0,0>; cells are 1x1.)
# 61 C:\temp\UOC\TrainData\img\image_1053.h5 C:\temp\UOC\TrainData\mask\mask_1053.h5
# ...
# Warning! No geotransform defined. Choosing a standard one! (Top left cell's top let corner at <0,0>; cells are 1x1.)
# Warning! No geotransform defined. Choosing a standard one! (Top left cell's top let corner at <0,0>; cells are 1x1.)
# Warning! No geotransform defined. Choosing a standard one! (Top left cell's top let corner at <0,0>; cells are 1x1.)
# Warning! No geotransform defined. Choosing a standard one! (Top left cell's top let corner at <0,0>; cells are 1x1.)
# Warning! No geotransform defined. Choosing a standard one! (Top left cell's top let corner at <0,0>; cells are 1x1.)
# Warning! No geotransform defined. Choosing a standard one! (Top left cell's top let corner at <0,0>; cells are 1x1.)
# 2031 C:\temp\UOC\TrainData\img\image_2827.h5 C:\temp\UOC\TrainData\mask\mask_2827.h5
# Warning! No geotransform defined. Choosing a standard one! (Top left cell's top let corner at <0,0>; cells are 1x1.)
# Warning! No geotransform defined. Choosing a standard one! (Top left cell's top let corner at <0,0>; cells are 1x1.)
# Warning! No geotransform defined. Choosing a standard one! (Top left cell's top let corner at <0,0>; cells are 1x1.)
# Warning! No geotransform defined. Choosing a standard one! (Top left cell's top let corner at <0,0>; cells are 1x1.)
# Warning! No geotransform defined. Choosing a standard one! (Top left cell's top let corner at <0,0>; cells are 1x1.)
# Warning! No geotransform defined. Choosing a standard one! (Top left cell's top let corner at <0,0>; cells are 1x1.)
# 2032 C:\temp\UOC\TrainData\img\image_2828.h5 C:\temp\UOC\TrainData\mask\mask_2828.h5
# Warning! No geotransform defined. Choosing a standard one! (Top left cell's top let corner at <0,0>; cells are 1x1.)
# Warning! No geotransform defined. Choosing a standard one! (Top left cell's top let corner at <0,0>; cells are 1x1.)
# Warning! No geotransform defined. Choosing a standard one! (Top left cell's top let corner at <0,0>; cells are 1x1.)
# Warning! No geotransform defined. Choosing a standard one! (Top left cell's top let corner at <0,0>; cells are 1x1.)
# Warning! No geotransform defined. Choosing a standard one! (Top left cell's top let corner at <0,0>; cells are 1x1.)
# Warning! No geotransform defined. Choosing a standard one! (Top left cell's top let corner at <0,0>; cells are 1x1.)
# 2033 C:\temp\UOC\TrainData\img\image_2829.h5 C:\temp\UOC\TrainData\mask\mask_2829.h5
# Warning! No geotransform defined. Choosing a standard one! (Top left cell's top let corner at <0,0>; cells are 1x1.)
# Warning! No geotransform defined. Choosing a standard one! (Top left cell's top let corner at <0,0>; cells are 1x1.)
# Warning! No geotransform defined. Choosing a standard one! (Top left cell's top let corner at <0,0>; cells are 1x1.)
# Warning! No geotransform defined. Choosing a standard one! (Top left cell's top let corner at <0,0>; cells are 1x1.)
# Warning! No geotransform defined. Choosing a standard one! (Top left cell's top let corner at <0,0>; cells are 1x1.)
# Warning! No geotransform defined. Choosing a standard one! (Top left cell's top let corner at <0,0>; cells are 1x1.)
# 2034 C:\temp\UOC\TrainData\img\image_283.h5 C:\temp\UOC\TrainData\mask\mask_283.h5
# Warning! No geotransform defined. Choosing a standard one! (Top left cell's top let corner at <0,0>; cells are 1x1.)
# Warning! No geotransform defined. Choosing a standard one! (Top left cell's top let corner at <0,0>; cells are 1x1.)
# Warning! No geotransform defined. Choosing a standard one! (Top left cell's top let corner at <0,0>; cells are 1x1.)
# Warning! No geotransform defined. Choosing a standard one! (Top left cell's top let corner at <0,0>; cells are 1x1.)
# Warning! No geotransform defined. Choosing a standard one! (Top left cell's top let corner at <0,0>; cells are 1x1.)
# Warning! No geotransform defined. Choosing a standard one! (Top left cell's top let corner at <0,0>; cells are 1x1.)
# 2035 C:\temp\UOC\TrainData\img\image_2830.h5 C:\temp\UOC\TrainData\mask\mask_2830.h5
# Warning! No geotransform defined. Choosing a standard one! (Top left cell's top let corner at <0,0>; cells are 1x1.)
# Warning! No geotransform defined. Choosing a standard one! (Top left cell's top let corner at <0,0>; cells are 1x1.)
# Warning! No geotransform defined. Choosing a standard one! (Top left cell's top let corner at <0,0>; cells are 1x1.)
# Warning! No geotransform defined. Choosing a standard one! (Top left cell's top let corner at <0,0>; cells are 1x1.)
# Warning! No geotransform defined. Choosing a standard one! (Top left cell's top let corner at <0,0>; cells are 1x1.)
# Warning! No geotransform defined. Choosing a standard one! (Top left cell's top let corner at <0,0>; cells are 1x1.)
# 2036 C:\temp\UOC\TrainData\img\image_2831.h5 C:\temp\UOC\TrainData\mask\mask_2831.h5
# Warning! No geotransform defined. Choosing a standard one! (Top left cell's top let corner at <0,0>; cells are 1x1.)
# Warning! No geotransform defined. Choosing a standard one! (Top left cell's top let corner at <0,0>; cells are 1x1.)
# Warning! No geotransform defined. Choosing a standard one! (Top left cell's top let corner at <0,0>; cells are 1x1.)
# Warning! No geotransform defined. Choosing a standard one! (Top left cell's top let corner at <0,0>; cells are 1x1.)
# Warning! No geotransform defined. Choosing a standard one! (Top left cell's top let corner at <0,0>; cells are 1x1.)
# Warning! No geotransform defined. Choosing a standard one! (Top left cell's top let corner at <0,0>; cells are 1x1.)
# 2037 C:\temp\UOC\TrainData\img\image_2832.h5 C:\temp\UOC\TrainData\mask\mask_2832.h5
# Warning! No geotransform defined. Choosing a standard one! (Top left cell's top let corner at <0,0>; cells are 1x1.)
# Warning! No geotransform defined. Choosing a standard one! (Top left cell's top let corner at <0,0>; cells are 1x1.)
# Warning! No geotransform defined. Choosing a standard one! (Top left cell's top let corner at <0,0>; cells are 1x1.)
# Warning! No geotransform defined. Choosing a standard one! (Top left cell's top let corner at <0,0>; cells are 1x1.)
# Warning! No geotransform defined. Choosing a standard one! (Top left cell's top let corner at <0,0>; cells are 1x1.)
# Warning! No geotransform defined. Choosing a standard one! (Top left cell's top let corner at <0,0>; cells are 1x1.)
# 2038 C:\temp\UOC\TrainData\img\image_2833.h5 C:\temp\UOC\TrainData\mask\mask_2833.h5
# Warning! No geotransform defined. Choosing a standard one! (Top left cell's top let corner at <0,0>; cells are 1x1.)
# Warning! No geotransform defined. Choosing a standard one! (Top left cell's top let corner at <0,0>; cells are 1x1.)
# Warning! No geotransform defined. Choosing a standard one! (Top left cell's top let corner at <0,0>; cells are 1x1.)
# Warning! No geotransform defined. Choosing a standard one! (Top left cell's top let corner at <0,0>; cells are 1x1.)
# Warning! No geotransform defined. Choosing a standard one! (Top left cell's top let corner at <0,0>; cells are 1x1.)
# Warning! No geotransform defined. Choosing a standard one! (Top left cell's top let corner at <0,0>; cells are 1x1.)
# 2039 C:\temp\UOC\TrainData\img\image_2834.h5 C:\temp\UOC\TrainData\mask\mask_2834.h5
# Warning! No geotransform defined. Choosing a standard one! (Top left cell's top let corner at <0,0>; cells are 1x1.)
# Warning! No geotransform defined. Choosing a standard one! (Top left cell's top let corner at <0,0>; cells are 1x1.)
# Warning! No geotransform defined. Choosing a standard one! (Top left cell's top let corner at <0,0>; cells are 1x1.)
# Warning! No geotransform defined. Choosing a standard one! (Top left cell's top let corner at <0,0>; cells are 1x1.)
# Warning! No geotransform defined. Choosing a standard one! (Top left cell's top let corner at <0,0>; cells are 1x1.)
# Warning! No geotransform defined. Choosing a standard one! (Top left cell's top let corner at <0,0>; cells are 1x1.)
# 2040 C:\temp\UOC\TrainData\img\image_2835.h5 C:\temp\UOC\TrainData\mask\mask_2835.h5
# Warning! No geotransform defined. Choosing a standard one! (Top left cell's top let corner at <0,0>; cells are 1x1.)
# Warning! No geotransform defined. Choosing a standard one! (Top left cell's top let corner at <0,0>; cells are 1x1.)
# Warning! No geotransform defined. Choosing a standard one! (Top left cell's top let corner at <0,0>; cells are 1x1.)
# Warning! No geotransform defined. Choosing a standard one! (Top left cell's top let corner at <0,0>; cells are 1x1.)
# Warning! No geotransform defined. Choosing a standard one! (Top left cell's top let corner at <0,0>; cells are 1x1.)
# Warning! No geotransform defined. Choosing a standard one! (Top left cell's top let corner at <0,0>; cells are 1x1.)
# 2041 C:\temp\UOC\TrainData\img\image_2836.h5 C:\temp\UOC\TrainData\mask\mask_2836.h5
# Warning! No geotransform defined. Choosing a standard one! (Top left cell's top let corner at <0,0>; cells are 1x1.)
# Warning! No geotransform defined. Choosing a standard one! (Top left cell's top let corner at <0,0>; cells are 1x1.)
# Warning! No geotransform defined. Choosing a standard one! (Top left cell's top let corner at <0,0>; cells are 1x1.)
# Warning! No geotransform defined. Choosing a standard one! (Top left cell's top let corner at <0,0>; cells are 1x1.)
# Warning! No geotransform defined. Choosing a standard one! (Top left cell's top let corner at <0,0>; cells are 1x1.)
# Warning! No geotransform defined. Choosing a standard one! (Top left cell's top let corner at <0,0>; cells are 1x1.)
# 2042 C:\temp\UOC\TrainData\img\image_2837.h5 C:\temp\UOC\TrainData\mask\mask_2837.h5
# Warning! No geotransform defined. Choosing a standard one! (Top left cell's top let corner at <0,0>; cells are 1x1.)
# Warning! No geotransform defined. Choosing a standard one! (Top left cell's top let corner at <0,0>; cells are 1x1.)
# Warning! No geotransform defined. Choosing a standard one! (Top left cell's top let corner at <0,0>; cells are 1x1.)
# Warning! No geotransform defined. Choosing a standard one! (Top left cell's top let corner at <0,0>; cells are 1x1.)
# Warning! No geotransform defined. Choosing a standard one! (Top left cell's top let corner at <0,0>; cells are 1x1.)
# Warning! No geotransform defined. Choosing a standard one! (Top left cell's top let corner at <0,0>; cells are 1x1.)
# 2043 C:\temp\UOC\TrainData\img\image_2838.h5 C:\temp\UOC\TrainData\mask\mask_2838.h5
# Warning! No geotransform defined. Choosing a standard one! (Top left cell's top let corner at <0,0>; cells are 1x1.)
# Warning! No geotransform defined. Choosing a standard one! (Top left cell's top let corner at <0,0>; cells are 1x1.)
# Warning! No geotransform defined. Choosing a standard one! (Top left cell's top let corner at <0,0>; cells are 1x1.)
# Warning! No geotransform defined. Choosing a standard one! (Top left cell's top let corner at <0,0>; cells are 1x1.)
# Warning! No geotransform defined. Choosing a standard one! (Top left cell's top let corner at <0,0>; cells are 1x1.)
# Warning! No geotransform defined. Choosing a standard one! (Top left cell's top let corner at <0,0>; cells are 1x1.)
# 2044 C:\temp\UOC\TrainData\img\image_2839.h5 C:\temp\UOC\TrainData\mask\mask_2839.h5
# Warning! No geotransform defined. Choosing a standard one! (Top left cell's top let corner at <0,0>; cells are 1x1.)
# Warning! No geotransform defined. Choosing a standard one! (Top left cell's top let corner at <0,0>; cells are 1x1.)
# Warning! No geotransform defined. Choosing a standard one! (Top left cell's top let corner at <0,0>; cells are 1x1.)
# Warning! No geotransform defined. Choosing a standard one! (Top left cell's top let corner at <0,0>; cells are 1x1.)
# Warning! No geotransform defined. Choosing a standard one! (Top left cell's top let corner at <0,0>; cells are 1x1.)
# Warning! No geotransform defined. Choosing a standard one! (Top left cell's top let corner at <0,0>; cells are 1x1.)
# 2045 C:\temp\UOC\TrainData\img\image_284.h5 C:\temp\UOC\TrainData\mask\mask_284.h5
# Warning! No geotransform defined. Choosing a standard one! (Top left cell's top let corner at <0,0>; cells are 1x1.)
# Warning! No geotransform defined. Choosing a standard one! (Top left cell's top let corner at <0,0>; cells are 1x1.)
# Warning! No geotransform defined. Choosing a standard one! (Top left cell's top let corner at <0,0>; cells are 1x1.)
# Warning! No geotransform defined. Choosing a standard one! (Top left cell's top let corner at <0,0>; cells are 1x1.)
# Warning! No geotransform defined. Choosing a standard one! (Top left cell's top let corner at <0,0>; cells are 1x1.)
# Warning! No geotransform defined. Choosing a standard one! (Top left cell's top let corner at <0,0>; cells are 1x1.)
# 2046 C:\temp\UOC\TrainData\img\image_2840.h5 C:\temp\UOC\TrainData\mask\mask_2840.h5
# Warning! No geotransform defined. Choosing a standard one! (Top left cell's top let corner at <0,0>; cells are 1x1.)
# Warning! No geotransform defined. Choosing a standard one! (Top left cell's top let corner at <0,0>; cells are 1x1.)
# Warning! No geotransform defined. Choosing a standard one! (Top left cell's top let corner at <0,0>; cells are 1x1.)
# Warning! No geotransform defined. Choosing a standard one! (Top left cell's top let corner at <0,0>; cells are 1x1.)
# Warning! No geotransform defined. Choosing a standard one! (Top left cell's top let corner at <0,0>; cells are 1x1.)
# Warning! No geotransform defined. Choosing a standard one! (Top left cell's top let corner at <0,0>; cells are 1x1.)
# 2047 C:\temp\UOC\TrainData\img\image_2841.h5 C:\temp\UOC\TrainData\mask\mask_2841.h5
# Warning! No geotransform defined. Choosing a standard one! (Top left cell's top let corner at <0,0>; cells are 1x1.)
# Warning! No geotransform defined. Choosing a standard one! (Top left cell's top let corner at <0,0>; cells are 1x1.)
# Warning! No geotransform defined. Choosing a standard one! (Top left cell's top let corner at <0,0>; cells are 1x1.)
# Warning! No geotransform defined. Choosing a standard one! (Top left cell's top let corner at <0,0>; cells are 1x1.)
# Warning! No geotransform defined. Choosing a standard one! (Top left cell's top let corner at <0,0>; cells are 1x1.)
# Warning! No geotransform defined. Choosing a standard one! (Top left cell's top let corner at <0,0>; cells are 1x1.)
# 2048 C:\temp\UOC\TrainData\img\image_2842.h5 C:\temp\UOC\TrainData\mask\mask_2842.h5
# Warning! No geotransform defined. Choosing a standard one! (Top left cell's top let corner at <0,0>; cells are 1x1.)
# Warning! No geotransform defined. Choosing a standard one! (Top left cell's top let corner at <0,0>; cells are 1x1.)
# Warning! No geotransform defined. Choosing a standard one! (Top left cell's top let corner at <0,0>; cells are 1x1.)
# Warning! No geotransform defined. Choosing a standard one! (Top left cell's top let corner at <0,0>; cells are 1x1.)
# Warning! No geotransform defined. Choosing a standard one! (Top left cell's top let corner at <0,0>; cells are 1x1.)
# Warning! No geotransform defined. Choosing a standard one! (Top left cell's top let corner at <0,0>; cells are 1x1.)
# 2049 C:\temp\UOC\TrainData\img\image_2843.h5 C:\temp\UOC\TrainData\mask\mask_2843.h5
# Warning! No geotransform defined. Choosing a standard one! (Top left cell's top let corner at <0,0>; cells are 1x1.)
# Warning! No geotransform defined. Choosing a standard one! (Top left cell's top let corner at <0,0>; cells are 1x1.)
# Warning! No geotransform defined. Choosing a standard one! (Top left cell's top let corner at <0,0>; cells are 1x1.)
# Warning! No geotransform defined. Choosing a standard one! (Top left cell's top let corner at <0,0>; cells are 1x1.)
# Warning! No geotransform defined. Choosing a standard one! (Top left cell's top let corner at <0,0>; cells are 1x1.)
# Warning! No geotransform defined. Choosing a standard one! (Top left cell's top let corner at <0,0>; cells are 1x1.)
# 2050 C:\temp\UOC\TrainData\img\image_2844.h5 C:\temp\UOC\TrainData\mask\mask_2844.h5
# Warning! No geotransform defined. Choosing a standard one! (Top left cell's top let corner at <0,0>; cells are 1x1.)
# Warning! No geotransform defined. Choosing a standard one! (Top left cell's top let corner at <0,0>; cells are 1x1.)

# %%
# with open('bands.pickle', 'wb') as f:
#     pickle.dump(TRAIN_XX, f)
#     pickle.dump(TRAIN_YY, f)

with open('bands.pickle', 'rb') as f:
    TRAIN_XX= pickle.load(f)
    TRAIN_YY= pickle.load(f)

# %%
# TRAIN_XX_n = TRAIN_XX / TRAIN_XX.max()
TRAIN_XX[np.isnan(TRAIN_XX)] = 0.000001
print(TRAIN_XX.min(), TRAIN_XX.max(), TRAIN_YY.min(), TRAIN_YY.max())
# Out:
# 0.0 1.0 0.0 1.0

# %%
img=234
fig,(ax1,ax2, ax3, ax4, ax5, ax6, ax7, ax8)= plt.subplots(1,8,figsize=(15,10))


ax1.set_title("DEM suavizado")
ax2.set_title("slope suavizado")
ax3.set_title("curvature")
ax4.set_title("planform curvature")
ax5.set_title("profile curvature")
ax6.set_title("BSI")
ax7.set_title("NDVI")
ax8.set_title("mask")

ax1.imshow(TRAIN_XX[img, :, :, 0])
ax2.imshow(TRAIN_XX[img, :, :, 1])
ax3.imshow(TRAIN_XX[img, :, :, 2])
ax4.imshow(TRAIN_XX[img, :, :, 3])
ax5.imshow(TRAIN_XX[img, :, :, 4])
ax6.imshow(TRAIN_XX[img, :, :, 5])
ax7.imshow(TRAIN_XX[img, :, :, 6])
ax8.imshow(TRAIN_YY[img, :, :, 0])

# %%
from sklearn.model_selection import train_test_split

# Split the data
x_train, x_valid, y_train, y_valid = train_test_split(TRAIN_XX, TRAIN_YY, test_size=0.2, shuffle= True)

# %%
x_train.shape, y_train.shape
# Out:
# ((3039, 128, 128, 7), (3039, 128, 128, 1))

# %% [markdown]
# # SEQUENTIAL MODEL

# %%
from keras.models import Sequential
from keras.layers import Dense, Dropout
from keras.callbacks import EarlyStopping

# %%
#Build the model
model = Sequential()
model.add(Dense(20, input_shape=(128, 128, 7), activation='relu')) # Add an input shape! (features,)
model.add(Dense(10, activation='relu'))
model.add(Dense(1, activation='sigmoid'))
model.summary()

# %%
# Compile the model
model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy', f1_m, precision_m, recall_m])

# %%
checkpointer = tf.keras.callbacks.ModelCheckpoint("best_model.h5", monitor="val_f1_m", verbose=1, save_best_only=True, mode="max")

history = model.fit(x_train, y_train, batch_size=16,  
          epochs=50, 
          verbose = 2,
          validation_data=(x_valid, y_valid),
          callbacks=callbacks)
model.save("model_save.h5")

# %%
loss, accuracy, f1_score, precision, recall = model.evaluate(x_valid, y_valid, verbose=0)
print(loss, accuracy, f1_score, precision, recall)

# %%
fig,((ax11,ax12),(ax13,ax14)) = plt.subplots(2,2,figsize=(20,15))
ax11.plot(history.history['loss'])
ax11.plot(history.history['val_loss'])
ax11.title.set_text('Unet model loss')
ax11.set_ylabel('loss')
ax11.set_xlabel('epoch')
ax11.legend(['train', 'validation'], loc='upper left')

ax12.plot(history.history['precision_m'])
ax12.plot(history.history['val_precision_m'])
ax12.set_title('Unet model precision')
ax12.set_ylabel('precision')
ax12.set_xlabel('epoch')
ax12.legend(['train', 'validation'], loc='upper left')

ax13.plot(history.history['recall_m'])
ax13.plot(history.history['val_recall_m'])
ax13.set_title('Unet model recall')
ax13.set_ylabel('recall')
ax13.set_xlabel('epoch')
ax13.legend(['train', 'validation'], loc='upper left')

ax14.plot(history.history['f1_m'])
ax14.plot(history.history['val_f1_m'])
ax14.set_title('Unet model f1')
ax14.set_ylabel('f1')
ax14.set_xlabel('epoch')
ax14.legend(['train', 'validation'], loc='upper left')

# %% [markdown]
# # UNET MODEL

# %%
def unet_model(IMG_WIDTH, IMG_HIGHT, IMG_CHANNELS):
    inputs = tf.keras.layers.Input((IMG_WIDTH, IMG_HIGHT, IMG_CHANNELS))

    # Converted inputs to floating
    #s = tf.keras.layers.Lambda(lambda x: x / 255)(inputs)


    #Contraction path
    c1 = tf.keras.layers.Conv2D(16, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(inputs)
    c1 = tf.keras.layers.Dropout(0.1)(c1)
    c1 = tf.keras.layers.Conv2D(16, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(c1)
    p1 = tf.keras.layers.MaxPooling2D((2, 2))(c1)

    c2 = tf.keras.layers.Conv2D(32, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(p1)
    c2 = tf.keras.layers.Dropout(0.1)(c2)
    c2 = tf.keras.layers.Conv2D(32, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(c2)
    p2 = tf.keras.layers.MaxPooling2D((2, 2))(c2)

    c3 = tf.keras.layers.Conv2D(64, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(p2)
    c3 = tf.keras.layers.Dropout(0.2)(c3)
    c3 = tf.keras.layers.Conv2D(64, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(c3)
    p3 = tf.keras.layers.MaxPooling2D((2, 2))(c3)

    c4 = tf.keras.layers.Conv2D(128, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(p3)
    c4 = tf.keras.layers.Dropout(0.2)(c4)
    c4 = tf.keras.layers.Conv2D(128, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(c4)
    p4 = tf.keras.layers.MaxPooling2D(pool_size=(2, 2))(c4)

    c5 = tf.keras.layers.Conv2D(256, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(p4)
    c5 = tf.keras.layers.Dropout(0.3)(c5)
    c5 = tf.keras.layers.Conv2D(256, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(c5)

    #Expansive path 
    u6 = tf.keras.layers.Conv2DTranspose(128, (2, 2), strides=(2, 2), padding='same')(c5)
    u6 = tf.keras.layers.concatenate([u6, c4])
    c6 = tf.keras.layers.Conv2D(128, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(u6)
    c6 = tf.keras.layers.Dropout(0.2)(c6)
    c6 = tf.keras.layers.Conv2D(128, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(c6)

    u7 = tf.keras.layers.Conv2DTranspose(64, (2, 2), strides=(2, 2), padding='same')(c6)
    u7 = tf.keras.layers.concatenate([u7, c3])
    c7 = tf.keras.layers.Conv2D(64, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(u7)
    c7 = tf.keras.layers.Dropout(0.2)(c7)
    c7 = tf.keras.layers.Conv2D(64, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(c7)

    u8 = tf.keras.layers.Conv2DTranspose(32, (2, 2), strides=(2, 2), padding='same')(c7)
    u8 = tf.keras.layers.concatenate([u8, c2])
    c8 = tf.keras.layers.Conv2D(32, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(u8)
    c8 = tf.keras.layers.Dropout(0.1)(c8)
    c8 = tf.keras.layers.Conv2D(32, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(c8)

    u9 = tf.keras.layers.Conv2DTranspose(16, (2, 2), strides=(2, 2), padding='same')(c8)
    u9 = tf.keras.layers.concatenate([u9, c1], axis=3)
    c9 = tf.keras.layers.Conv2D(16, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(u9)
    c9 = tf.keras.layers.Dropout(0.1)(c9)
    c9 = tf.keras.layers.Conv2D(16, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(c9)

    outputs = tf.keras.layers.Conv2D(1, (1, 1), activation='sigmoid')(c9)

    model = tf.keras.Model(inputs=[inputs], outputs=[outputs])
    model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy', f1_m, precision_m, recall_m])
    
    return model

# %%
model = unet_model(128, 128, 7)
# model.summary()
checkpointer = tf.keras.callbacks.ModelCheckpoint("best_model.h5", monitor="val_f1_m", verbose=1, save_best_only=True, mode="max")
earlyStopping = tf.keras.callbacks.EarlyStopping(monitor='val_f1_m', patience=10, verbose=1, mode='max')

callbacks = [
    earlyStopping,
    checkpointer
    ]
history = model.fit(x_train, y_train, batch_size=16,  
          epochs=100, 
          verbose = 2,
          validation_data=(x_valid, y_valid),
          callbacks=callbacks)

model.save("model_save.h5")
# Out:
# Epoch 1/100
#
# Epoch 1: val_f1_m improved from -inf to 0.47737, saving model to best_model.h5
# 190/190 - 313s - loss: 0.1192 - accuracy: 0.9510 - f1_m: 0.1212 - precision_m: 0.4127 - recall_m: 0.1083 - val_loss: 0.0506 - val_accuracy: 0.9816 - val_f1_m: 0.4774 - val_precision_m: 0.5756 - val_recall_m: 0.4310 - 313s/epoch - 2s/step
# Epoch 2/100
#
# Epoch 2: val_f1_m improved from 0.47737 to 0.56002, saving model to best_model.h5
# 190/190 - 297s - loss: 0.0481 - accuracy: 0.9818 - f1_m: 0.5144 - precision_m: 0.6932 - recall_m: 0.4296 - val_loss: 0.0452 - val_accuracy: 0.9831 - val_f1_m: 0.5600 - val_precision_m: 0.5823 - val_recall_m: 0.5611 - 297s/epoch - 2s/step
# Epoch 3/100
#
# Epoch 3: val_f1_m did not improve from 0.56002
# 190/190 - 291s - loss: 0.0439 - accuracy: 0.9831 - f1_m: 0.5524 - precision_m: 0.7164 - recall_m: 0.4707 - val_loss: 0.0397 - val_accuracy: 0.9851 - val_f1_m: 0.5361 - val_precision_m: 0.6902 - val_recall_m: 0.4526 - 291s/epoch - 2s/step
# Epoch 4/100
#
# Epoch 4: val_f1_m improved from 0.56002 to 0.58031, saving model to best_model.h5
# 190/190 - 302s - loss: 0.0430 - accuracy: 0.9836 - f1_m: 0.5622 - precision_m: 0.7401 - recall_m: 0.4754 - val_loss: 0.0425 - val_accuracy: 0.9836 - val_f1_m: 0.5803 - val_precision_m: 0.5997 - val_recall_m: 0.5871 - 302s/epoch - 2s/step
# Epoch 5/100
#
# Epoch 5: val_f1_m improved from 0.58031 to 0.58726, saving model to best_model.h5
# 190/190 - 292s - loss: 0.0426 - accuracy: 0.9837 - f1_m: 0.5739 - precision_m: 0.7344 - recall_m: 0.4947 - val_loss: 0.0368 - val_accuracy: 0.9859 - val_f1_m: 0.5873 - val_precision_m: 0.6967 - val_recall_m: 0.5214 - 292s/epoch - 2s/step
# Epoch 6/100
#
# Epoch 6: val_f1_m did not improve from 0.58726
# 190/190 - 293s - loss: 0.0421 - accuracy: 0.9837 - f1_m: 0.5632 - precision_m: 0.7408 - recall_m: 0.4801 - val_loss: 0.0365 - val_accuracy: 0.9864 - val_f1_m: 0.5572 - val_precision_m: 0.7682 - val_recall_m: 0.4489 - 293s/epoch - 2s/step
# Epoch 7/100
#
# Epoch 7: val_f1_m improved from 0.58726 to 0.60032, saving model to best_model.h5
# 190/190 - 287s - loss: 0.0408 - accuracy: 0.9842 - f1_m: 0.5876 - precision_m: 0.7452 - recall_m: 0.4997 - val_loss: 0.0362 - val_accuracy: 0.9864 - val_f1_m: 0.6003 - val_precision_m: 0.7054 - val_recall_m: 0.5374 - 287s/epoch - 2s/step
# Epoch 8/100
#
# Epoch 8: val_f1_m did not improve from 0.60032
# 190/190 - 295s - loss: 0.0394 - accuracy: 0.9847 - f1_m: 0.6031 - precision_m: 0.7511 - recall_m: 0.5221 - val_loss: 0.0347 - val_accuracy: 0.9870 - val_f1_m: 0.5696 - val_precision_m: 0.8182 - val_recall_m: 0.4490 - 295s/epoch - 2s/step
# Epoch 9/100
#
# Epoch 9: val_f1_m improved from 0.60032 to 0.64068, saving model to best_model.h5
# 190/190 - 309s - loss: 0.0389 - accuracy: 0.9848 - f1_m: 0.6056 - precision_m: 0.7554 - recall_m: 0.5239 - val_loss: 0.0353 - val_accuracy: 0.9867 - val_f1_m: 0.6407 - val_precision_m: 0.6738 - val_recall_m: 0.6262 - 309s/epoch - 2s/step
# Epoch 10/100
#
# Epoch 10: val_f1_m did not improve from 0.64068
# 190/190 - 302s - loss: 0.0397 - accuracy: 0.9847 - f1_m: 0.6021 - precision_m: 0.7533 - recall_m: 0.5253 - val_loss: 0.0395 - val_accuracy: 0.9845 - val_f1_m: 0.6050 - val_precision_m: 0.6220 - val_recall_m: 0.6145 - 302s/epoch - 2s/step
# Epoch 11/100
#
# Epoch 11: val_f1_m did not improve from 0.64068
# 190/190 - 292s - loss: 0.0380 - accuracy: 0.9852 - f1_m: 0.6163 - precision_m: 0.7542 - recall_m: 0.5392 - val_loss: 0.0329 - val_accuracy: 0.9875 - val_f1_m: 0.6351 - val_precision_m: 0.7340 - val_recall_m: 0.5731 - 292s/epoch - 2s/step
# Epoch 12/100
#
# Epoch 12: val_f1_m did not improve from 0.64068
# 190/190 - 291s - loss: 0.0369 - accuracy: 0.9856 - f1_m: 0.6318 - precision_m: 0.7592 - recall_m: 0.5586 - val_loss: 0.0412 - val_accuracy: 0.9849 - val_f1_m: 0.5376 - val_precision_m: 0.6884 - val_recall_m: 0.4572 - 291s/epoch - 2s/step
# Epoch 13/100
#
# Epoch 13: val_f1_m did not improve from 0.64068
# 190/190 - 296s - loss: 0.0385 - accuracy: 0.9850 - f1_m: 0.6164 - precision_m: 0.7580 - recall_m: 0.5351 - val_loss: 0.0325 - val_accuracy: 0.9877 - val_f1_m: 0.6306 - val_precision_m: 0.7635 - val_recall_m: 0.5503 - 296s/epoch - 2s/step
# Epoch 14/100
#
# Epoch 14: val_f1_m did not improve from 0.64068
# 190/190 - 298s - loss: 0.0359 - accuracy: 0.9860 - f1_m: 0.6414 - precision_m: 0.7660 - recall_m: 0.5648 - val_loss: 0.0331 - val_accuracy: 0.9877 - val_f1_m: 0.5975 - val_precision_m: 0.8174 - val_recall_m: 0.4829 - 298s/epoch - 2s/step
# Epoch 15/100
#
# Epoch 15: val_f1_m did not improve from 0.64068
# 190/190 - 290s - loss: 0.0360 - accuracy: 0.9860 - f1_m: 0.6392 - precision_m: 0.7710 - recall_m: 0.5618 - val_loss: 0.0364 - val_accuracy: 0.9873 - val_f1_m: 0.5618 - val_precision_m: 0.8519 - val_recall_m: 0.4313 - 290s/epoch - 2s/step
# Epoch 16/100
#
# Epoch 16: val_f1_m improved from 0.64068 to 0.65272, saving model to best_model.h5
# 190/190 - 285s - loss: 0.0357 - accuracy: 0.9861 - f1_m: 0.6435 - precision_m: 0.7663 - recall_m: 0.5701 - val_loss: 0.0335 - val_accuracy: 0.9872 - val_f1_m: 0.6527 - val_precision_m: 0.6892 - val_recall_m: 0.6338 - 285s/epoch - 1s/step
# Epoch 17/100
#
# Epoch 17: val_f1_m did not improve from 0.65272
# 190/190 - 285s - loss: 0.0353 - accuracy: 0.9863 - f1_m: 0.6514 - precision_m: 0.7738 - recall_m: 0.5785 - val_loss: 0.0330 - val_accuracy: 0.9877 - val_f1_m: 0.6498 - val_precision_m: 0.7278 - val_recall_m: 0.5992 - 285s/epoch - 2s/step
# Epoch 18/100
#
# Epoch 18: val_f1_m did not improve from 0.65272
# 190/190 - 285s - loss: 0.0349 - accuracy: 0.9864 - f1_m: 0.6518 - precision_m: 0.7662 - recall_m: 0.5799 - val_loss: 0.0324 - val_accuracy: 0.9876 - val_f1_m: 0.6410 - val_precision_m: 0.7455 - val_recall_m: 0.5768 - 285s/epoch - 2s/step
# Epoch 19/100
#
# Epoch 19: val_f1_m did not improve from 0.65272
# 190/190 - 286s - loss: 0.0345 - accuracy: 0.9866 - f1_m: 0.6548 - precision_m: 0.7700 - recall_m: 0.5862 - val_loss: 0.0322 - val_accuracy: 0.9876 - val_f1_m: 0.6241 - val_precision_m: 0.7616 - val_recall_m: 0.5420 - 286s/epoch - 2s/step
# Epoch 20/100
#
# Epoch 20: val_f1_m did not improve from 0.65272
# 190/190 - 287s - loss: 0.0339 - accuracy: 0.9867 - f1_m: 0.6621 - precision_m: 0.7754 - recall_m: 0.5927 - val_loss: 0.0373 - val_accuracy: 0.9871 - val_f1_m: 0.5599 - val_precision_m: 0.8502 - val_recall_m: 0.4292 - 287s/epoch - 2s/step
# Epoch 21/100
#
# Epoch 21: val_f1_m did not improve from 0.65272
# 190/190 - 284s - loss: 0.0344 - accuracy: 0.9866 - f1_m: 0.6628 - precision_m: 0.7785 - recall_m: 0.5950 - val_loss: 0.0335 - val_accuracy: 0.9869 - val_f1_m: 0.6435 - val_precision_m: 0.6965 - val_recall_m: 0.6151 - 284s/epoch - 1s/step
# Epoch 22/100
#
# Epoch 22: val_f1_m did not improve from 0.65272
# 190/190 - 288s - loss: 0.0342 - accuracy: 0.9867 - f1_m: 0.6641 - precision_m: 0.7743 - recall_m: 0.5960 - val_loss: 0.0322 - val_accuracy: 0.9879 - val_f1_m: 0.6309 - val_precision_m: 0.7646 - val_recall_m: 0.5485 - 288s/epoch - 2s/step
# Epoch 23/100
#
# Epoch 23: val_f1_m improved from 0.65272 to 0.66010, saving model to best_model.h5
# 190/190 - 284s - loss: 0.0333 - accuracy: 0.9870 - f1_m: 0.6731 - precision_m: 0.7804 - recall_m: 0.6050 - val_loss: 0.0308 - val_accuracy: 0.9883 - val_f1_m: 0.6601 - val_precision_m: 0.7532 - val_recall_m: 0.5997 - 284s/epoch - 1s/step
# Epoch 24/100
#
# Epoch 24: val_f1_m improved from 0.66010 to 0.66286, saving model to best_model.h5
# 190/190 - 284s - loss: 0.0327 - accuracy: 0.9872 - f1_m: 0.6773 - precision_m: 0.7834 - recall_m: 0.6078 - val_loss: 0.0311 - val_accuracy: 0.9884 - val_f1_m: 0.6629 - val_precision_m: 0.7620 - val_recall_m: 0.5946 - 284s/epoch - 1s/step
# Epoch 25/100
#
# Epoch 25: val_f1_m did not improve from 0.66286
# 190/190 - 286s - loss: 0.0342 - accuracy: 0.9866 - f1_m: 0.6628 - precision_m: 0.7753 - recall_m: 0.5966 - val_loss: 0.0359 - val_accuracy: 0.9871 - val_f1_m: 0.5906 - val_precision_m: 0.7740 - val_recall_m: 0.4877 - 286s/epoch - 2s/step
# Epoch 26/100
#
# Epoch 26: val_f1_m did not improve from 0.66286
# 190/190 - 284s - loss: 0.0339 - accuracy: 0.9868 - f1_m: 0.6657 - precision_m: 0.7806 - recall_m: 0.5938 - val_loss: 0.0309 - val_accuracy: 0.9883 - val_f1_m: 0.6279 - val_precision_m: 0.8229 - val_recall_m: 0.5180 - 284s/epoch - 1s/step
# Epoch 27/100
#
# Epoch 27: val_f1_m did not improve from 0.66286
# 190/190 - 284s - loss: 0.0319 - accuracy: 0.9875 - f1_m: 0.6845 - precision_m: 0.7855 - recall_m: 0.6146 - val_loss: 0.0315 - val_accuracy: 0.9879 - val_f1_m: 0.6471 - val_precision_m: 0.7607 - val_recall_m: 0.5759 - 284s/epoch - 1s/step
# Epoch 28/100
#
# Epoch 28: val_f1_m did not improve from 0.66286
# 190/190 - 286s - loss: 0.0320 - accuracy: 0.9874 - f1_m: 0.6831 - precision_m: 0.7801 - recall_m: 0.6173 - val_loss: 0.0315 - val_accuracy: 0.9879 - val_f1_m: 0.6577 - val_precision_m: 0.7426 - val_recall_m: 0.6067 - 286s/epoch - 2s/step
# Epoch 29/100
#
# Epoch 29: val_f1_m did not improve from 0.66286
# 190/190 - 283s - loss: 0.0310 - accuracy: 0.9878 - f1_m: 0.6969 - precision_m: 0.7876 - recall_m: 0.6352 - val_loss: 0.0301 - val_accuracy: 0.9884 - val_f1_m: 0.6473 - val_precision_m: 0.7973 - val_recall_m: 0.5562 - 283s/epoch - 1s/step
# Epoch 30/100
#
# Epoch 30: val_f1_m did not improve from 0.66286
# 190/190 - 285s - loss: 0.0336 - accuracy: 0.9869 - f1_m: 0.6730 - precision_m: 0.7767 - recall_m: 0.6097 - val_loss: 0.0302 - val_accuracy: 0.9884 - val_f1_m: 0.6480 - val_precision_m: 0.7913 - val_recall_m: 0.5602 - 285s/epoch - 1s/step
# Epoch 31/100
#
# Epoch 31: val_f1_m did not improve from 0.66286
# 190/190 - 286s - loss: 0.0309 - accuracy: 0.9878 - f1_m: 0.6932 - precision_m: 0.7863 - recall_m: 0.6319 - val_loss: 0.0301 - val_accuracy: 0.9884 - val_f1_m: 0.6481 - val_precision_m: 0.7901 - val_recall_m: 0.5605 - 286s/epoch - 2s/step
# Epoch 32/100
#
# Epoch 32: val_f1_m did not improve from 0.66286
# 190/190 - 285s - loss: 0.0309 - accuracy: 0.9878 - f1_m: 0.6960 - precision_m: 0.7892 - recall_m: 0.6328 - val_loss: 0.0316 - val_accuracy: 0.9881 - val_f1_m: 0.6621 - val_precision_m: 0.7435 - val_recall_m: 0.6087 - 285s/epoch - 1s/step
# Epoch 33/100
#
# Epoch 33: val_f1_m did not improve from 0.66286
# 190/190 - 285s - loss: 0.0305 - accuracy: 0.9880 - f1_m: 0.7009 - precision_m: 0.7927 - recall_m: 0.6376 - val_loss: 0.0304 - val_accuracy: 0.9883 - val_f1_m: 0.6528 - val_precision_m: 0.7696 - val_recall_m: 0.5758 - 285s/epoch - 1s/step
# Epoch 34/100
#
# Epoch 34: val_f1_m did not improve from 0.66286
# 190/190 - 285s - loss: 0.0301 - accuracy: 0.9881 - f1_m: 0.7071 - precision_m: 0.7924 - recall_m: 0.6461 - val_loss: 0.0309 - val_accuracy: 0.9882 - val_f1_m: 0.6285 - val_precision_m: 0.7981 - val_recall_m: 0.5272 - 285s/epoch - 2s/step
# Epoch 35/100
#
# Epoch 35: val_f1_m did not improve from 0.66286
# 190/190 - 286s - loss: 0.0298 - accuracy: 0.9882 - f1_m: 0.7043 - precision_m: 0.7930 - recall_m: 0.6413 - val_loss: 0.0301 - val_accuracy: 0.9884 - val_f1_m: 0.6521 - val_precision_m: 0.7792 - val_recall_m: 0.5699 - 286s/epoch - 2s/step
# Epoch 36/100
#
# Epoch 36: val_f1_m did not improve from 0.66286
# 190/190 - 284s - loss: 0.0301 - accuracy: 0.9882 - f1_m: 0.7046 - precision_m: 0.7989 - recall_m: 0.6394 - val_loss: 0.0299 - val_accuracy: 0.9886 - val_f1_m: 0.6567 - val_precision_m: 0.7914 - val_recall_m: 0.5690 - 284s/epoch - 1s/step
# Epoch 37/100
#
# Epoch 37: val_f1_m did not improve from 0.66286
# 190/190 - 284s - loss: 0.0295 - accuracy: 0.9884 - f1_m: 0.7134 - precision_m: 0.7998 - recall_m: 0.6529 - val_loss: 0.0311 - val_accuracy: 0.9883 - val_f1_m: 0.6489 - val_precision_m: 0.7676 - val_recall_m: 0.5718 - 284s/epoch - 1s/step
# Epoch 38/100
#
# Epoch 38: val_f1_m improved from 0.66286 to 0.67185, saving model to best_model.h5
# 190/190 - 286s - loss: 0.0300 - accuracy: 0.9882 - f1_m: 0.7075 - precision_m: 0.8043 - recall_m: 0.6431 - val_loss: 0.0297 - val_accuracy: 0.9886 - val_f1_m: 0.6719 - val_precision_m: 0.7617 - val_recall_m: 0.6105 - 286s/epoch - 2s/step
# Epoch 39/100
#
# Epoch 39: val_f1_m did not improve from 0.67185
# 190/190 - 284s - loss: 0.0290 - accuracy: 0.9885 - f1_m: 0.7179 - precision_m: 0.8012 - recall_m: 0.6574 - val_loss: 0.0302 - val_accuracy: 0.9886 - val_f1_m: 0.6536 - val_precision_m: 0.7967 - val_recall_m: 0.5634 - 284s/epoch - 1s/step
# Epoch 40/100
#
# Epoch 40: val_f1_m did not improve from 0.67185
# 190/190 - 286s - loss: 0.0291 - accuracy: 0.9885 - f1_m: 0.7128 - precision_m: 0.8014 - recall_m: 0.6503 - val_loss: 0.0309 - val_accuracy: 0.9880 - val_f1_m: 0.6480 - val_precision_m: 0.7436 - val_recall_m: 0.5850 - 286s/epoch - 2s/step
# Epoch 41/100
#
# Epoch 41: val_f1_m did not improve from 0.67185
# 190/190 - 287s - loss: 0.0291 - accuracy: 0.9885 - f1_m: 0.7159 - precision_m: 0.8030 - recall_m: 0.6542 - val_loss: 0.0318 - val_accuracy: 0.9883 - val_f1_m: 0.6715 - val_precision_m: 0.7326 - val_recall_m: 0.6334 - 287s/epoch - 2s/step
# Epoch 42/100
#
# Epoch 42: val_f1_m did not improve from 0.67185
# 190/190 - 284s - loss: 0.0310 - accuracy: 0.9879 - f1_m: 0.7009 - precision_m: 0.7938 - recall_m: 0.6390 - val_loss: 0.0325 - val_accuracy: 0.9883 - val_f1_m: 0.6405 - val_precision_m: 0.7929 - val_recall_m: 0.5484 - 284s/epoch - 1s/step
# Epoch 43/100
#
# Epoch 43: val_f1_m did not improve from 0.67185
# 190/190 - 286s - loss: 0.0283 - accuracy: 0.9887 - f1_m: 0.7281 - precision_m: 0.8042 - recall_m: 0.6712 - val_loss: 0.0307 - val_accuracy: 0.9882 - val_f1_m: 0.6602 - val_precision_m: 0.7537 - val_recall_m: 0.5977 - 286s/epoch - 2s/step
# Epoch 44/100
#
# Epoch 44: val_f1_m did not improve from 0.67185
# 190/190 - 287s - loss: 0.0282 - accuracy: 0.9888 - f1_m: 0.7218 - precision_m: 0.8033 - recall_m: 0.6628 - val_loss: 0.0309 - val_accuracy: 0.9885 - val_f1_m: 0.6545 - val_precision_m: 0.7902 - val_recall_m: 0.5690 - 287s/epoch - 2s/step
# Epoch 45/100
#
# Epoch 45: val_f1_m did not improve from 0.67185
# 190/190 - 309s - loss: 0.0278 - accuracy: 0.9889 - f1_m: 0.7309 - precision_m: 0.8064 - recall_m: 0.6743 - val_loss: 0.0313 - val_accuracy: 0.9884 - val_f1_m: 0.6337 - val_precision_m: 0.8154 - val_recall_m: 0.5281 - 309s/epoch - 2s/step
# Epoch 46/100
#
# Epoch 46: val_f1_m did not improve from 0.67185
# 190/190 - 284s - loss: 0.0287 - accuracy: 0.9886 - f1_m: 0.7210 - precision_m: 0.8026 - recall_m: 0.6627 - val_loss: 0.0344 - val_accuracy: 0.9881 - val_f1_m: 0.6078 - val_precision_m: 0.8241 - val_recall_m: 0.4920 - 284s/epoch - 1s/step
# Epoch 47/100
#
# Epoch 47: val_f1_m did not improve from 0.67185
# 190/190 - 287s - loss: 0.0276 - accuracy: 0.9890 - f1_m: 0.7302 - precision_m: 0.8066 - recall_m: 0.6742 - val_loss: 0.0349 - val_accuracy: 0.9883 - val_f1_m: 0.6313 - val_precision_m: 0.8034 - val_recall_m: 0.5306 - 287s/epoch - 2s/step
# Epoch 48/100
#
# Epoch 48: val_f1_m did not improve from 0.67185
# 190/190 - 284s - loss: 0.0273 - accuracy: 0.9892 - f1_m: 0.7368 - precision_m: 0.8091 - recall_m: 0.6813 - val_loss: 0.0318 - val_accuracy: 0.9884 - val_f1_m: 0.6464 - val_precision_m: 0.7923 - val_recall_m: 0.5549 - 284s/epoch - 1s/step
# Epoch 49/100
#
# Epoch 49: val_f1_m did not improve from 0.67185
# 190/190 - 285s - loss: 0.0280 - accuracy: 0.9889 - f1_m: 0.7263 - precision_m: 0.8073 - recall_m: 0.6689 - val_loss: 0.0322 - val_accuracy: 0.9883 - val_f1_m: 0.6498 - val_precision_m: 0.7778 - val_recall_m: 0.5678 - 285s/epoch - 1s/step
# Epoch 50/100
#
# Epoch 50: val_f1_m did not improve from 0.67185
# 190/190 - 286s - loss: 0.0276 - accuracy: 0.9890 - f1_m: 0.7333 - precision_m: 0.8076 - recall_m: 0.6789 - val_loss: 0.0319 - val_accuracy: 0.9886 - val_f1_m: 0.6518 - val_precision_m: 0.7974 - val_recall_m: 0.5614 - 286s/epoch - 2s/step
# Epoch 51/100
#
# Epoch 51: val_f1_m did not improve from 0.67185
# 190/190 - 285s - loss: 0.0268 - accuracy: 0.9893 - f1_m: 0.7393 - precision_m: 0.8124 - recall_m: 0.6838 - val_loss: 0.0303 - val_accuracy: 0.9887 - val_f1_m: 0.6484 - val_precision_m: 0.7971 - val_recall_m: 0.5556 - 285s/epoch - 1s/step
# Epoch 52/100
#
# Epoch 52: val_f1_m did not improve from 0.67185
# 190/190 - 284s - loss: 0.0271 - accuracy: 0.9892 - f1_m: 0.7371 - precision_m: 0.8134 - recall_m: 0.6801 - val_loss: 0.0314 - val_accuracy: 0.9883 - val_f1_m: 0.6679 - val_precision_m: 0.7528 - val_recall_m: 0.6117 - 284s/epoch - 1s/step
# Epoch 53/100
#
# Epoch 53: val_f1_m did not improve from 0.67185
# 190/190 - 289s - loss: 0.0268 - accuracy: 0.9893 - f1_m: 0.7355 - precision_m: 0.8119 - recall_m: 0.6785 - val_loss: 0.0356 - val_accuracy: 0.9883 - val_f1_m: 0.6270 - val_precision_m: 0.8229 - val_recall_m: 0.5146 - 289s/epoch - 2s/step
# Epoch 54/100
#
# Epoch 54: val_f1_m improved from 0.67185 to 0.67344, saving model to best_model.h5
# 190/190 - 291s - loss: 0.0273 - accuracy: 0.9891 - f1_m: 0.7357 - precision_m: 0.8120 - recall_m: 0.6808 - val_loss: 0.0301 - val_accuracy: 0.9885 - val_f1_m: 0.6734 - val_precision_m: 0.7465 - val_recall_m: 0.6224 - 291s/epoch - 2s/step
# Epoch 55/100
#
# Epoch 55: val_f1_m did not improve from 0.67344
# 190/190 - 291s - loss: 0.0275 - accuracy: 0.9891 - f1_m: 0.7355 - precision_m: 0.8113 - recall_m: 0.6797 - val_loss: 0.0338 - val_accuracy: 0.9881 - val_f1_m: 0.6205 - val_precision_m: 0.8050 - val_recall_m: 0.5138 - 291s/epoch - 2s/step
# Epoch 56/100
#
# Epoch 56: val_f1_m did not improve from 0.67344
# 190/190 - 286s - loss: 0.0271 - accuracy: 0.9892 - f1_m: 0.7369 - precision_m: 0.8093 - recall_m: 0.6823 - val_loss: 0.0341 - val_accuracy: 0.9884 - val_f1_m: 0.6329 - val_precision_m: 0.8157 - val_recall_m: 0.5261 - 286s/epoch - 2s/step
# Epoch 57/100
#
# Epoch 57: val_f1_m did not improve from 0.67344
# 190/190 - 288s - loss: 0.0271 - accuracy: 0.9892 - f1_m: 0.7381 - precision_m: 0.8052 - recall_m: 0.6874 - val_loss: 0.0361 - val_accuracy: 0.9879 - val_f1_m: 0.6230 - val_precision_m: 0.8035 - val_recall_m: 0.5198 - 288s/epoch - 2s/step
# Epoch 58/100
#
# Epoch 58: val_f1_m did not improve from 0.67344
# 190/190 - 284s - loss: 0.0270 - accuracy: 0.9892 - f1_m: 0.7392 - precision_m: 0.8112 - recall_m: 0.6860 - val_loss: 0.0303 - val_accuracy: 0.9886 - val_f1_m: 0.6574 - val_precision_m: 0.7852 - val_recall_m: 0.5738 - 284s/epoch - 1s/step
# Epoch 59/100
#
# Epoch 59: val_f1_m did not improve from 0.67344
# 190/190 - 284s - loss: 0.0263 - accuracy: 0.9895 - f1_m: 0.7451 - precision_m: 0.8166 - recall_m: 0.6909 - val_loss: 0.0319 - val_accuracy: 0.9885 - val_f1_m: 0.6594 - val_precision_m: 0.7726 - val_recall_m: 0.5830 - 284s/epoch - 1s/step
# Epoch 60/100
#
# Epoch 60: val_f1_m did not improve from 0.67344
# 190/190 - 286s - loss: 0.0259 - accuracy: 0.9896 - f1_m: 0.7491 - precision_m: 0.8187 - recall_m: 0.6967 - val_loss: 0.0315 - val_accuracy: 0.9883 - val_f1_m: 0.6609 - val_precision_m: 0.7483 - val_recall_m: 0.5999 - 286s/epoch - 2s/step
# Epoch 61/100
#
# Epoch 61: val_f1_m did not improve from 0.67344
# 190/190 - 284s - loss: 0.0256 - accuracy: 0.9897 - f1_m: 0.7557 - precision_m: 0.8192 - recall_m: 0.7057 - val_loss: 0.0320 - val_accuracy: 0.9885 - val_f1_m: 0.6627 - val_precision_m: 0.7700 - val_recall_m: 0.5893 - 284s/epoch - 1s/step
# Epoch 62/100
#
# Epoch 62: val_f1_m did not improve from 0.67344
# 190/190 - 285s - loss: 0.0256 - accuracy: 0.9897 - f1_m: 0.7479 - precision_m: 0.8145 - recall_m: 0.6972 - val_loss: 0.0331 - val_accuracy: 0.9883 - val_f1_m: 0.6276 - val_precision_m: 0.8141 - val_recall_m: 0.5193 - 285s/epoch - 1s/step
# Epoch 63/100
#
# Epoch 63: val_f1_m did not improve from 0.67344
# 190/190 - 287s - loss: 0.0254 - accuracy: 0.9898 - f1_m: 0.7524 - precision_m: 0.8212 - recall_m: 0.6998 - val_loss: 0.0322 - val_accuracy: 0.9884 - val_f1_m: 0.6423 - val_precision_m: 0.8079 - val_recall_m: 0.5414 - 287s/epoch - 2s/step
# Epoch 64/100
#
# Epoch 64: val_f1_m did not improve from 0.67344
# 190/190 - 284s - loss: 0.0257 - accuracy: 0.9897 - f1_m: 0.7551 - precision_m: 0.8180 - recall_m: 0.7053 - val_loss: 0.0324 - val_accuracy: 0.9886 - val_f1_m: 0.6442 - val_precision_m: 0.8117 - val_recall_m: 0.5417 - 284s/epoch - 1s/step
# Epoch 65/100
#
# Epoch 65: val_f1_m did not improve from 0.67344
# 190/190 - 284s - loss: 0.0251 - accuracy: 0.9899 - f1_m: 0.7584 - precision_m: 0.8204 - recall_m: 0.7096 - val_loss: 0.0348 - val_accuracy: 0.9886 - val_f1_m: 0.6514 - val_precision_m: 0.7912 - val_recall_m: 0.5615 - 284s/epoch - 1s/step
# Epoch 66/100
#
# Epoch 66: val_f1_m did not improve from 0.67344
# 190/190 - 289s - loss: 0.0250 - accuracy: 0.9899 - f1_m: 0.7609 - precision_m: 0.8225 - recall_m: 0.7113 - val_loss: 0.0307 - val_accuracy: 0.9884 - val_f1_m: 0.6716 - val_precision_m: 0.7496 - val_recall_m: 0.6163 - 289s/epoch - 2s/step
# Epoch 67/100
#
# Epoch 67: val_f1_m did not improve from 0.67344
# 190/190 - 285s - loss: 0.0249 - accuracy: 0.9900 - f1_m: 0.7570 - precision_m: 0.8240 - recall_m: 0.7056 - val_loss: 0.0325 - val_accuracy: 0.9883 - val_f1_m: 0.6619 - val_precision_m: 0.7505 - val_recall_m: 0.6004 - 285s/epoch - 1s/step
# Epoch 68/100
#
# Epoch 68: val_f1_m did not improve from 0.67344
# 190/190 - 285s - loss: 0.0247 - accuracy: 0.9900 - f1_m: 0.7621 - precision_m: 0.8217 - recall_m: 0.7146 - val_loss: 0.0338 - val_accuracy: 0.9883 - val_f1_m: 0.6405 - val_precision_m: 0.7929 - val_recall_m: 0.5450 - 285s/epoch - 1s/step
# Epoch 69/100
#
# Epoch 69: val_f1_m did not improve from 0.67344
# 190/190 - 287s - loss: 0.0354 - accuracy: 0.9863 - f1_m: 0.6524 - precision_m: 0.7532 - recall_m: 0.6047 - val_loss: 0.0318 - val_accuracy: 0.9884 - val_f1_m: 0.6423 - val_precision_m: 0.7965 - val_recall_m: 0.5478 - 287s/epoch - 2s/step
# Epoch 70/100
#
# Epoch 70: val_f1_m did not improve from 0.67344
# 190/190 - 287s - loss: 0.0274 - accuracy: 0.9891 - f1_m: 0.7316 - precision_m: 0.8147 - recall_m: 0.6716 - val_loss: 0.0332 - val_accuracy: 0.9880 - val_f1_m: 0.6258 - val_precision_m: 0.8016 - val_recall_m: 0.5252 - 287s/epoch - 2s/step
# Epoch 71/100
#
# Epoch 71: val_f1_m did not improve from 0.67344
# 190/190 - 285s - loss: 0.0258 - accuracy: 0.9897 - f1_m: 0.7480 - precision_m: 0.8174 - recall_m: 0.6950 - val_loss: 0.0319 - val_accuracy: 0.9887 - val_f1_m: 0.6631 - val_precision_m: 0.7843 - val_recall_m: 0.5811 - 285s/epoch - 1s/step
# Epoch 72/100
#
# Epoch 72: val_f1_m did not improve from 0.67344
# 190/190 - 284s - loss: 0.0251 - accuracy: 0.9900 - f1_m: 0.7607 - precision_m: 0.8236 - recall_m: 0.7108 - val_loss: 0.0316 - val_accuracy: 0.9887 - val_f1_m: 0.6671 - val_precision_m: 0.7717 - val_recall_m: 0.5953 - 284s/epoch - 1s/step
# Epoch 73/100
#
# Epoch 73: val_f1_m improved from 0.67344 to 0.68021, saving model to best_model.h5
# 190/190 - 286s - loss: 0.0248 - accuracy: 0.9900 - f1_m: 0.7606 - precision_m: 0.8234 - recall_m: 0.7119 - val_loss: 0.0303 - val_accuracy: 0.9885 - val_f1_m: 0.6802 - val_precision_m: 0.7402 - val_recall_m: 0.6387 - 286s/epoch - 2s/step
# Epoch 74/100
#
# Epoch 74: val_f1_m did not improve from 0.68021
# 190/190 - 285s - loss: 0.0249 - accuracy: 0.9900 - f1_m: 0.7582 - precision_m: 0.8226 - recall_m: 0.7079 - val_loss: 0.0339 - val_accuracy: 0.9884 - val_f1_m: 0.6413 - val_precision_m: 0.7937 - val_recall_m: 0.5482 - 285s/epoch - 1s/step
# Epoch 75/100
#
# Epoch 75: val_f1_m did not improve from 0.68021
# 190/190 - 284s - loss: 0.0245 - accuracy: 0.9901 - f1_m: 0.7636 - precision_m: 0.8242 - recall_m: 0.7151 - val_loss: 0.0323 - val_accuracy: 0.9886 - val_f1_m: 0.6532 - val_precision_m: 0.7994 - val_recall_m: 0.5600 - 284s/epoch - 1s/step
# Epoch 76/100
#
# Epoch 76: val_f1_m did not improve from 0.68021
# 190/190 - 287s - loss: 0.0241 - accuracy: 0.9902 - f1_m: 0.7681 - precision_m: 0.8251 - recall_m: 0.7224 - val_loss: 0.0353 - val_accuracy: 0.9884 - val_f1_m: 0.6312 - val_precision_m: 0.8163 - val_recall_m: 0.5238 - 287s/epoch - 2s/step
# Epoch 77/100
#
# Epoch 77: val_f1_m did not improve from 0.68021
# 190/190 - 284s - loss: 0.0241 - accuracy: 0.9903 - f1_m: 0.7667 - precision_m: 0.8254 - recall_m: 0.7191 - val_loss: 0.0323 - val_accuracy: 0.9885 - val_f1_m: 0.6545 - val_precision_m: 0.7831 - val_recall_m: 0.5707 - 284s/epoch - 1s/step
# Epoch 78/100
#
# Epoch 78: val_f1_m did not improve from 0.68021
# 190/190 - 284s - loss: 0.0240 - accuracy: 0.9903 - f1_m: 0.7670 - precision_m: 0.8235 - recall_m: 0.7221 - val_loss: 0.0327 - val_accuracy: 0.9886 - val_f1_m: 0.6480 - val_precision_m: 0.8024 - val_recall_m: 0.5528 - 284s/epoch - 1s/step
# Epoch 79/100
#
# Epoch 79: val_f1_m did not improve from 0.68021
# 190/190 - 286s - loss: 0.0242 - accuracy: 0.9902 - f1_m: 0.7700 - precision_m: 0.8284 - recall_m: 0.7241 - val_loss: 0.0324 - val_accuracy: 0.9882 - val_f1_m: 0.6517 - val_precision_m: 0.7635 - val_recall_m: 0.5780 - 286s/epoch - 2s/step
# Epoch 80/100
#
# Epoch 80: val_f1_m did not improve from 0.68021
# 190/190 - 285s - loss: 0.0240 - accuracy: 0.9903 - f1_m: 0.7718 - precision_m: 0.8279 - recall_m: 0.7265 - val_loss: 0.0342 - val_accuracy: 0.9874 - val_f1_m: 0.6446 - val_precision_m: 0.7299 - val_recall_m: 0.5908 - 285s/epoch - 1s/step
# Epoch 81/100
#
# Epoch 81: val_f1_m did not improve from 0.68021
# 190/190 - 284s - loss: 0.0253 - accuracy: 0.9899 - f1_m: 0.7579 - precision_m: 0.8243 - recall_m: 0.7083 - val_loss: 0.0341 - val_accuracy: 0.9886 - val_f1_m: 0.6542 - val_precision_m: 0.7889 - val_recall_m: 0.5667 - 284s/epoch - 1s/step
# Epoch 82/100
#
# Epoch 82: val_f1_m did not improve from 0.68021
# 190/190 - 286s - loss: 0.0257 - accuracy: 0.9897 - f1_m: 0.7445 - precision_m: 0.8202 - recall_m: 0.6924 - val_loss: 0.0329 - val_accuracy: 0.9884 - val_f1_m: 0.6422 - val_precision_m: 0.8006 - val_recall_m: 0.5456 - 286s/epoch - 2s/step
# Epoch 83/100
#
# Epoch 83: val_f1_m did not improve from 0.68021
# 190/190 - 287s - loss: 0.0244 - accuracy: 0.9902 - f1_m: 0.7621 - precision_m: 0.8233 - recall_m: 0.7140 - val_loss: 0.0316 - val_accuracy: 0.9886 - val_f1_m: 0.6714 - val_precision_m: 0.7599 - val_recall_m: 0.6094 - 287s/epoch - 2s/step
# Epoch 84/100
#
# Epoch 84: val_f1_m did not improve from 0.68021
# 190/190 - 288s - loss: 0.0238 - accuracy: 0.9904 - f1_m: 0.7692 - precision_m: 0.8272 - recall_m: 0.7236 - val_loss: 0.0315 - val_accuracy: 0.9888 - val_f1_m: 0.6673 - val_precision_m: 0.7799 - val_recall_m: 0.5913 - 288s/epoch - 2s/step
# Epoch 85/100
#
# Epoch 85: val_f1_m did not improve from 0.68021
# 190/190 - 298s - loss: 0.0234 - accuracy: 0.9906 - f1_m: 0.7727 - precision_m: 0.8288 - recall_m: 0.7275 - val_loss: 0.0333 - val_accuracy: 0.9886 - val_f1_m: 0.6622 - val_precision_m: 0.7828 - val_recall_m: 0.5829 - 298s/epoch - 2s/step
# Epoch 86/100
#
# Epoch 86: val_f1_m did not improve from 0.68021
# 190/190 - 299s - loss: 0.0233 - accuracy: 0.9906 - f1_m: 0.7748 - precision_m: 0.8292 - recall_m: 0.7309 - val_loss: 0.0347 - val_accuracy: 0.9884 - val_f1_m: 0.6324 - val_precision_m: 0.8200 - val_recall_m: 0.5242 - 299s/epoch - 2s/step
# Epoch 87/100
#
# Epoch 87: val_f1_m did not improve from 0.68021
# 190/190 - 289s - loss: 0.0233 - accuracy: 0.9906 - f1_m: 0.7781 - precision_m: 0.8321 - recall_m: 0.7343 - val_loss: 0.0321 - val_accuracy: 0.9885 - val_f1_m: 0.6701 - val_precision_m: 0.7540 - val_recall_m: 0.6119 - 289s/epoch - 2s/step
# Epoch 88/100
#
# Epoch 88: val_f1_m did not improve from 0.68021
# 190/190 - 284s - loss: 0.0235 - accuracy: 0.9905 - f1_m: 0.7774 - precision_m: 0.8328 - recall_m: 0.7334 - val_loss: 0.0345 - val_accuracy: 0.9885 - val_f1_m: 0.6393 - val_precision_m: 0.8139 - val_recall_m: 0.5347 - 284s/epoch - 1s/step
# Epoch 89/100
#
# Epoch 89: val_f1_m did not improve from 0.68021
# 190/190 - 286s - loss: 0.0230 - accuracy: 0.9907 - f1_m: 0.7804 - precision_m: 0.8318 - recall_m: 0.7376 - val_loss: 0.0349 - val_accuracy: 0.9884 - val_f1_m: 0.6513 - val_precision_m: 0.7785 - val_recall_m: 0.5679 - 286s/epoch - 2s/step
# Epoch 90/100
#
# Epoch 90: val_f1_m did not improve from 0.68021
# 190/190 - 285s - loss: 0.0246 - accuracy: 0.9901 - f1_m: 0.7659 - precision_m: 0.8248 - recall_m: 0.7208 - val_loss: 0.0360 - val_accuracy: 0.9880 - val_f1_m: 0.6020 - val_precision_m: 0.8397 - val_recall_m: 0.4785 - 285s/epoch - 2s/step
# Epoch 91/100
#
# Epoch 91: val_f1_m did not improve from 0.68021
# 190/190 - 284s - loss: 0.0243 - accuracy: 0.9902 - f1_m: 0.7666 - precision_m: 0.8218 - recall_m: 0.7225 - val_loss: 0.0311 - val_accuracy: 0.9888 - val_f1_m: 0.6730 - val_precision_m: 0.7691 - val_recall_m: 0.6053 - 284s/epoch - 1s/step
# Epoch 92/100
#
# Epoch 92: val_f1_m did not improve from 0.68021
# 190/190 - 286s - loss: 0.0232 - accuracy: 0.9906 - f1_m: 0.7793 - precision_m: 0.8344 - recall_m: 0.7349 - val_loss: 0.0345 - val_accuracy: 0.9886 - val_f1_m: 0.6575 - val_precision_m: 0.7870 - val_recall_m: 0.5718 - 286s/epoch - 2s/step
# Epoch 93/100
#
# Epoch 93: val_f1_m did not improve from 0.68021
# 190/190 - 286s - loss: 0.0228 - accuracy: 0.9907 - f1_m: 0.7754 - precision_m: 0.8281 - recall_m: 0.7322 - val_loss: 0.0323 - val_accuracy: 0.9887 - val_f1_m: 0.6672 - val_precision_m: 0.7679 - val_recall_m: 0.5971 - 286s/epoch - 2s/step
# Epoch 94/100
#
# Epoch 94: val_f1_m did not improve from 0.68021
# 190/190 - 285s - loss: 0.0229 - accuracy: 0.9907 - f1_m: 0.7795 - precision_m: 0.8340 - recall_m: 0.7362 - val_loss: 0.0334 - val_accuracy: 0.9887 - val_f1_m: 0.6665 - val_precision_m: 0.7743 - val_recall_m: 0.5925 - 285s/epoch - 1s/step
# Epoch 95/100
#
# Epoch 95: val_f1_m did not improve from 0.68021
# 190/190 - 288s - loss: 0.0229 - accuracy: 0.9907 - f1_m: 0.7800 - precision_m: 0.8307 - recall_m: 0.7382 - val_loss: 0.0359 - val_accuracy: 0.9884 - val_f1_m: 0.6339 - val_precision_m: 0.8135 - val_recall_m: 0.5289 - 288s/epoch - 2s/step
# Epoch 96/100
#
# Epoch 96: val_f1_m did not improve from 0.68021
# 190/190 - 285s - loss: 0.0228 - accuracy: 0.9907 - f1_m: 0.7764 - precision_m: 0.8317 - recall_m: 0.7327 - val_loss: 0.0345 - val_accuracy: 0.9886 - val_f1_m: 0.6512 - val_precision_m: 0.7917 - val_recall_m: 0.5617 - 285s/epoch - 1s/step
# Epoch 97/100
#
# Epoch 97: val_f1_m did not improve from 0.68021
# 190/190 - 285s - loss: 0.0226 - accuracy: 0.9908 - f1_m: 0.7848 - precision_m: 0.8325 - recall_m: 0.7451 - val_loss: 0.0332 - val_accuracy: 0.9887 - val_f1_m: 0.6554 - val_precision_m: 0.7908 - val_recall_m: 0.5674 - 285s/epoch - 1s/step
# Epoch 98/100
#
# Epoch 98: val_f1_m did not improve from 0.68021
# 190/190 - 286s - loss: 0.0252 - accuracy: 0.9899 - f1_m: 0.7610 - precision_m: 0.8219 - recall_m: 0.7157 - val_loss: 0.0355 - val_accuracy: 0.9883 - val_f1_m: 0.6388 - val_precision_m: 0.7901 - val_recall_m: 0.5450 - 286s/epoch - 2s/step
# Epoch 99/100
#
# Epoch 99: val_f1_m did not improve from 0.68021
# 190/190 - 284s - loss: 0.0233 - accuracy: 0.9906 - f1_m: 0.7767 - precision_m: 0.8295 - recall_m: 0.7334 - val_loss: 0.0371 - val_accuracy: 0.9883 - val_f1_m: 0.6278 - val_precision_m: 0.8140 - val_recall_m: 0.5209 - 284s/epoch - 1s/step
# Epoch 100/100
#
# Epoch 100: val_f1_m did not improve from 0.68021
# 190/190 - 285s - loss: 0.0226 - accuracy: 0.9908 - f1_m: 0.7847 - precision_m: 0.8351 - recall_m: 0.7432 - val_loss: 0.0367 - val_accuracy: 0.9885 - val_f1_m: 0.6404 - val_precision_m: 0.8012 - val_recall_m: 0.5427 - 285s/epoch - 1s/step

# %%
# with open('model_v1.pickle', 'wb') as f:
#     pickle.dump(model, f)
#     pickle.dump(history, f)

    with open('model_v1.pickle', 'rb') as f:
        model= pickle.load(f)
        history= pickle.load(f)
# Out:
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op while saving (showing 5 of 23). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: ram://c1f8cf64-659b-4849-9d00-f905d632bac2/assets
# INFO:tensorflow:Assets written to: ram://c1f8cf64-659b-4849-9d00-f905d632bac2/assets
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op while saving (showing 5 of 23). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: ram://6c7405c2-3532-4b80-8230-ac59a7b445ce/assets
# INFO:tensorflow:Assets written to: ram://6c7405c2-3532-4b80-8230-ac59a7b445ce/assets

# %%
loss, accuracy, f1_score, precision, recall = model.evaluate(x_valid, y_valid, verbose=0)
print(loss, accuracy, f1_score, precision, recall)
# Out:
# 0.03668443486094475 0.988465428352356 0.6535392999649048 0.8055066466331482 0.5546383261680603

# %%
fig,((ax11,ax12),(ax13,ax14)) = plt.subplots(2,2,figsize=(20,15))
ax11.plot(history.history['loss'])
ax11.plot(history.history['val_loss'])
ax11.title.set_text('Unet model loss')
ax11.set_ylabel('loss')
ax11.set_xlabel('epoch')
ax11.legend(['train', 'validation'], loc='upper left')

ax12.plot(history.history['precision_m'])
ax12.plot(history.history['val_precision_m'])
ax12.set_title('Unet model precision')
ax12.set_ylabel('precision')
ax12.set_xlabel('epoch')
ax12.legend(['train', 'validation'], loc='upper left')

ax13.plot(history.history['recall_m'])
ax13.plot(history.history['val_recall_m'])
ax13.set_title('Unet model recall')
ax13.set_ylabel('recall')
ax13.set_xlabel('epoch')
ax13.legend(['train', 'validation'], loc='upper left')

ax14.plot(history.history['f1_m'])
ax14.plot(history.history['val_f1_m'])
ax14.set_title('Unet model f1')
ax14.set_ylabel('f1')
ax14.set_xlabel('epoch')
ax14.legend(['train', 'validation'], loc='upper left')

# %%
threshold = 0.5
pred_img = model.predict(x_valid)
pred_img = (pred_img > threshold).astype(np.uint8)
# Out:
# 24/24 [==============================] - 11s 440ms/step

# %%
img = 156
fig,(ax1,ax2,ax3)= plt.subplots(1,3,figsize=(15,10))
ax1.imshow(pred_img[img, :, :, 0])
ax1.set_title("Predictions")
ax2.imshow(y_valid[img, :, :, 0])
ax2.set_title("Label")
ax3.imshow(x_valid[img, :, :, 5])
ax3.set_title('Training Image (BSI)')
# Out:
# Text(0.5, 1.0, 'Training Image (BSI)')
